# %%
# imports
import os
import json
import time
import concurrent.futures
from pathlib import Path
import threading
import requests

import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from ai_tools.tools import LLMQuery
from pokemon_tools import PokemonAPIClient

# %%
SYSTEM_PROMPT = """You are an expert Pokémon Data Analyst and Lorekeeper. Your task is to process raw JSON data into a **semantically dense, natural language profile** optimized for Vector Search retrieval (RAG).

### Core Instruction:
Use the provided JSON as the **primary source** for facts (Stats, Moves, Evolution), but use your **World Knowledge** to expand on behavior, competitive viability, and lore. The goal is to maximize the number of relevant searchable keywords (moves, abilities, behaviors) in the output.

### STRICT Output Constraints:
1.  **NO Conversational Filler:** Start immediately with the Markdown headers. Do not say "Here is the profile."
2.  **Naturalize the ID:** Include the Pokémon's ID (e.g., #006) naturally in the first sentence of the Identity section.
3.  **Omit Empty Data:** If a field is empty (e.g., `held_items` or `forms`), skip it entirely.
4.  **Format:** Use Markdown headers (`##`) for sections.

### Processing Guidelines:

**1. Identity & Lore (Expand this)**
* **Variant Detection:** Check the `name` field. If it contains suffixes like `-alola`, `-galar`, `-hisui`, or `-paldea`, explicitly name it as the **[Region]n Form** (e.g., convert `vulpix-alola` to "Alolan Vulpix").
* **Bio Synthesis:** Combine `genus`, `flavor_text`, `habitat`, `generation`, and `color` into a cohesive summary.
* **Form Potential (World Knowledge):** Explicitly mention if this Pokémon has **Mega Evolutions**, **Gigantamax forms**, or **Paradox forms**, even if they are not listed in the JSON.
* **Context:** Mention the specific region associated with the generation (e.g., "Generation I (Kanto)").

**2. Combat Profile (Detailed Analysis)**
* **Stat Block:** You **MUST** list the specific Base Stats in a list format using these standard abbreviations: **HP, Attack, Defense, Sp. Atk, Sp. Def, Speed**.
* **Archetype:** Analyze the stats to assign a competitive role (e.g., "Fast Special Sweeper," "Physical Tank," "Mixed Attacker").
* **Type Matchups:**
    * Explicitly list **Weaknesses** and **Resistances**.
    * **Logic Check:** If a Pokémon has a double weakness (e.g., Fire/Flying vs. Rock), explicitly label it as a **"Double Weakness (4x)."**
* **Smart Move Selection:** Select 4 specific moves that align with the Pokémon's **highest offensive stat**. (e.g., If Sp. Atk > Attack, list *Flamethrower*, not *Fire Punch*). Include Utility moves (Recover, Roost) if relevant.
* **Abilities:** Name the abilities and briefly explain their tactical effect.

**3. Evolution & Acquisition**
* **Detailed Chain:** Narrate the full evolutionary line.
* **Triggers:** You must specify the **method** found in `evolution_details` (e.g., "when exposed to a Thunder Stone," "leveled up with High Friendship," "at Level 36").
* **Breeding:** Mention Egg Groups and Hatch Counters if relevant.

---

### Required Output Structure:

**## Identity & Lore**
[Name] (Pokedex #[ID]) is the [Genus]... [Detailed Description of appearance, habitat, and lore]... [Mention of Mega/G-Max forms if applicable]...

**## Combat Profile**
* **Stats:** HP [Val], Attack [Val], Defense [Val], Sp. Atk [Val], Sp. Def [Val], Speed [Val].
* **Archetype:** [Role Name] (e.g., Fast Special Sweeper).
* **Type Matchups:** It is **weak to [Types]** (mentioning any 4x weaknesses) and **resists [Types]**.
* **Move Selection:** Capitalizing on its stats, key moves include **[Move 1], [Move 2], [Move 3], and [Move 4]**.
* **Abilities:** [Ability Name] ([Effect description])...

**## Evolution & Biology**
[Name] is part of a [Number]-stage evolutionary line. It evolves from [Pre-evo] when [Condition]... It belongs to the [Egg Group] group...

---
**Input Data:**
[JSON Data provided in the user prompt]
"""

# %%
LIST_CACHE_FILE = Path("pokemon_list.json")

def get_all_pokemon():
    if LIST_CACHE_FILE.exists():
        print("Loading Pokemon list from cache...")
        try:
            with open(LIST_CACHE_FILE, "r") as f:
                return json.load(f)
        except Exception as e:
            print(f"Error reading cache, fetching fresh list. Error: {e}")

    print("Fetching list of all Pokemon from API...")
    url = "https://pokeapi.co/api/v2/pokemon?limit=10000"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        pokemon_list = [p["name"] for p in data["results"]]
        
        # Save to cache
        with open(LIST_CACHE_FILE, "w") as f:
            json.dump(pokemon_list, f)
        print(f"Saved {len(pokemon_list)} Pokemon to {LIST_CACHE_FILE}")
        return pokemon_list
    except Exception as e:
        print(f"Error fetching Pokemon list: {e}")
        return []

len(get_all_pokemon())
# Out:
# Loading Pokemon list from cache...
# ['bulbasaur',
#  'ivysaur',
#  'venusaur',
#  'charmander',
#  'charmeleon',
#  'charizard',
#  'squirtle',
#  'wartortle',
#  'blastoise',
#  'caterpie',
#  'metapod',
#  'butterfree',
#  'weedle',
#  'kakuna',
#  'beedrill',
#  'pidgey',
#  'pidgeotto',
#  'pidgeot',
#  'rattata',
#  'raticate',
#  'spearow',
#  'fearow',
#  'ekans',
#  'arbok',
#  'pikachu',
#  'raichu',
#  'sandshrew',
#  'sandslash',
#  'nidoran-f',
#  'nidorina',
#  'nidoqueen',
#  'nidoran-m',
#  'nidorino',
#  'nidoking',
#  'clefairy',
#  'clefable',
#  'vulpix',
#  'ninetales',
#  'jigglypuff',
#  'wigglytuff',
#  'zubat',
#  'golbat',
#  'oddish',
#  'gloom',
#  'vileplume',
#  'paras',
#  'parasect',
#  'venonat',
#  'venomoth',
#  'diglett',
#  'dugtrio',
#  'meowth',
#  'persian',
#  'psyduck',
#  'golduck',
#  'mankey',
#  'primeape',
#  'growlithe',
#  'arcanine',
#  'poliwag',
#  'poliwhirl',
#  'poliwrath',
#  'abra',
#  'kadabra',
#  'alakazam',
#  'machop',
#  'machoke',
#  'machamp',
#  'bellsprout',
#  'weepinbell',
#  'victreebel',
#  'tentacool',
#  'tentacruel',
#  'geodude',
#  'graveler',
#  'golem',
#  'ponyta',
#  'rapidash',
#  'slowpoke',
#  'slowbro',
#  'magnemite',
#  'magneton',
#  'farfetchd',
#  'doduo',
#  'dodrio',
#  'seel',
#  'dewgong',
#  'grimer',
#  'muk',
#  'shellder',
#  'cloyster',
#  'gastly',
#  'haunter',
#  'gengar',
#  'onix',
#  'drowzee',
#  'hypno',
#  'krabby',
#  'kingler',
#  'voltorb',
#  'electrode',
#  'exeggcute',
#  'exeggutor',
#  'cubone',
#  'marowak',
#  'hitmonlee',
#  'hitmonchan',
#  'lickitung',
#  'koffing',
#  'weezing',
#  'rhyhorn',
#  'rhydon',
#  'chansey',
#  'tangela',
#  'kangaskhan',
#  'horsea',
#  'seadra',
#  'goldeen',
#  'seaking',
#  'staryu',
#  'starmie',
#  'mr-mime',
#  'scyther',
#  'jynx',
#  'electabuzz',
#  'magmar',
#  'pinsir',
#  'tauros',
#  'magikarp',
#  'gyarados',
#  'lapras',
#  'ditto',
#  'eevee',
#  'vaporeon',
#  'jolteon',
#  'flareon',
#  'porygon',
#  'omanyte',
#  'omastar',
#  'kabuto',
#  'kabutops',
#  'aerodactyl',
#  'snorlax',
#  'articuno',
#  'zapdos',
#  'moltres',
#  'dratini',
#  'dragonair',
#  'dragonite',
#  'mewtwo',
#  'mew',
#  'chikorita',
#  'bayleef',
#  'meganium',
#  'cyndaquil',
#  'quilava',
#  'typhlosion',
#  'totodile',
#  'croconaw',
#  'feraligatr',
#  'sentret',
#  'furret',
#  'hoothoot',
#  'noctowl',
#  'ledyba',
#  'ledian',
#  'spinarak',
#  'ariados',
#  'crobat',
#  'chinchou',
#  'lanturn',
#  'pichu',
#  'cleffa',
#  'igglybuff',
#  'togepi',
#  'togetic',
#  'natu',
#  'xatu',
#  'mareep',
#  'flaaffy',
#  'ampharos',
#  'bellossom',
#  'marill',
#  'azumarill',
#  'sudowoodo',
#  'politoed',
#  'hoppip',
#  'skiploom',
#  'jumpluff',
#  'aipom',
#  'sunkern',
#  'sunflora',
#  'yanma',
#  'wooper',
#  'quagsire',
#  'espeon',
#  'umbreon',
#  'murkrow',
#  'slowking',
#  'misdreavus',
#  'unown',
#  'wobbuffet',
#  'girafarig',
#  'pineco',
#  'forretress',
#  'dunsparce',
#  'gligar',
#  'steelix',
#  'snubbull',
#  'granbull',
#  'qwilfish',
#  'scizor',
#  'shuckle',
#  'heracross',
#  'sneasel',
#  'teddiursa',
#  'ursaring',
#  'slugma',
#  'magcargo',
#  'swinub',
#  'piloswine',
#  'corsola',
#  'remoraid',
#  'octillery',
#  'delibird',
#  'mantine',
#  'skarmory',
#  'houndour',
#  'houndoom',
#  'kingdra',
#  'phanpy',
#  'donphan',
#  'porygon2',
#  'stantler',
#  'smeargle',
#  'tyrogue',
#  'hitmontop',
#  'smoochum',
#  'elekid',
#  'magby',
#  'miltank',
#  'blissey',
#  'raikou',
#  'entei',
#  'suicune',
#  'larvitar',
#  'pupitar',
#  'tyranitar',
#  'lugia',
#  'ho-oh',
#  'celebi',
#  'treecko',
#  'grovyle',
#  'sceptile',
#  'torchic',
#  'combusken',
#  'blaziken',
#  'mudkip',
#  'marshtomp',
#  'swampert',
#  'poochyena',
#  'mightyena',
#  'zigzagoon',
#  'linoone',
#  'wurmple',
#  'silcoon',
#  'beautifly',
#  'cascoon',
#  'dustox',
#  'lotad',
#  'lombre',
#  'ludicolo',
#  'seedot',
#  'nuzleaf',
#  'shiftry',
#  'taillow',
#  'swellow',
#  'wingull',
#  'pelipper',
#  'ralts',
#  'kirlia',
#  'gardevoir',
#  'surskit',
#  'masquerain',
#  'shroomish',
#  'breloom',
#  'slakoth',
#  'vigoroth',
#  'slaking',
#  'nincada',
#  'ninjask',
#  'shedinja',
#  'whismur',
#  'loudred',
#  'exploud',
#  'makuhita',
#  'hariyama',
#  'azurill',
#  'nosepass',
#  'skitty',
#  'delcatty',
#  'sableye',
#  'mawile',
#  'aron',
#  'lairon',
#  'aggron',
#  'meditite',
#  'medicham',
#  'electrike',
#  'manectric',
#  'plusle',
#  'minun',
#  'volbeat',
#  'illumise',
#  'roselia',
#  'gulpin',
#  'swalot',
#  'carvanha',
#  'sharpedo',
#  'wailmer',
#  'wailord',
#  'numel',
#  'camerupt',
#  'torkoal',
#  'spoink',
#  'grumpig',
#  'spinda',
#  'trapinch',
#  'vibrava',
#  'flygon',
#  'cacnea',
#  'cacturne',
#  'swablu',
#  'altaria',
#  'zangoose',
#  'seviper',
#  'lunatone',
#  'solrock',
#  'barboach',
#  'whiscash',
#  'corphish',
#  'crawdaunt',
#  'baltoy',
#  'claydol',
#  'lileep',
#  'cradily',
#  'anorith',
#  'armaldo',
#  'feebas',
#  'milotic',
#  'castform',
#  'kecleon',
#  'shuppet',
#  'banette',
#  'duskull',
#  'dusclops',
#  'tropius',
#  'chimecho',
#  'absol',
#  'wynaut',
#  'snorunt',
#  'glalie',
#  'spheal',
#  'sealeo',
#  'walrein',
#  'clamperl',
#  'huntail',
#  'gorebyss',
#  'relicanth',
#  'luvdisc',
#  'bagon',
#  'shelgon',
#  'salamence',
#  'beldum',
#  'metang',
#  'metagross',
#  'regirock',
#  'regice',
#  'registeel',
#  'latias',
#  'latios',
#  'kyogre',
#  'groudon',
#  'rayquaza',
#  'jirachi',
#  'deoxys-normal',
#  'turtwig',
#  'grotle',
#  'torterra',
#  'chimchar',
#  'monferno',
#  'infernape',
#  'piplup',
#  'prinplup',
#  'empoleon',
#  'starly',
#  'staravia',
#  'staraptor',
#  'bidoof',
#  'bibarel',
#  'kricketot',
#  'kricketune',
#  'shinx',
#  'luxio',
#  'luxray',
#  'budew',
#  'roserade',
#  'cranidos',
#  'rampardos',
#  'shieldon',
#  'bastiodon',
#  'burmy',
#  'wormadam-plant',
#  'mothim',
#  'combee',
#  'vespiquen',
#  'pachirisu',
#  'buizel',
#  'floatzel',
#  'cherubi',
#  'cherrim',
#  'shellos',
#  'gastrodon',
#  'ambipom',
#  'drifloon',
#  'drifblim',
#  'buneary',
#  'lopunny',
#  'mismagius',
#  'honchkrow',
#  'glameow',
#  'purugly',
#  'chingling',
#  'stunky',
#  'skuntank',
#  'bronzor',
#  'bronzong',
#  'bonsly',
#  'mime-jr',
#  'happiny',
#  'chatot',
#  'spiritomb',
#  'gible',
#  'gabite',
#  'garchomp',
#  'munchlax',
#  'riolu',
#  'lucario',
#  'hippopotas',
#  'hippowdon',
#  'skorupi',
#  'drapion',
#  'croagunk',
#  'toxicroak',
#  'carnivine',
#  'finneon',
#  'lumineon',
#  'mantyke',
#  'snover',
#  'abomasnow',
#  'weavile',
#  'magnezone',
#  'lickilicky',
#  'rhyperior',
#  'tangrowth',
#  'electivire',
#  'magmortar',
#  'togekiss',
#  'yanmega',
#  'leafeon',
#  'glaceon',
#  'gliscor',
#  'mamoswine',
#  'porygon-z',
#  'gallade',
#  'probopass',
#  'dusknoir',
#  'froslass',
#  'rotom',
#  'uxie',
#  'mesprit',
#  'azelf',
#  'dialga',
#  'palkia',
#  'heatran',
#  'regigigas',
#  'giratina-altered',
#  'cresselia',
#  'phione',
#  'manaphy',
#  'darkrai',
#  'shaymin-land',
#  'arceus',
#  'victini',
#  'snivy',
#  'servine',
#  'serperior',
#  'tepig',
#  'pignite',
#  'emboar',
#  'oshawott',
#  'dewott',
#  'samurott',
#  'patrat',
#  'watchog',
#  'lillipup',
#  'herdier',
#  'stoutland',
#  'purrloin',
#  'liepard',
#  'pansage',
#  'simisage',
#  'pansear',
#  'simisear',
#  'panpour',
#  'simipour',
#  'munna',
#  'musharna',
#  'pidove',
#  'tranquill',
#  'unfezant',
#  'blitzle',
#  'zebstrika',
#  'roggenrola',
#  'boldore',
#  'gigalith',
#  'woobat',
#  'swoobat',
#  'drilbur',
#  'excadrill',
#  'audino',
#  'timburr',
#  'gurdurr',
#  'conkeldurr',
#  'tympole',
#  'palpitoad',
#  'seismitoad',
#  'throh',
#  'sawk',
#  'sewaddle',
#  'swadloon',
#  'leavanny',
#  'venipede',
#  'whirlipede',
#  'scolipede',
#  'cottonee',
#  'whimsicott',
#  'petilil',
#  'lilligant',
#  'basculin-red-striped',
#  'sandile',
#  'krokorok',
#  'krookodile',
#  'darumaka',
#  'darmanitan-standard',
#  'maractus',
#  'dwebble',
#  'crustle',
#  'scraggy',
#  'scrafty',
#  'sigilyph',
#  'yamask',
#  'cofagrigus',
#  'tirtouga',
#  'carracosta',
#  'archen',
#  'archeops',
#  'trubbish',
#  'garbodor',
#  'zorua',
#  'zoroark',
#  'minccino',
#  'cinccino',
#  'gothita',
#  'gothorita',
#  'gothitelle',
#  'solosis',
#  'duosion',
#  'reuniclus',
#  'ducklett',
#  'swanna',
#  'vanillite',
#  'vanillish',
#  'vanilluxe',
#  'deerling',
#  'sawsbuck',
#  'emolga',
#  'karrablast',
#  'escavalier',
#  'foongus',
#  'amoonguss',
#  'frillish',
#  'jellicent',
#  'alomomola',
#  'joltik',
#  'galvantula',
#  'ferroseed',
#  'ferrothorn',
#  'klink',
#  'klang',
#  'klinklang',
#  'tynamo',
#  'eelektrik',
#  'eelektross',
#  'elgyem',
#  'beheeyem',
#  'litwick',
#  'lampent',
#  'chandelure',
#  'axew',
#  'fraxure',
#  'haxorus',
#  'cubchoo',
#  'beartic',
#  'cryogonal',
#  'shelmet',
#  'accelgor',
#  'stunfisk',
#  'mienfoo',
#  'mienshao',
#  'druddigon',
#  'golett',
#  'golurk',
#  'pawniard',
#  'bisharp',
#  'bouffalant',
#  'rufflet',
#  'braviary',
#  'vullaby',
#  'mandibuzz',
#  'heatmor',
#  'durant',
#  'deino',
#  'zweilous',
#  'hydreigon',
#  'larvesta',
#  'volcarona',
#  'cobalion',
#  'terrakion',
#  'virizion',
#  'tornadus-incarnate',
#  'thundurus-incarnate',
#  'reshiram',
#  'zekrom',
#  'landorus-incarnate',
#  'kyurem',
#  'keldeo-ordinary',
#  'meloetta-aria',
#  'genesect',
#  'chespin',
#  'quilladin',
#  'chesnaught',
#  'fennekin',
#  'braixen',
#  'delphox',
#  'froakie',
#  'frogadier',
#  'greninja',
#  'bunnelby',
#  'diggersby',
#  'fletchling',
#  'fletchinder',
#  'talonflame',
#  'scatterbug',
#  'spewpa',
#  'vivillon',
#  'litleo',
#  'pyroar',
#  'flabebe',
#  'floette',
#  'florges',
#  'skiddo',
#  'gogoat',
#  'pancham',
#  'pangoro',
#  'furfrou',
#  'espurr',
#  'meowstic-male',
#  'honedge',
#  'doublade',
#  'aegislash-shield',
#  'spritzee',
#  'aromatisse',
#  'swirlix',
#  'slurpuff',
#  'inkay',
#  'malamar',
#  'binacle',
#  'barbaracle',
#  'skrelp',
#  'dragalge',
#  'clauncher',
#  'clawitzer',
#  'helioptile',
#  'heliolisk',
#  'tyrunt',
#  'tyrantrum',
#  'amaura',
#  'aurorus',
#  'sylveon',
#  'hawlucha',
#  'dedenne',
#  'carbink',
#  'goomy',
#  'sliggoo',
#  'goodra',
#  'klefki',
#  'phantump',
#  'trevenant',
#  'pumpkaboo-average',
#  'gourgeist-average',
#  'bergmite',
#  'avalugg',
#  'noibat',
#  'noivern',
#  'xerneas',
#  'yveltal',
#  'zygarde-50',
#  'diancie',
#  'hoopa',
#  'volcanion',
#  'rowlet',
#  'dartrix',
#  'decidueye',
#  'litten',
#  'torracat',
#  'incineroar',
#  'popplio',
#  'brionne',
#  'primarina',
#  'pikipek',
#  'trumbeak',
#  'toucannon',
#  'yungoos',
#  'gumshoos',
#  'grubbin',
#  'charjabug',
#  'vikavolt',
#  'crabrawler',
#  'crabominable',
#  'oricorio-baile',
#  'cutiefly',
#  'ribombee',
#  'rockruff',
#  'lycanroc-midday',
#  'wishiwashi-solo',
#  'mareanie',
#  'toxapex',
#  'mudbray',
#  'mudsdale',
#  'dewpider',
#  'araquanid',
#  'fomantis',
#  'lurantis',
#  'morelull',
#  'shiinotic',
#  'salandit',
#  'salazzle',
#  'stufful',
#  'bewear',
#  'bounsweet',
#  'steenee',
#  'tsareena',
#  'comfey',
#  'oranguru',
#  'passimian',
#  'wimpod',
#  'golisopod',
#  'sandygast',
#  'palossand',
#  'pyukumuku',
#  'type-null',
#  'silvally',
#  'minior-red-meteor',
#  'komala',
#  'turtonator',
#  'togedemaru',
#  'mimikyu-disguised',
#  'bruxish',
#  'drampa',
#  'dhelmise',
#  'jangmo-o',
#  'hakamo-o',
#  'kommo-o',
#  'tapu-koko',
#  'tapu-lele',
#  'tapu-bulu',
#  'tapu-fini',
#  'cosmog',
#  'cosmoem',
#  'solgaleo',
#  'lunala',
#  'nihilego',
#  'buzzwole',
#  'pheromosa',
#  'xurkitree',
#  'celesteela',
#  'kartana',
#  'guzzlord',
#  'necrozma',
#  'magearna',
#  'marshadow',
#  'poipole',
#  'naganadel',
#  'stakataka',
#  'blacephalon',
#  'zeraora',
#  'meltan',
#  'melmetal',
#  'grookey',
#  'thwackey',
#  'rillaboom',
#  'scorbunny',
#  'raboot',
#  'cinderace',
#  'sobble',
#  'drizzile',
#  'inteleon',
#  'skwovet',
#  'greedent',
#  'rookidee',
#  'corvisquire',
#  'corviknight',
#  'blipbug',
#  'dottler',
#  'orbeetle',
#  'nickit',
#  'thievul',
#  'gossifleur',
#  'eldegoss',
#  'wooloo',
#  'dubwool',
#  'chewtle',
#  'drednaw',
#  'yamper',
#  'boltund',
#  'rolycoly',
#  'carkol',
#  'coalossal',
#  'applin',
#  'flapple',
#  'appletun',
#  'silicobra',
#  'sandaconda',
#  'cramorant',
#  'arrokuda',
#  'barraskewda',
#  'toxel',
#  'toxtricity-amped',
#  'sizzlipede',
#  'centiskorch',
#  'clobbopus',
#  'grapploct',
#  'sinistea',
#  'polteageist',
#  'hatenna',
#  'hattrem',
#  'hatterene',
#  'impidimp',
#  'morgrem',
#  'grimmsnarl',
#  'obstagoon',
#  'perrserker',
#  'cursola',
#  'sirfetchd',
#  'mr-rime',
#  'runerigus',
#  'milcery',
#  'alcremie',
#  'falinks',
#  'pincurchin',
#  'snom',
#  'frosmoth',
#  'stonjourner',
#  'eiscue-ice',
#  'indeedee-male',
#  'morpeko-full-belly',
#  'cufant',
#  'copperajah',
#  'dracozolt',
#  'arctozolt',
#  'dracovish',
#  'arctovish',
#  'duraludon',
#  'dreepy',
#  'drakloak',
#  'dragapult',
#  'zacian',
#  'zamazenta',
#  'eternatus',
#  'kubfu',
#  'urshifu-single-strike',
#  'zarude',
#  'regieleki',
#  'regidrago',
#  'glastrier',
#  'spectrier',
#  'calyrex',
#  'wyrdeer',
#  'kleavor',
#  'ursaluna',
#  'basculegion-male',
#  'sneasler',
#  'overqwil',
#  'enamorus-incarnate',
#  'sprigatito',
#  'floragato',
#  'meowscarada',
#  'fuecoco',
#  'crocalor',
#  'skeledirge',
#  'quaxly',
#  'quaxwell',
#  'quaquaval',
#  'lechonk',
#  'oinkologne-male',
#  'tarountula',
#  'spidops',
#  'nymble',
#  'lokix',
#  'pawmi',
#  'pawmo',
#  'pawmot',
#  'tandemaus',
#  'maushold-family-of-four',
#  'fidough',
#  'dachsbun',
#  'smoliv',
#  'dolliv',
#  'arboliva',
#  'squawkabilly-green-plumage',
#  'nacli',
#  'naclstack',
#  'garganacl',
#  'charcadet',
#  'armarouge',
#  'ceruledge',
#  'tadbulb',
#  'bellibolt',
#  'wattrel',
#  'kilowattrel',
#  'maschiff',
#  'mabosstiff',
#  'shroodle',
#  'grafaiai',
#  'bramblin',
#  'brambleghast',
#  'toedscool',
#  'toedscruel',
#  'klawf',
#  'capsakid',
#  'scovillain',
#  'rellor',
#  'rabsca',
#  'flittle',
#  'espathra',
#  'tinkatink',
#  'tinkatuff',
#  'tinkaton',
#  'wiglett',
#  'wugtrio',
#  'bombirdier',
#  'finizen',
#  'palafin-zero',
#  'varoom',
#  'revavroom',
#  'cyclizar',
#  'orthworm',
#  'glimmet',
#  'glimmora',
#  'greavard',
#  'houndstone',
#  'flamigo',
#  'cetoddle',
#  'cetitan',
#  'veluza',
#  'dondozo',
#  'tatsugiri-curly',
#  'annihilape',
#  'clodsire',
#  'farigiraf',
#  'dudunsparce-two-segment',
#  'kingambit',
#  'great-tusk',
#  'scream-tail',
#  'brute-bonnet',
#  'flutter-mane',
#  'slither-wing',
#  'sandy-shocks',
#  'iron-treads',
#  'iron-bundle',
#  'iron-hands',
#  'iron-jugulis',
#  'iron-moth',
#  'iron-thorns',
#  'frigibax',
#  'arctibax',
#  'baxcalibur',
#  'gimmighoul',
#  'gholdengo',
#  ...]

# %%
# Configuration
OUTPUT_DIR = Path("raw")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
MODEL_NAME = "gemini-3-flash-preview"
MAX_WORKERS = 10
ABORT_LIMIT = 20

# Global state
error_count = 0
error_lock = threading.Lock()
abort_event = threading.Event()



def generate_pokemon_data(pokemon_name):
    global error_count
    
    if abort_event.is_set():
        return

    # Optimistic existing file check
    existing = list(OUTPUT_DIR.glob(f"*_{pokemon_name}.md"))
    if existing:
        # print(f"Skipping {pokemon_name} (File exists)")
        return

    # Initialize Clients (Thread-safe)
    pokemon_client = PokemonAPIClient(enable_cache=False)
    llm_client = LLMQuery(model=MODEL_NAME, system_prompt=SYSTEM_PROMPT)
    
    time.sleep(0.5)
    
    try:
        print(f"Processing {pokemon_name}...")
        details = pokemon_client.get_pokemon_details(pokemon_name)
        if "error" in details:
            raise Exception(f"API Error: {details.get('error')}")
            
        type_info = []
        for t in details.get("types", []):
            t_info = pokemon_client.get_type_info(t)
            if "error" not in t_info:
                type_info.append(t_info)

        context = {"pokemon_details": details, "type_info": type_info}
        user_prompt = f"Here is the data for {pokemon_name}:\n```json\n{json.dumps(context, indent=2)}\n```"
        
        response = None
        for attempt in range(3):
            try:
                response = llm_client.query(user_prompt=user_prompt, use_history=False)
                if response: break
            except Exception as e:
                if attempt == 2: raise e
                time.sleep(2 ** attempt)

        p_id = details.get("id", 0)
        file_prefix = f"{p_id:04d}_{pokemon_name}"
        
        with open(OUTPUT_DIR / f"{file_prefix}.json", "w", encoding="utf-8") as f:
            json.dump(context, f, indent=2)
        with open(OUTPUT_DIR / f"{file_prefix}.md", "w", encoding="utf-8") as f:
            f.write(response)
            
        print(f"Saved {file_prefix}.md")
        
    except Exception as e:
        with error_lock:
            error_count += 1
            print(f"Error processing {pokemon_name}: {e} (Count: {error_count})")
            if error_count >= ABORT_LIMIT:
                print("Aborting generation due to error limit.")
                abort_event.set()

# Main Execution
try:
    POKEMON_LIST = get_all_pokemon()
    if POKEMON_LIST:
        print(f"Starting generation for {len(POKEMON_LIST)} Pokemon with {MAX_WORKERS} threads...")
        with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
            list(executor.map(generate_pokemon_data, POKEMON_LIST))
    else:
        print("No Pokemon found to process.")
    print("Generation complete.")
except KeyboardInterrupt:
    print("Generation interrupted.")
except Exception as e:
    print(f"Fatal error: {e}")
# Out:
# Loading Pokemon list from cache...
# Starting generation for 1350 Pokemon with 10 threads...
# Processing ralts...
# Processing stoutland...
# Processing purrloin...
# Processing liepard...
# Processing pansage...
# Processing simisage...
# Processing pansear...
# Processing panpour...
# Processing simipour...
# Processing simisear...
# Saved 0509_purrloin.md
# Saved 0510_liepard.md
# Processing munna...
# Processing musharna...
# Saved 0516_simipour.md
# Saved 0280_ralts.md
# Saved 0508_stoutland.md
# Processing pidove...
# Processing tranquill...
# Processing unfezant...
# Saved 0515_panpour.md
# Saved 0514_simisear.md
# Processing blitzle...
# Processing zebstrika...
# Saved 0512_simisage.md
# Saved 0511_pansage.md
# Processing roggenrola...
# Processing boldore...
# Saved 0513_pansear.md
# Processing gigalith...
# Saved 0517_munna.md
# Processing woobat...
# Saved 0521_unfezant.md
# Processing swoobat...
# Saved 0518_musharna.md
# Saved 0523_zebstrika.md
# Saved 0519_pidove.md
# Processing drilbur...
# Saved 0520_tranquill.md
# Processing excadrill...
# Processing audino...
# Processing timburr...
# Saved 0522_blitzle.md
# Saved 0526_gigalith.md
# Processing gurdurr...
# Saved 0524_roggenrola.md
# Processing conkeldurr...
# Saved 0525_boldore.md
# Processing tympole...
# Processing palpitoad...
# Saved 0527_woobat.md
# Processing seismitoad...
# Saved 0529_drilbur.md
# Processing throh...
# Saved 0533_gurdurr.md
# Saved 0532_timburr.md
# Processing sawk...
# Saved 0531_audino.md
# Saved 0528_swoobat.md
# Processing sewaddle...
# Processing leavanny...
# Processing swadloon...
# Saved 0536_palpitoad.md
# Processing venipede...
# Saved 0534_conkeldurr.md
# Saved 0535_tympole.md
# Processing whirlipede...
# Processing scolipede...
# Saved 0530_excadrill.md
# Processing cottonee...
# Saved 0537_seismitoad.md
# Processing whimsicott...
# Saved 0538_throh.md
# Processing petilil...
# Saved 0541_swadloon.md
# Processing lilligant...
# Saved 0539_sawk.md
# Saved 0540_sewaddle.md
# Saved 0542_leavanny.md
# Processing basculin-red-striped...
# Processing sandile...
# Processing krokorok...
# Saved 0543_venipede.md
# Processing krookodile...
# Saved 0544_whirlipede.md
# Processing darumaka...
# Saved 0545_scolipede.md
# Processing darmanitan-standard...
# Saved 0546_cottonee.md
# Processing maractus...
# Saved 0547_whimsicott.md
# Processing dwebble...
# Saved 0551_sandile.md
# Processing crustle...
# Saved 0548_petilil.md
# Processing scraggy...
# Saved 0549_lilligant.md
# Saved 0553_krookodile.md
# Processing scrafty...
# Processing sigilyph...
# Saved 0552_krokorok.md
# Saved 0554_darumaka.md
# Saved 0550_basculin-red-striped.md
# Processing yamask...
# Saved 0555_darmanitan-standard.md
# Processing cofagrigus...
# Processing tirtouga...
# Processing carracosta...
# Saved 0556_maractus.md
# Processing archen...
# Saved 0557_dwebble.md
# Processing archeops...
# Saved 0558_crustle.md
# Saved 0561_sigilyph.md
# Saved 0559_scraggy.md
# Processing trubbish...
# Processing garbodor...
# Saved 0562_yamask.md
# Processing zorua...
# Saved 0560_scrafty.md
# Processing zoroark...
# Processing minccino...
# Saved 0565_carracosta.md
# Processing cinccino...
# Saved 0563_cofagrigus.md
# Processing gothita...
# Saved 0566_archen.md
# Processing gothorita...
# Saved 0564_tirtouga.md
# Processing gothitelle...
# Saved 0568_trubbish.md
# Saved 0567_archeops.md
# Processing solosis...
# Processing duosion...
# Saved 0571_zoroark.md
# Processing reuniclus...
# Saved 0570_zorua.md
# Processing ducklett...
# Saved 0572_minccino.md
# Saved 0569_garbodor.md
# Processing swanna...
# Saved 0574_gothita.md
# Processing vanillite...
# Saved 0573_cinccino.md
# Processing vanillish...
# Processing vanilluxe...
# Saved 0576_gothitelle.md
# Saved 0575_gothorita.md
# Processing deerling...
# Processing sawsbuck...
# Saved 0578_duosion.md
# Saved 0577_solosis.md
# Processing emolga...
# Processing karrablast...
# Saved 0579_reuniclus.md
# Saved 0580_ducklett.md
# Processing escavalier...
# Processing foongus...
# Saved 0582_vanillite.md
# Processing amoonguss...
# Saved 0581_swanna.md
# Saved 0583_vanillish.md
# Processing frillish...
# Processing jellicent...
# Saved 0584_vanilluxe.md
# Processing alomomola...
# Saved 0586_sawsbuck.md
# Processing joltik...
# Saved 0585_deerling.md
# Saved 0588_karrablast.md
# Saved 0587_emolga.md
# Processing galvantula...
# Saved 0589_escavalier.md
# Processing ferroseed...
# Processing ferrothorn...
# Processing klink...
# Saved 0591_amoonguss.md
# Saved 0590_foongus.md
# Saved 0593_jellicent.md
# Processing klang...
# Processing klinklang...
# Processing tynamo...
# Saved 0594_alomomola.md
# Saved 0592_frillish.md
# Processing eelektrik...
# Processing eelektross...
# Saved 0595_joltik.md
# Processing elgyem...
# Saved 0599_klink.md
# Saved 0596_galvantula.md
# Processing beheeyem...
# Processing litwick...
# Saved 0598_ferrothorn.md
# Saved 0602_tynamo.md
# Processing lampent...
# Processing chandelure...
# Saved 0597_ferroseed.md
# Processing axew...
# Saved 0600_klang.md
# Saved 0604_eelektross.md
# Processing fraxure...
# Saved 0603_eelektrik.md
# Processing haxorus...
# Processing cubchoo...
# Saved 0601_klinklang.md
# Processing beartic...
# Saved 0605_elgyem.md
# Processing cryogonal...
# Saved 0606_beheeyem.md
# Processing shelmet...
# Saved 0609_chandelure.md
# Saved 0611_fraxure.md
# Processing accelgor...
# Processing stunfisk...
# Saved 0608_lampent.md
# Saved 0610_axew.md
# Saved 0607_litwick.md
# Processing mienfoo...
# Processing mienshao...
# Processing druddigon...
# Saved 0612_haxorus.md
# Processing golett...
# Saved 0613_cubchoo.md
# Processing golurk...
# Saved 0614_beartic.md
# Processing pawniard...
# Saved 0615_cryogonal.md
# Processing bisharp...
# Saved 0616_shelmet.md
# Processing bouffalant...
# Saved 0619_mienfoo.md
# Saved 0617_accelgor.md
# Saved 0620_mienshao.md
# Processing rufflet...
# Processing braviary...
# Processing vullaby...
# Saved 0621_druddigon.md
# Processing mandibuzz...
# Saved 0618_stunfisk.md
# Saved 0623_golurk.md
# Processing heatmor...
# Saved 0622_golett.md
# Processing durant...
# Processing deino...
# Saved 0624_pawniard.md
# Processing zweilous...
# Saved 0625_bisharp.md
# Processing hydreigon...
# Saved 0626_bouffalant.md
# Processing larvesta...
# Saved 0628_braviary.md
# Processing volcarona...
# Saved 0627_rufflet.md
# Processing cobalion...
# Saved 0631_heatmor.md
# Saved 0630_mandibuzz.md
# Processing terrakion...
# Processing virizion...
# Saved 0629_vullaby.md
# Processing tornadus-incarnate...
# Saved 0632_durant.md
# Processing thundurus-incarnate...
# Saved 0633_deino.md
# Processing reshiram...
# Saved 0634_zweilous.md
# Processing zekrom...
# Saved 0635_hydreigon.md
# Processing landorus-incarnate...
# Saved 0636_larvesta.md
# Processing kyurem...
# Saved 0638_cobalion.md
# Processing keldeo-ordinary...
# Saved 0640_virizion.md
# Processing meloetta-aria...
# Saved 0637_volcarona.md
# Saved 0639_terrakion.md
# Processing genesect...
# Processing chespin...
# Saved 0643_reshiram.md
# Processing quilladin...
# Saved 0641_tornadus-incarnate.md
# Processing chesnaught...
# Saved 0644_zekrom.md
# Processing fennekin...
# Saved 0642_thundurus-incarnate.md
# Processing braixen...
# Saved 0645_landorus-incarnate.md
# Processing delphox...
# Saved 0646_kyurem.md
# Processing froakie...
# Saved 0647_keldeo-ordinary.md
# Processing frogadier...
# Saved 0648_meloetta-aria.md
# Processing greninja...
# Saved 0651_quilladin.md
# Processing bunnelby...
# Saved 0649_genesect.md
# Processing diggersby...
# Saved 0650_chespin.md
# Processing fletchling...
# Saved 0652_chesnaught.md
# Processing fletchinder...
# Saved 0653_fennekin.md
# Processing talonflame...
# Saved 0654_braixen.md
# Saved 0655_delphox.md
# Saved 0656_froakie.md
# Processing scatterbug...
# Processing spewpa...
# Processing vivillon...
# Saved 0657_frogadier.md
# Processing litleo...
# Saved 0658_greninja.md
# Processing pyroar...
# Saved 0659_bunnelby.md
# Processing flabebe...
# Saved 0660_diggersby.md
# Processing floette...
# Saved 0663_talonflame.md
# Saved 0661_fletchling.md
# Saved 0662_fletchinder.md
# Processing florges...
# Processing skiddo...
# Processing gogoat...
# Saved 0665_spewpa.md
# Saved 0664_scatterbug.md
# Processing pancham...
# Processing pangoro...
# Saved 0666_vivillon.md
# Processing furfrou...
# Saved 0669_flabebe.md
# Processing espurr...
# Saved 0667_litleo.md
# Saved 0668_pyroar.md
# Processing meowstic-male...
# Processing honedge...
# Saved 0670_floette.md
# Saved 0673_gogoat.md
# Processing doublade...
# Processing aegislash-shield...
# Saved 0671_florges.md
# Processing spritzee...
# Saved 0672_skiddo.md
# Saved 0675_pangoro.md
# Processing aromatisse...
# Saved 0676_furfrou.md
# Saved 0674_pancham.md
# Processing swirlix...
# Processing slurpuff...
# Processing inkay...
# Saved 0677_espurr.md
# Processing malamar...
# Saved 0678_meowstic-male.md
# Processing binacle...
# Saved 0679_honedge.md
# Processing barbaracle...
# Saved 0682_spritzee.md
# Saved 0680_doublade.md
# Saved 0681_aegislash-shield.md
# Processing skrelp...
# Processing dragalge...
# Processing clauncher...
# Saved 0684_swirlix.md
# Processing clawitzer...
# Saved 0683_aromatisse.md
# Saved 0686_inkay.md
# Processing helioptile...
# Processing heliolisk...
# Saved 0685_slurpuff.md
# Saved 0687_malamar.md
# Processing tyrunt...
# Processing tyrantrum...
# Saved 0689_barbaracle.md
# Processing amaura...
# Saved 0692_clauncher.md
# Processing aurorus...
# Saved 0690_skrelp.md
# Saved 0688_binacle.md
# Processing sylveon...
# Processing hawlucha...
# Saved 0693_clawitzer.md
# Processing dedenne...
# Saved 0691_dragalge.md
# Processing carbink...
# Saved 0695_heliolisk.md
# Saved 0694_helioptile.md
# Processing goomy...
# Processing sliggoo...
# Saved 0697_tyrantrum.md
# Processing goodra...
# Saved 0696_tyrunt.md
# Processing klefki...
# Saved 0698_amaura.md
# Processing phantump...
# Saved 0699_aurorus.md
# Saved 0700_sylveon.md
# Processing trevenant...
# Processing pumpkaboo-average...
# Saved 0702_dedenne.md
# Processing gourgeist-average...
# Saved 0704_goomy.md
# Saved 0706_goodra.md
# Processing bergmite...
# Processing avalugg...
# Saved 0701_hawlucha.md
# Processing noibat...
# Saved 0703_carbink.md
# Processing noivern...
# Saved 0705_sliggoo.md
# Processing xerneas...
# Saved 0707_klefki.md
# Processing yveltal...
# Saved 0708_phantump.md
# Processing zygarde-50...
# Saved 0710_pumpkaboo-average.md
# Processing diancie...
# Saved 0709_trevenant.md
# Saved 0711_gourgeist-average.md
# Saved 0713_avalugg.md
# Processing hoopa...
# Processing volcanion...
# Processing rowlet...
# Saved 0712_bergmite.md
# Saved 0716_xerneas.md
# Saved 0715_noivern.md
# Saved 0714_noibat.md
# Processing dartrix...
# Processing decidueye...
# Processing litten...
# Processing torracat...
# Saved 0717_yveltal.md
# Processing incineroar...
# Saved 0718_zygarde-50.md
# Processing popplio...
# Saved 0720_hoopa.md
# Processing brionne...
# Saved 0719_diancie.md
# Processing primarina...
# Saved 0721_volcanion.md
# Processing pikipek...
# Saved 0722_rowlet.md
# Saved 0724_decidueye.md
# Saved 0723_dartrix.md
# Processing trumbeak...
# Processing toucannon...
# Processing yungoos...
# Saved 0725_litten.md
# Processing gumshoos...
# Saved 0726_torracat.md
# Processing grubbin...
# Saved 0727_incineroar.md
# Processing charjabug...
# Saved 0728_popplio.md
# Processing vikavolt...
# Saved 0729_brionne.md
# Processing crabrawler...
# Saved 0731_pikipek.md
# Saved 0730_primarina.md
# Processing crabominable...
# Processing oricorio-baile...
# Saved 0734_yungoos.md
# Processing cutiefly...
# Saved 0735_gumshoos.md
# Saved 0733_toucannon.md
# Processing ribombee...
# Processing rockruff...
# Saved 0732_trumbeak.md
# Saved 0736_grubbin.md
# Processing lycanroc-midday...
# Processing wishiwashi-solo...
# Saved 0738_vikavolt.md
# Processing mareanie...
# Saved 0739_crabrawler.md
# Processing toxapex...
# Saved 0740_crabominable.md
# Saved 0737_charjabug.md
# Processing mudbray...
# Saved 0741_oricorio-baile.md
# Processing mudsdale...
# Processing dewpider...
# Saved 0746_wishiwashi-solo.md
# Saved 0742_cutiefly.md
# Saved 0744_rockruff.md
# Saved 0743_ribombee.md
# Processing araquanid...
# Processing fomantis...
# Processing lurantis...
# Processing morelull...
# Saved 0745_lycanroc-midday.md
# Processing shiinotic...
# Saved 0747_mareanie.md
# Processing salandit...
# Saved 0748_toxapex.md
# Processing salazzle...
# Saved 0749_mudbray.md
# Saved 0750_mudsdale.md
# Processing stufful...
# Saved 0753_fomantis.md
# Processing bewear...
# Processing bounsweet...
# Saved 0751_dewpider.md
# Processing steenee...
# Saved 0755_morelull.md
# Saved 0752_araquanid.md
# Processing tsareena...
# Saved 0754_lurantis.md
# Processing comfey...
# Processing oranguru...
# Saved 0756_shiinotic.md
# Processing passimian...
# Saved 0757_salandit.md
# Saved 0758_salazzle.md
# Processing wimpod...
# Processing golisopod...
# Saved 0761_bounsweet.md
# Saved 0762_steenee.md
# Saved 0759_stufful.md
# Processing sandygast...
# Processing palossand...
# Processing pyukumuku...
# Saved 0760_bewear.md
# Processing type-null...
# Saved 0763_tsareena.md
# Saved 0766_passimian.md
# Processing silvally...
# Processing minior-red-meteor...
# Saved 0764_comfey.md
# Processing komala...
# Saved 0765_oranguru.md
# Processing turtonator...
# Saved 0767_wimpod.md
# Processing togedemaru...
# Saved 0768_golisopod.md
# Processing mimikyu-disguised...
# Saved 0772_type-null.md
# Processing bruxish...
# Saved 0771_pyukumuku.md
# Saved 0770_palossand.md
# Saved 0773_silvally.md
# Processing drampa...
# Saved 0774_minior-red-meteor.md
# Processing dhelmise...
# Processing jangmo-o...
# Processing hakamo-o...
# Saved 0769_sandygast.md
# Saved 0775_komala.md
# Processing kommo-o...
# Processing tapu-koko...
# Saved 0776_turtonator.md
# Processing tapu-lele...
# Saved 0777_togedemaru.md
# Processing tapu-bulu...
# Saved 0778_mimikyu-disguised.md
# Processing tapu-fini...
# Saved 0779_bruxish.md
# Processing cosmog...
# Saved 0785_tapu-koko.md
# Processing cosmoem...
# Saved 0784_kommo-o.md
# Saved 0780_drampa.md
# Processing solgaleo...
# Saved 0783_hakamo-o.md
# Processing lunala...
# Processing nihilego...
# Saved 0782_jangmo-o.md
# Processing buzzwole...
# Saved 0786_tapu-lele.md
# Processing pheromosa...
# Saved 0788_tapu-fini.md
# Saved 0789_cosmog.md
# Processing xurkitree...
# Processing celesteela...
# Saved 0787_tapu-bulu.md
# Processing kartana...
# Error processing dhelmise: API Error: Pokemon 'dhelmise' not found. (Count: 1)
# Saved 0790_cosmoem.md
# Processing guzzlord...
# Processing necrozma...
# Saved 0791_solgaleo.md
# Saved 0793_nihilego.md
# Processing magearna...
# Processing marshadow...
# Saved 0792_lunala.md
# Saved 0794_buzzwole.md
# Processing poipole...
# Processing naganadel...
# Saved 0795_pheromosa.md
# Processing stakataka...
# Saved 0798_kartana.md
# Saved 0796_xurkitree.md
# Processing blacephalon...
# Processing zeraora...
# Saved 0797_celesteela.md
# Processing meltan...
# Saved 0800_necrozma.md
# Saved 0799_guzzlord.md
# Processing melmetal...
# Processing grookey...
# Saved 0802_marshadow.md
# Processing thwackey...
# Saved 0801_magearna.md
# Processing rillaboom...
# Saved 0803_poipole.md
# Processing scorbunny...
# Saved 0804_naganadel.md
# Processing raboot...
# Saved 0805_stakataka.md
# Processing cinderace...
# Saved 0809_melmetal.md
# Processing sobble...
# Saved 0806_blacephalon.md
# Saved 0807_zeraora.md
# Processing drizzile...
# Processing inteleon...
# Saved 0810_grookey.md
# Saved 0808_meltan.md
# Processing skwovet...
# Processing greedent...
# Saved 0812_rillaboom.md
# Processing rookidee...
# Saved 0811_thwackey.md
# Processing corvisquire...
# Saved 0813_scorbunny.md
# Processing corviknight...
# Saved 0814_raboot.md
# Processing blipbug...
# Saved 0815_cinderace.md
# Processing dottler...
# Saved 0816_sobble.md
# Processing orbeetle...
# Saved 0821_rookidee.md
# Saved 0822_corvisquire.md
# Saved 0819_skwovet.md
# Processing nickit...
# Saved 0818_inteleon.md
# Saved 0817_drizzile.md
# Processing thievul...
# Processing gossifleur...
# Processing eldegoss...
# Processing wooloo...
# Saved 0820_greedent.md
# Processing dubwool...
# Saved 0824_blipbug.md
# Processing chewtle...
# Saved 0823_corviknight.md
# Processing drednaw...
# Saved 0825_dottler.md
# Processing yamper...
# Saved 0826_orbeetle.md
# Saved 0827_nickit.md
# Processing boltund...
# Processing rolycoly...
# Saved 0830_eldegoss.md
# Saved 0832_dubwool.md
# Processing carkol...
# Processing coalossal...
# Saved 0828_thievul.md
# Processing applin...
# Saved 0829_gossifleur.md
# Processing flapple...
# Saved 0831_wooloo.md
# Processing appletun...
# Saved 0833_chewtle.md
# Processing silicobra...
# Saved 0835_yamper.md
# Processing sandaconda...
# Saved 0834_drednaw.md
# Processing cramorant...
# Saved 0836_boltund.md
# Processing arrokuda...
# Saved 0837_rolycoly.md
# Processing barraskewda...
# Saved 0840_applin.md
# Saved 0841_flapple.md
# Processing toxel...
# Processing toxtricity-amped...
# Saved 0842_appletun.md
# Processing sizzlipede...
# Saved 0839_coalossal.md
# Saved 0838_carkol.md
# Processing centiskorch...
# Processing clobbopus...
# Saved 0843_silicobra.md
# Processing grapploct...
# Saved 0844_sandaconda.md
# Saved 0846_arrokuda.md
# Processing sinistea...
# Processing polteageist...
# Saved 0845_cramorant.md
# Processing hatenna...
# Saved 0847_barraskewda.md
# Processing hattrem...
# Saved 0852_clobbopus.md
# Saved 0849_toxtricity-amped.md
# Processing impidimp...
# Processing hatterene...
# Saved 0848_toxel.md
# Processing morgrem...
# Saved 0850_sizzlipede.md
# Processing grimmsnarl...
# Saved 0851_centiskorch.md
# Processing obstagoon...
# Saved 0853_grapploct.md
# Processing perrserker...
# Saved 0854_sinistea.md
# Saved 0855_polteageist.md
# Processing cursola...
# Saved 0857_hattrem.md
# Processing sirfetchd...
# Processing mr-rime...
# Saved 0856_hatenna.md
# Processing runerigus...
# Saved 0859_impidimp.md
# Saved 0862_obstagoon.md
# Saved 0858_hatterene.md
# Processing milcery...
# Processing alcremie...
# Processing falinks...
# Saved 0861_grimmsnarl.md
# Saved 0860_morgrem.md
# Processing pincurchin...
# Saved 0865_sirfetchd.md
# Processing snom...
# Processing frosmoth...
# Saved 0863_perrserker.md
# Processing stonjourner...
# Saved 0866_mr-rime.md
# Processing eiscue-ice...
# Saved 0864_cursola.md
# Saved 0867_runerigus.md
# Processing indeedee-male...
# Processing morpeko-full-belly...
# Saved 0869_alcremie.md
# Saved 0870_falinks.md
# Processing cufant...
# Processing copperajah...
# Saved 0868_milcery.md
# Saved 0872_snom.md
# Processing dracozolt...
# Processing arctozolt...
# Saved 0871_pincurchin.md
# Saved 0873_frosmoth.md
# Processing dracovish...
# Processing arctovish...
# Saved 0877_morpeko-full-belly.md
# Saved 0874_stonjourner.md
# Processing duraludon...
# Processing dreepy...
# Saved 0875_eiscue-ice.md
# Processing drakloak...
# Saved 0876_indeedee-male.md
# Processing dragapult...
# Saved 0878_cufant.md
# Processing zacian...
# Saved 0881_arctozolt.md
# Saved 0879_copperajah.md
# Processing zamazenta...
# Processing eternatus...
# Saved 0882_dracovish.md
# Saved 0880_dracozolt.md
# Processing kubfu...
# Processing urshifu-single-strike...
# Saved 0883_arctovish.md
# Processing zarude...
# Saved 0884_duraludon.md
# Processing regieleki...
# Saved 0885_dreepy.md
# Saved 0886_drakloak.md
# Processing regidrago...
# Processing glastrier...
# Saved 0887_dragapult.md
# Saved 0889_zamazenta.md
# Processing spectrier...
# Processing calyrex...
# Saved 0888_zacian.md
# Processing wyrdeer...
# Saved 0891_kubfu.md
# Saved 0890_eternatus.md
# Processing kleavor...
# Processing ursaluna...
# Saved 0894_regieleki.md
# Processing basculegion-male...
# Saved 0893_zarude.md
# Saved 0892_urshifu-single-strike.md
# Processing sneasler...
# Saved 0895_regidrago.md
# Processing overqwil...
# Processing enamorus-incarnate...
# Saved 0897_spectrier.md
# Processing sprigatito...
# Saved 0898_calyrex.md
# Processing floragato...
# Saved 0896_glastrier.md
# Processing meowscarada...
# Saved 0899_wyrdeer.md
# Saved 0900_kleavor.md
# Processing fuecoco...
# Processing crocalor...
# Saved 0901_ursaluna.md
# Processing skeledirge...
# Saved 0903_sneasler.md
# Saved 0905_enamorus-incarnate.md
# Processing quaxly...
# Processing quaxwell...
# Saved 0902_basculegion-male.md
# Processing quaquaval...
# Saved 0904_overqwil.md
# Processing lechonk...
# Saved 0907_floragato.md
# Processing oinkologne-male...
# Saved 0906_sprigatito.md
# Processing tarountula...
# Saved 0910_crocalor.md
# Saved 0908_meowscarada.md
# Processing spidops...
# Processing nymble...
# Saved 0909_fuecoco.md
# Saved 0913_quaxwell.md
# Processing lokix...
# Saved 0912_quaxly.md
# Processing pawmi...
# Saved 0911_skeledirge.md
# Processing pawmo...
# Processing pawmot...
# Saved 0914_quaquaval.md
# Saved 0915_lechonk.md
# Processing tandemaus...
# Processing maushold-family-of-four...
# Saved 0916_oinkologne-male.md
# Processing fidough...
# Saved 0917_tarountula.md
# Processing dachsbun...
# Saved 0919_nymble.md
# Processing smoliv...
# Saved 0918_spidops.md
# Saved 0920_lokix.md
# Processing dolliv...
# Processing arboliva...
# Saved 0922_pawmo.md
# Processing squawkabilly-green-plumage...
# Saved 0921_pawmi.md
# Saved 0923_pawmot.md
# Saved 0925_maushold-family-of-four.md
# Processing nacli...
# Processing naclstack...
# Processing garganacl...
# Saved 0924_tandemaus.md
# Processing charcadet...
# Saved 0926_fidough.md
# Saved 0927_dachsbun.md
# Processing armarouge...
# Processing ceruledge...
# Saved 0928_smoliv.md
# Processing tadbulb...
# Saved 0929_dolliv.md
# Processing bellibolt...
# Saved 0930_arboliva.md
# Processing wattrel...
# Saved 0932_nacli.md
# Saved 0931_squawkabilly-green-plumage.md
# Processing kilowattrel...
# Processing maschiff...
# Saved 0935_charcadet.md
# Processing mabosstiff...
# Saved 0933_naclstack.md
# Processing shroodle...
# Saved 0937_ceruledge.md
# Saved 0934_garganacl.md
# Processing grafaiai...
# Processing bramblin...
# Saved 0936_armarouge.md
# Processing brambleghast...
# Saved 0938_tadbulb.md
# Processing toedscool...
# Saved 0940_wattrel.md
# Saved 0942_maschiff.md
# Saved 0941_kilowattrel.md
# Saved 0939_bellibolt.md
# Processing toedscruel...
# Processing klawf...
# Processing capsakid...
# Processing scovillain...
# Saved 0943_mabosstiff.md
# Processing rellor...
# Saved 0946_bramblin.md
# Saved 0944_shroodle.md
# Processing rabsca...
# Saved 0947_brambleghast.md
# Saved 0945_grafaiai.md
# Processing flittle...
# Processing espathra...
# Processing tinkatink...
# Saved 0948_toedscool.md
# Processing tinkatuff...
# Saved 0951_capsakid.md
# Processing tinkaton...
# Saved 0949_toedscruel.md
# Processing wiglett...
# Saved 0950_klawf.md
# Saved 0953_rellor.md
# Processing wugtrio...
# Processing bombirdier...
# Saved 0952_scovillain.md
# Processing finizen...
# Saved 0956_espathra.md
# Saved 0954_rabsca.md
# Processing palafin-zero...
# Saved 0955_flittle.md
# Processing varoom...
# Processing revavroom...
# Saved 0958_tinkatuff.md
# Processing cyclizar...
# Saved 0957_tinkatink.md
# Processing orthworm...
# Saved 0959_tinkaton.md
# Saved 0960_wiglett.md
# Processing glimmet...
# Processing glimmora...
# Saved 0962_bombirdier.md
# Processing greavard...
# Saved 0961_wugtrio.md
# Processing houndstone...
# Saved 0966_revavroom.md
# Saved 0965_varoom.md
# Saved 0964_palafin-zero.md
# Processing flamigo...
# Saved 0963_finizen.md
# Processing cetoddle...
# Processing cetitan...
# Processing veluza...
# Saved 0967_cyclizar.md
# Saved 0968_orthworm.md
# Processing dondozo...
# Processing tatsugiri-curly...
# Saved 0969_glimmet.md
# Processing annihilape...
# Saved 0970_glimmora.md
# Processing clodsire...
# Saved 0971_greavard.md
# Processing farigiraf...
# Saved 0972_houndstone.md
# Processing dudunsparce-two-segment...
# Saved 0975_cetitan.md
# Saved 0973_flamigo.md
# Saved 0974_cetoddle.md
# Processing kingambit...
# Saved 0976_veluza.md
# Processing great-tusk...
# Processing scream-tail...
# Processing brute-bonnet...
# Saved 0978_tatsugiri-curly.md
# Processing flutter-mane...
# Saved 0980_clodsire.md
# Saved 0977_dondozo.md
# Processing slither-wing...
# Processing sandy-shocks...
# Saved 0979_annihilape.mdSaved 0982_dudunsparce-two-segment.md
#
# Processing iron-treads...
# Processing iron-bundle...
# Saved 0984_great-tusk.md
# Processing iron-hands...
# Saved 0986_brute-bonnet.md
# Saved 0981_farigiraf.md
# Saved 0985_scream-tail.md
# Saved 0983_kingambit.md
# Processing iron-jugulis...
# Processing iron-moth...
# Processing iron-thorns...
# Processing frigibax...
# Saved 0987_flutter-mane.md
# Processing arctibax...
# Saved 0989_sandy-shocks.md
# Processing baxcalibur...
# Saved 0990_iron-treads.md
# Saved 0991_iron-bundle.md
# Processing gimmighoul...
# Saved 0988_slither-wing.md
# Processing gholdengo...
# Processing wo-chien...
# Saved 0992_iron-hands.md
# Processing chien-pao...
# Saved 0996_frigibax.md
# Processing ting-lu...
# Saved 0994_iron-moth.md
# Saved 0995_iron-thorns.md
# Saved 0993_iron-jugulis.md
# Processing chi-yu...
# Processing roaring-moon...
# Processing iron-valiant...
# Saved 0997_arctibax.md
# Processing koraidon...
# Saved 0999_gimmighoul.md
# Processing miraidon...
# Saved 0998_baxcalibur.md
# Processing walking-wake...
# Saved 1004_chi-yu.md
# Saved 1005_roaring-moon.md
# Saved 1000_gholdengo.md
# Processing iron-leaves...
# Processing dipplin...
# Processing poltchageist...
# Saved 1002_chien-pao.md
# Processing sinistcha...
# Saved 1006_iron-valiant.md
# Saved 1003_ting-lu.md
# Processing okidogi...
# Processing munkidori...
# Saved 1001_wo-chien.md
# Processing fezandipiti...
# Saved 1007_koraidon.md
# Processing ogerpon...
# Saved 1010_iron-leaves.md
# Saved 1013_sinistcha.md
# Processing archaludon...
# Processing hydrapple...
# Saved 1009_walking-wake.md
# Saved 1011_dipplin.md
# Saved 1008_miraidon.md
# Processing gouging-fire...
# Processing raging-bolt...
# Processing iron-boulder...
# Saved 1014_okidogi.md
# Processing iron-crown...
# Saved 1012_poltchageist.md
# Processing terapagos...
# Saved 1016_fezandipiti.md
# Processing pecharunt...
# Saved 1015_munkidori.md
# Processing deoxys-attack...
# Saved 1017_ogerpon.md
# Processing deoxys-defense...
# Saved 1019_hydrapple.md
# Saved 1021_raging-bolt.md
# Saved 1020_gouging-fire.md
# Saved 1018_archaludon.md
# Processing deoxys-speed...
# Processing wormadam-sandy...
# Processing wormadam-trash...
# Saved 1022_iron-boulder.md
# Saved 1023_iron-crown.md
# Processing shaymin-sky...
# Processing giratina-origin...
# Processing rotom-heat...
# Saved 1024_terapagos.md
# Processing rotom-wash...
# Saved 1025_pecharunt.md
# Processing rotom-frost...
# Saved 10001_deoxys-attack.md
# Processing rotom-fan...
# Saved 10002_deoxys-defense.md
# Processing rotom-mow...
# Saved 10005_wormadam-trash.md
# Processing castform-sunny...
# Saved 10003_deoxys-speed.md
# Saved 10006_shaymin-sky.md
# Processing castform-rainy...
# Processing castform-snowy...
# Saved 10004_wormadam-sandy.md
# Saved 10008_rotom-heat.md
# Processing basculin-blue-striped...
# Processing darmanitan-zen...
# Saved 10007_giratina-origin.md
# Saved 10009_rotom-wash.md
# Processing meloetta-pirouette...
# Processing tornadus-therian...
# Saved 10010_rotom-frost.md
# Saved 10012_rotom-mow.md
# Processing thundurus-therian...
# Saved 10011_rotom-fan.md
# Processing landorus-therian...
# Processing kyurem-black...
# Saved 10014_castform-rainy.md
# Saved 10013_castform-sunny.md
# Saved 10015_castform-snowy.md
# Processing kyurem-white...Processing keldeo-resolute...
#
# Processing meowstic-female...
# Saved 10017_darmanitan-zen.md
# Saved 10016_basculin-blue-striped.md
# Processing aegislash-blade...
# Saved 10019_tornadus-therian.md
# Processing pumpkaboo-small...
# Processing pumpkaboo-large...
# Saved 10018_meloetta-pirouette.md
# Processing pumpkaboo-super...
# Saved 10020_thundurus-therian.md
# Processing gourgeist-small...
# Saved 10021_landorus-therian.md
# Processing gourgeist-large...
# Saved 10022_kyurem-black.md
# Processing gourgeist-super...
# Saved 10024_keldeo-resolute.md
# Processing venusaur-mega...
# Saved 10025_meowstic-female.md
# Processing charizard-mega-x...
# Saved 10023_kyurem-white.md
# Processing charizard-mega-y...
# Saved 10026_aegislash-blade.md
# Saved 10027_pumpkaboo-small.md
# Processing blastoise-mega...
# Processing alakazam-mega...
# Saved 10029_pumpkaboo-super.md
# Saved 10028_pumpkaboo-large.md
# Processing gengar-mega...
# Processing kangaskhan-mega...
# Saved 10031_gourgeist-large.md
# Saved 10033_venusaur-mega.md
# Saved 10030_gourgeist-small.md
# Processing pinsir-mega...
# Saved 10032_gourgeist-super.md
# Processing gyarados-mega...
# Processing aerodactyl-mega...
# Processing mewtwo-mega-x...
# Saved 10037_alakazam-mega.md
# Saved 10035_charizard-mega-y.md
# Processing mewtwo-mega-y...
# Saved 10036_blastoise-mega.md
# Processing ampharos-mega...
# Processing scizor-mega...
# Saved 10038_gengar-mega.md
# Processing heracross-mega...
# Saved 10039_kangaskhan-mega.md
# Processing houndoom-mega...
# Saved 10034_charizard-mega-x.md
# Processing tyranitar-mega...
# Saved 10040_pinsir-mega.md
# Processing blaziken-mega...
# Saved 10043_mewtwo-mega-x.md
# Processing gardevoir-mega...
# Saved 10041_gyarados-mega.md
# Processing mawile-mega...
# Saved 10044_mewtwo-mega-y.md
# Saved 10045_ampharos-mega.md
# Processing aggron-mega...
# Processing medicham-mega...
# Saved 10042_aerodactyl-mega.md
# Processing manectric-mega...
# Saved 10046_scizor-mega.md
# Processing banette-mega...
# Saved 10047_heracross-mega.md
# Processing absol-mega...
# Saved 10048_houndoom-mega.md
# Processing garchomp-mega...
# Saved 10049_tyranitar-mega.md
# Saved 10053_aggron-mega.md
# Processing lucario-mega...
# Saved 10050_blaziken-mega.md
# Processing abomasnow-mega...
# Processing floette-eternal...
# Saved 10054_medicham-mega.md
# Saved 10051_gardevoir-mega.md
# Processing latias-mega...
# Processing latios-mega...
# Saved 10055_manectric-mega.md
# Processing swampert-mega...
# Saved 10056_banette-mega.md
# Processing sceptile-mega...
# Saved 10052_mawile-mega.md
# Processing sableye-mega...
# Saved 10058_garchomp-mega.md
# Processing altaria-mega...
# Saved 10057_absol-mega.md
# Processing gallade-mega...
# Saved 10060_abomasnow-mega.md
# Processing audino-mega...
# Saved 10063_latios-mega.md
# Processing sharpedo-mega...
# Saved 10062_latias-mega.md
# Saved 10061_floette-eternal.md
# Processing slowbro-mega...
# Processing steelix-mega...
# Saved 10059_lucario-mega.md
# Saved 10064_swampert-mega.md
# Processing pidgeot-mega...
# Processing glalie-mega...
# Saved 10065_sceptile-mega.md
# Processing diancie-mega...
# Saved 10066_sableye-mega.md
# Processing metagross-mega...
# Saved 10067_altaria-mega.md
# Saved 10068_gallade-mega.md
# Processing kyogre-primal...
# Processing groudon-primal...
# Saved 10070_sharpedo-mega.md
# Processing rayquaza-mega...
# Saved 10069_audino-mega.md
# Saved 10072_steelix-mega.md
# Processing pikachu-rock-star...
# Processing pikachu-belle...
# Saved 10071_slowbro-mega.md
# Processing pikachu-pop-star...
# Saved 10073_pidgeot-mega.md
# Processing pikachu-phd...
# Saved 10074_glalie-mega.md
# Processing pikachu-libre...
# Saved 10075_diancie-mega.md
# Processing pikachu-cosplay...
# Saved 10076_metagross-mega.md
# Processing hoopa-unbound...
# Saved 10078_groudon-primal.md
# Saved 10077_kyogre-primal.md
# Processing camerupt-mega...
# Processing lopunny-mega...
# Saved 10079_rayquaza-mega.md
# Saved 10082_pikachu-pop-star.md
# Processing salamence-mega...
# Saved 10080_pikachu-rock-star.md
# Processing beedrill-mega...
# Processing rattata-alola...
# Saved 10081_pikachu-belle.md
# Saved 10083_pikachu-phd.md
# Processing raticate-alola...
# Saved 10084_pikachu-libre.md
# Processing raticate-totem-alola...
# Processing pikachu-original-cap...
# Saved 10085_pikachu-cosplay.md
# Saved 10086_hoopa-unbound.md
# Processing pikachu-hoenn-cap...
# Processing pikachu-sinnoh-cap...
# Saved 10087_camerupt-mega.md
# Processing pikachu-unova-cap...
# Saved 10089_salamence-mega.mdSaved 10090_beedrill-mega.md
#
# Processing pikachu-alola-cap...Processing pikachu-kalos-cap...
#
# Saved 10088_lopunny-mega.md
# Saved 10093_raticate-totem-alola.md
# Processing raichu-alola...
# Saved 10091_rattata-alola.md
# Processing sandshrew-alola...
# Processing sandslash-alola...
# Saved 10092_raticate-alola.md
# Processing vulpix-alola...
# Saved 10094_pikachu-original-cap.md
# Processing ninetales-alola...
# Saved 10095_pikachu-hoenn-cap.md
# Processing diglett-alola...
# Saved 10096_pikachu-sinnoh-cap.md
# Processing dugtrio-alola...
# Saved 10098_pikachu-kalos-cap.md
# Processing meowth-alola...
# Saved 10097_pikachu-unova-cap.md
# Processing persian-alola...
# Saved 10099_pikachu-alola-cap.md
# Processing geodude-alola...
# Saved 10100_raichu-alola.md
# Processing graveler-alola...
# Saved 10102_sandslash-alola.md
# Saved 10103_vulpix-alola.md
# Processing golem-alola...
# Processing grimer-alola...
# Saved 10101_sandshrew-alola.md
# Processing muk-alola...
# Saved 10104_ninetales-alola.md
# Saved 10105_diglett-alola.md
# Processing exeggutor-alola...
# Processing marowak-alola...
# Saved 10106_dugtrio-alola.md
# Processing greninja-battle-bond...
# Saved 10107_meowth-alola.md
# Processing greninja-ash...
# Saved 10108_persian-alola.md
# Saved 10109_geodude-alola.md
# Processing zygarde-10-power-construct...
# Processing zygarde-50-power-construct...
# Saved 10110_graveler-alola.md
# Processing zygarde-complete...
# Saved 10112_grimer-alola.md
# Saved 10111_golem-alola.md
# Processing gumshoos-totem...
# Processing vikavolt-totem...
# Saved 10114_exeggutor-alola.md
# Processing oricorio-pom-pom...
# Saved 10115_marowak-alola.md
# Saved 10113_muk-alola.md
# Processing oricorio-pau...
# Processing oricorio-sensu...
# Saved 10116_greninja-battle-bond.md
# Saved 10117_greninja-ash.md
# Processing lycanroc-midnight...
# Processing wishiwashi-school...
# Saved 10118_zygarde-10-power-construct.md
# Processing lurantis-totem...
# Saved 10119_zygarde-50-power-construct.md
# Processing salazzle-totem...
# Saved 10122_vikavolt-totem.md
# Processing minior-orange-meteor...
# Saved 10121_gumshoos-totem.md
# Processing minior-yellow-meteor...
# Saved 10120_zygarde-complete.md
# Processing minior-green-meteor...
# Saved 10124_oricorio-pau.md
# Processing minior-blue-meteor...
# Saved 10123_oricorio-pom-pom.md
# Processing minior-indigo-meteor...
# Saved 10125_oricorio-sensu.md
# Processing minior-violet-meteor...
# Saved 10126_lycanroc-midnight.md
# Processing minior-red...
# Saved 10127_wishiwashi-school.md
# Processing minior-orange...
# Saved 10129_salazzle-totem.md
# Processing minior-yellow...
# Saved 10128_lurantis-totem.md
# Saved 10131_minior-yellow-meteor.md
# Processing minior-green...
# Saved 10130_minior-orange-meteor.md
# Processing minior-blue...
# Processing minior-indigo...
# Saved 10132_minior-green-meteor.md
# Processing minior-violet...
# Saved 10133_minior-blue-meteor.md
# Processing mimikyu-busted...
# Saved 10134_minior-indigo-meteor.md
# Processing mimikyu-totem-disguised...
# Saved 10136_minior-red.md
# Processing mimikyu-totem-busted...
# Saved 10135_minior-violet-meteor.md
# Processing kommo-o-totem...
# Saved 10137_minior-orange.md
# Processing magearna-original...
# Saved 10139_minior-green.md
# Saved 10138_minior-yellow.md
# Processing pikachu-partner-cap...
# Processing marowak-totem...
# Saved 10141_minior-indigo.md
# Processing ribombee-totem...
# Saved 10142_minior-violet.md
# Processing rockruff-own-tempo...
# Saved 10140_minior-blue.md
# Processing lycanroc-dusk...
# Saved 10143_mimikyu-busted.md
# Processing araquanid-totem...
# Saved 10144_mimikyu-totem-disguised.md
# Processing togedemaru-totem...
# Saved 10145_mimikyu-totem-busted.md
# Saved 10146_kommo-o-totem.md
# Processing necrozma-dusk...
# Processing necrozma-dawn...
# Saved 10148_pikachu-partner-cap.md
# Processing necrozma-ultra...
# Saved 10149_marowak-totem.md
# Processing pikachu-starter...
# Saved 10152_lycanroc-dusk.md
# Saved 10151_rockruff-own-tempo.md
# Saved 10150_ribombee-totem.md
# Processing eevee-starter...
# Processing pikachu-world-cap...
# Processing meowth-galar...
# Saved 10147_magearna-original.md
# Processing ponyta-galar...
# Saved 10154_togedemaru-totem.md
# Processing rapidash-galar...
# Saved 10153_araquanid-totem.md
# Processing slowpoke-galar...
# Saved 10156_necrozma-dawn.md
# Processing slowbro-galar...
# Saved 10157_necrozma-ultra.md
# Saved 10155_necrozma-dusk.md
# Processing farfetchd-galar...
# Processing weezing-galar...
# Saved 10158_pikachu-starter.md
# Processing mr-mime-galar...
# Saved 10159_eevee-starter.md
# Processing articuno-galar...
# Saved 10162_ponyta-galar.md
# Processing zapdos-galar...
# Saved 10160_pikachu-world-cap.md
# Saved 10161_meowth-galar.md
# Processing moltres-galar...
# Processing slowking-galar...
# Saved 10164_slowpoke-galar.md
# Saved 10165_slowbro-galar.md
# Processing corsola-galar...
# Processing zigzagoon-galar...
# Saved 10166_farfetchd-galar.md
# Processing linoone-galar...
# Saved 10167_weezing-galar.md
# Saved 10163_rapidash-galar.md
# Processing darumaka-galar...
# Processing darmanitan-galar-standard...
# Saved 10170_zapdos-galar.md
# Processing darmanitan-galar-zen...
# Saved 10168_mr-mime-galar.md
# Saved 10172_slowking-galar.md
# Processing yamask-galar...
# Processing stunfisk-galar...
# Saved 10171_moltres-galar.md
# Processing zygarde-10...
# Saved 10169_articuno-galar.md
# Processing cramorant-gulping...
# Saved 10173_corsola-galar.md
# Processing cramorant-gorging...
# Saved 10175_linoone-galar.md
# Saved 10177_darmanitan-galar-standard.md
# Processing toxtricity-low-key...
# Processing eiscue-noice...
# Saved 10174_zigzagoon-galar.md
# Processing indeedee-female...
# Saved 10176_darumaka-galar.md
# Processing morpeko-hangry...
# Saved 10178_darmanitan-galar-zen.md
# Processing zacian-crowned...
# Saved 10179_yamask-galar.md
# Processing zamazenta-crowned...
# Saved 10180_stunfisk-galar.md
# Saved 10182_cramorant-gulping.md
# Processing eternatus-eternamax...
# Saved 10181_zygarde-10.md
# Processing urshifu-rapid-strike...
# Processing zarude-dada...
# Saved 10185_eiscue-noice.md
# Processing calyrex-ice...
# Saved 10183_cramorant-gorging.md
# Processing calyrex-shadow...
# Saved 10184_toxtricity-low-key.md
# Processing venusaur-gmax...
# Saved 10187_morpeko-hangry.md
# Processing charizard-gmax...
# Saved 10186_indeedee-female.md
# Processing blastoise-gmax...
# Saved 10189_zamazenta-crowned.md
# Saved 10188_zacian-crowned.md
# Processing butterfree-gmax...
# Processing pikachu-gmax...
# Saved 10191_urshifu-rapid-strike.md
# Processing meowth-gmax...
# Saved 10192_zarude-dada.md
# Saved 10190_eternatus-eternamax.md
# Processing machamp-gmax...
# Processing gengar-gmax...
# Saved 10194_calyrex-shadow.md
# Processing kingler-gmax...
# Saved 10193_calyrex-ice.md
# Processing lapras-gmax...
# Saved 10195_venusaur-gmax.md
# Saved 10196_charizard-gmax.md
# Processing eevee-gmax...
# Processing snorlax-gmax...
# Saved 10199_pikachu-gmax.md
# Processing garbodor-gmax...
# Saved 10197_blastoise-gmax.md
# Processing melmetal-gmax...
# Saved 10198_butterfree-gmax.md
# Processing rillaboom-gmax...
# Saved 10201_machamp-gmax.md
# Saved 10200_meowth-gmax.md
# Processing cinderace-gmax...
# Processing inteleon-gmax...
# Saved 10202_gengar-gmax.md
# Processing corviknight-gmax...
# Saved 10203_kingler-gmax.md
# Processing orbeetle-gmax...
# Saved 10204_lapras-gmax.md
# Processing drednaw-gmax...
# Saved 10205_eevee-gmax.md
# Processing coalossal-gmax...
# Saved 10206_snorlax-gmax.md
# Processing flapple-gmax...
# Saved 10207_garbodor-gmax.md
# Processing appletun-gmax...
# Saved 10208_melmetal-gmax.md
# Processing sandaconda-gmax...
# Saved 10209_rillaboom-gmax.md
# Processing toxtricity-amped-gmax...
# Saved 10210_cinderace-gmax.md
# Processing centiskorch-gmax...
# Saved 10211_inteleon-gmax.md
# Processing hatterene-gmax...
# Saved 10212_corviknight-gmax.md
# Saved 10213_orbeetle-gmax.md
# Processing grimmsnarl-gmax...
# Processing alcremie-gmax...
# Saved 10214_drednaw-gmax.md
# Processing copperajah-gmax...
# Saved 10215_coalossal-gmax.md
# Processing duraludon-gmax...
# Saved 10217_appletun-gmax.md
# Processing urshifu-single-strike-gmax...
# Saved 10216_flapple-gmax.md
# Processing urshifu-rapid-strike-gmax...
# Saved 10218_sandaconda-gmax.md
# Saved 10219_toxtricity-amped-gmax.md
# Processing toxtricity-low-key-gmax...
# Processing growlithe-hisui...
# Saved 10220_centiskorch-gmax.md
# Processing arcanine-hisui...
# Saved 10221_hatterene-gmax.md
# Saved 10223_alcremie-gmax.md
# Processing voltorb-hisui...
# Processing electrode-hisui...
# Saved 10224_copperajah-gmax.md
# Saved 10222_grimmsnarl-gmax.md
# Processing typhlosion-hisui...
# Processing qwilfish-hisui...
# Saved 10225_duraludon-gmax.md
# Saved 10227_urshifu-rapid-strike-gmax.md
# Processing sneasel-hisui...
# Saved 10226_urshifu-single-strike-gmax.md
# Processing samurott-hisui...
# Processing lilligant-hisui...
# Saved 10228_toxtricity-low-key-gmax.md
# Processing zorua-hisui...
# Saved 10229_growlithe-hisui.md
# Processing zoroark-hisui...
# Saved 10230_arcanine-hisui.md
# Processing braviary-hisui...
# Saved 10231_voltorb-hisui.md
# Saved 10232_electrode-hisui.md
# Processing sliggoo-hisui...
# Processing goodra-hisui...
# Saved 10234_qwilfish-hisui.md
# Processing avalugg-hisui...
# Saved 10233_typhlosion-hisui.md
# Processing decidueye-hisui...
# Saved 10237_lilligant-hisui.md
# Saved 10236_samurott-hisui.md
# Processing dialga-origin...
# Processing palkia-origin...
# Saved 10235_sneasel-hisui.md
# Saved 10238_zorua-hisui.md
# Processing basculin-white-striped...Processing basculegion-female...
#
# Saved 10240_braviary-hisui.md
# Saved 10239_zoroark-hisui.md
# Processing enamorus-therian...
# Processing tauros-paldea-combat-breed...
# Saved 10241_sliggoo-hisui.md
# Processing tauros-paldea-blaze-breed...
# Saved 10242_goodra-hisui.md
# Saved 10243_avalugg-hisui.md
# Saved 10244_decidueye-hisui.md
# Processing tauros-paldea-aqua-breed...
# Processing wooper-paldea...
# Processing oinkologne-female...
# Saved 10246_palkia-origin.md
# Processing dudunsparce-three-segment...
# Saved 10245_dialga-origin.md
# Processing palafin-hero...
# Saved 10247_basculin-white-striped.md
# Processing maushold-family-of-three...
# Saved 10248_basculegion-female.md
# Processing tatsugiri-droopy...
# Saved 10250_tauros-paldea-combat-breed.md
# Processing tatsugiri-stretchy...
# Saved 10249_enamorus-therian.md
# Saved 10251_tauros-paldea-blaze-breed.md
# Processing squawkabilly-blue-plumage...
# Saved 10252_tauros-paldea-aqua-breed.md
# Saved 10254_oinkologne-female.md
# Processing squawkabilly-yellow-plumage...
# Processing squawkabilly-white-plumage...
# Processing gimmighoul-roaming...
# Saved 10253_wooper-paldea.md
# Processing koraidon-limited-build...
# Saved 10256_palafin-hero.md
# Processing koraidon-sprinting-build...
# Saved 10255_dudunsparce-three-segment.md
# Processing koraidon-swimming-build...
# Saved 10257_maushold-family-of-three.md
# Processing koraidon-gliding-build...
# Saved 10260_squawkabilly-blue-plumage.md
# Saved 10259_tatsugiri-stretchy.md
# Processing miraidon-low-power-mode...
# Processing miraidon-drive-mode...
# Saved 10261_squawkabilly-yellow-plumage.md
# Processing miraidon-aquatic-mode...
# Saved 10258_tatsugiri-droopy.md
# Saved 10264_koraidon-limited-build.md
# Processing miraidon-glide-mode...
# Processing ursaluna-bloodmoon...
# Saved 10263_gimmighoul-roaming.md
# Processing ogerpon-wellspring-mask...
# Saved 10265_koraidon-sprinting-build.md
# Saved 10262_squawkabilly-white-plumage.md
# Saved 10266_koraidon-swimming-build.md
# Processing ogerpon-hearthflame-mask...
# Processing ogerpon-cornerstone-mask...
# Processing terapagos-terastal...
# Saved 10267_koraidon-gliding-build.md
# Processing terapagos-stellar...
# Saved 10269_miraidon-drive-mode.md
# Saved 10268_miraidon-low-power-mode.md
# Processing clefable-mega...
# Processing victreebel-mega...
# Saved 10270_miraidon-aquatic-mode.md
# Processing starmie-mega...
# Saved 10272_ursaluna-bloodmoon.md
# Processing dragonite-mega...
# Saved 10276_terapagos-terastal.md
# Saved 10271_miraidon-glide-mode.md
# Processing meganium-mega...Processing feraligatr-mega...
#
# Saved 10273_ogerpon-wellspring-mask.md
# Processing skarmory-mega...
# Saved 10274_ogerpon-hearthflame-mask.md
# Processing froslass-mega...
# Saved 10275_ogerpon-cornerstone-mask.md
# Processing emboar-mega...
# Saved 10277_terapagos-stellar.md
# Processing excadrill-mega...
# Saved 10278_clefable-mega.md
# Processing scolipede-mega...
# Saved 10279_victreebel-mega.md
# Saved 10280_starmie-mega.md
# Processing scrafty-mega...
# Processing eelektross-mega...
# Saved 10284_skarmory-mega.md
# Processing chandelure-mega...
# Saved 10283_feraligatr-mega.md
# Saved 10286_emboar-mega.md
# Saved 10281_dragonite-mega.md
# Processing chesnaught-mega...
# Processing delphox-mega...
# Saved 10285_froslass-mega.md
# Processing greninja-mega...
# Processing pyroar-mega...
# Saved 10282_meganium-mega.md
# Processing floette-mega...
# Saved 10287_excadrill-mega.md
# Processing malamar-mega...
# Saved 10289_scrafty-mega.md
# Saved 10290_eelektross-mega.md
# Processing barbaracle-mega...
# Processing dragalge-mega...
# Saved 10288_scolipede-mega.md
# Processing hawlucha-mega...
# Saved 10291_chandelure-mega.md
# Processing zygarde-mega...
# Saved 10292_chesnaught-mega.md
# Processing drampa-mega...
# Saved 10293_delphox-mega.md
# Saved 10296_floette-mega.md
# Processing falinks-mega...Saved 10294_greninja-mega.md
#
# Processing raichu-mega-x...
# Processing raichu-mega-y...
# Saved 10295_pyroar-mega.md
# Processing chimecho-mega...
# Saved 10297_malamar-mega.md
# Processing absol-mega-z...
# Saved 10299_dragalge-mega.md
# Processing staraptor-mega...
# Saved 10301_zygarde-mega.md
# Saved 10300_hawlucha-mega.md
# Saved 10298_barbaracle-mega.md
# Processing lucario-mega-z...
# Processing garchomp-mega-z...
# Processing heatran-mega...
# Saved 10302_drampa-mega.md
# Processing darkrai-mega...
# Saved 10304_raichu-mega-x.md
# Processing golurk-mega...
# Saved 10305_raichu-mega-y.md
# Processing meowstic-mega...
# Saved 10303_falinks-mega.md
# Processing crabominable-mega...
# Saved 10306_chimecho-mega.md
# Processing golisopod-mega...
# Saved 10308_staraptor-mega.md
# Processing magearna-mega...
# Saved 10309_garchomp-mega-z.md
# Processing magearna-original-mega...
# Saved 10307_absol-mega-z.md
# Saved 10311_heatran-mega.md
# Processing zeraora-mega...
# Saved 10310_lucario-mega-z.md
# Processing scovillain-mega...
# Processing glimmora-mega...
# Saved 10313_golurk-mega.mdSaved 10312_darkrai-mega.md
#
# Processing tatsugiri-droopy-mega...Processing tatsugiri-curly-mega...
#
# Saved 10314_meowstic-mega.md
# Processing tatsugiri-stretchy-mega...
# Saved 10315_crabominable-mega.md
# Processing baxcalibur-mega...
# Saved 10316_golisopod-mega.md
# Saved 10319_zeraora-mega.md
# Saved 10320_scovillain-mega.md
# Saved 10318_magearna-original-mega.md
# Saved 10317_magearna-mega.md
# Saved 10323_tatsugiri-droopy-mega.md
# Saved 10322_tatsugiri-curly-mega.md
# Saved 10324_tatsugiri-stretchy-mega.md
# Saved 10325_baxcalibur-mega.md
# Saved 10321_glimmora-mega.md
# Generation complete.

# %%
llm_client.chat_history
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 llm_client.chat_history
#
# NameError: name 'llm_client' is not defined
