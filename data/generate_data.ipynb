# %%
# imports
import os
import json
import time
import concurrent.futures
from pathlib import Path
import threading
import requests

import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from ai_tools.tools import LLMQuery
from pokemon_tools import PokemonAPIClient

# %%
SYSTEM_PROMPT = """You are an expert Pokémon Data Analyst and Lorekeeper. Your task is to process raw JSON data into a **semantically dense, natural language profile** optimized for Vector Search retrieval (RAG).

### Core Instruction:
Use the provided JSON as the **primary source** for facts (Stats, Moves, Evolution), but use your **World Knowledge** to expand on behavior, competitive viability, and lore. The goal is to maximize the number of relevant searchable keywords (moves, abilities, behaviors) in the output.

### STRICT Output Constraints:
1.  **NO Conversational Filler:** Start immediately with the Markdown headers. Do not say "Here is the profile."
2.  **Naturalize the ID:** Include the Pokémon's ID (e.g., #006) naturally in the first sentence of the Identity section.
3.  **Omit Empty Data:** If a field is empty (e.g., `held_items` or `forms`), skip it entirely.
4.  **Format:** Use Markdown headers (`##`) for sections.

### Processing Guidelines:

**1. Identity & Lore (Expand this)**
* **Variant Detection:** Check the `name` field. If it contains suffixes like `-alola`, `-galar`, `-hisui`, or `-paldea`, explicitly name it as the **[Region]n Form** (e.g., convert `vulpix-alola` to "Alolan Vulpix").
* **Bio Synthesis:** Combine `genus`, `flavor_text`, `habitat`, `generation`, and `color` into a cohesive summary.
* **Form Potential (World Knowledge):** Explicitly mention if this Pokémon has **Mega Evolutions**, **Gigantamax forms**, or **Paradox forms**, even if they are not listed in the JSON.
* **Context:** Mention the specific region associated with the generation (e.g., "Generation I (Kanto)").

**2. Combat Profile (Detailed Analysis)**
* **Stat Block:** You **MUST** list the specific Base Stats in a list format using these standard abbreviations: **HP, Attack, Defense, Sp. Atk, Sp. Def, Speed**.
* **Archetype:** Analyze the stats to assign a competitive role (e.g., "Fast Special Sweeper," "Physical Tank," "Mixed Attacker").
* **Type Matchups:**
    * Explicitly list **Weaknesses** and **Resistances**.
    * **Logic Check:** If a Pokémon has a double weakness (e.g., Fire/Flying vs. Rock), explicitly label it as a **"Double Weakness (4x)."**
* **Smart Move Selection:** Select 4 specific moves that align with the Pokémon's **highest offensive stat**. (e.g., If Sp. Atk > Attack, list *Flamethrower*, not *Fire Punch*). Include Utility moves (Recover, Roost) if relevant.
* **Abilities:** Name the abilities and briefly explain their tactical effect.

**3. Evolution & Acquisition**
* **Detailed Chain:** Narrate the full evolutionary line.
* **Triggers:** You must specify the **method** found in `evolution_details` (e.g., "when exposed to a Thunder Stone," "leveled up with High Friendship," "at Level 36").
* **Breeding:** Mention Egg Groups and Hatch Counters if relevant.

---

### Required Output Structure:

**## Identity & Lore**
[Name] (Pokedex #[ID]) is the [Genus]... [Detailed Description of appearance, habitat, and lore]... [Mention of Mega/G-Max forms if applicable]...

**## Combat Profile**
* **Stats:** HP [Val], Attack [Val], Defense [Val], Sp. Atk [Val], Sp. Def [Val], Speed [Val].
* **Archetype:** [Role Name] (e.g., Fast Special Sweeper).
* **Type Matchups:** It is **weak to [Types]** (mentioning any 4x weaknesses) and **resists [Types]**.
* **Move Selection:** Capitalizing on its stats, key moves include **[Move 1], [Move 2], [Move 3], and [Move 4]**.
* **Abilities:** [Ability Name] ([Effect description])...

**## Evolution & Biology**
[Name] is part of a [Number]-stage evolutionary line. It evolves from [Pre-evo] when [Condition]... It belongs to the [Egg Group] group...

---
**Input Data:**
[JSON Data provided in the user prompt]
"""

# %%
LIST_CACHE_FILE = Path("pokemon_list.json")

def get_all_pokemon():
    if LIST_CACHE_FILE.exists():
        print("Loading Pokemon list from cache...")
        try:
            with open(LIST_CACHE_FILE, "r") as f:
                return json.load(f)
        except Exception as e:
            print(f"Error reading cache, fetching fresh list. Error: {e}")

    print("Fetching list of all Pokemon from API...")
    url = "https://pokeapi.co/api/v2/pokemon?limit=10000"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        pokemon_list = [p["name"] for p in data["results"]]
        
        # Save to cache
        with open(LIST_CACHE_FILE, "w") as f:
            json.dump(pokemon_list, f)
        print(f"Saved {len(pokemon_list)} Pokemon to {LIST_CACHE_FILE}")
        return pokemon_list
    except Exception as e:
        print(f"Error fetching Pokemon list: {e}")
        return []

get_all_pokemon()
# Out:
# Loading Pokemon list from cache...
# ['bulbasaur',
#  'ivysaur',
#  'venusaur',
#  'charmander',
#  'charmeleon',
#  'charizard',
#  'squirtle',
#  'wartortle',
#  'blastoise',
#  'caterpie',
#  'metapod',
#  'butterfree',
#  'weedle',
#  'kakuna',
#  'beedrill',
#  'pidgey',
#  'pidgeotto',
#  'pidgeot',
#  'rattata',
#  'raticate',
#  'spearow',
#  'fearow',
#  'ekans',
#  'arbok',
#  'pikachu',
#  'raichu',
#  'sandshrew',
#  'sandslash',
#  'nidoran-f',
#  'nidorina',
#  'nidoqueen',
#  'nidoran-m',
#  'nidorino',
#  'nidoking',
#  'clefairy',
#  'clefable',
#  'vulpix',
#  'ninetales',
#  'jigglypuff',
#  'wigglytuff',
#  'zubat',
#  'golbat',
#  'oddish',
#  'gloom',
#  'vileplume',
#  'paras',
#  'parasect',
#  'venonat',
#  'venomoth',
#  'diglett',
#  'dugtrio',
#  'meowth',
#  'persian',
#  'psyduck',
#  'golduck',
#  'mankey',
#  'primeape',
#  'growlithe',
#  'arcanine',
#  'poliwag',
#  'poliwhirl',
#  'poliwrath',
#  'abra',
#  'kadabra',
#  'alakazam',
#  'machop',
#  'machoke',
#  'machamp',
#  'bellsprout',
#  'weepinbell',
#  'victreebel',
#  'tentacool',
#  'tentacruel',
#  'geodude',
#  'graveler',
#  'golem',
#  'ponyta',
#  'rapidash',
#  'slowpoke',
#  'slowbro',
#  'magnemite',
#  'magneton',
#  'farfetchd',
#  'doduo',
#  'dodrio',
#  'seel',
#  'dewgong',
#  'grimer',
#  'muk',
#  'shellder',
#  'cloyster',
#  'gastly',
#  'haunter',
#  'gengar',
#  'onix',
#  'drowzee',
#  'hypno',
#  'krabby',
#  'kingler',
#  'voltorb',
#  'electrode',
#  'exeggcute',
#  'exeggutor',
#  'cubone',
#  'marowak',
#  'hitmonlee',
#  'hitmonchan',
#  'lickitung',
#  'koffing',
#  'weezing',
#  'rhyhorn',
#  'rhydon',
#  'chansey',
#  'tangela',
#  'kangaskhan',
#  'horsea',
#  'seadra',
#  'goldeen',
#  'seaking',
#  'staryu',
#  'starmie',
#  'mr-mime',
#  'scyther',
#  'jynx',
#  'electabuzz',
#  'magmar',
#  'pinsir',
#  'tauros',
#  'magikarp',
#  'gyarados',
#  'lapras',
#  'ditto',
#  'eevee',
#  'vaporeon',
#  'jolteon',
#  'flareon',
#  'porygon',
#  'omanyte',
#  'omastar',
#  'kabuto',
#  'kabutops',
#  'aerodactyl',
#  'snorlax',
#  'articuno',
#  'zapdos',
#  'moltres',
#  'dratini',
#  'dragonair',
#  'dragonite',
#  'mewtwo',
#  'mew',
#  'chikorita',
#  'bayleef',
#  'meganium',
#  'cyndaquil',
#  'quilava',
#  'typhlosion',
#  'totodile',
#  'croconaw',
#  'feraligatr',
#  'sentret',
#  'furret',
#  'hoothoot',
#  'noctowl',
#  'ledyba',
#  'ledian',
#  'spinarak',
#  'ariados',
#  'crobat',
#  'chinchou',
#  'lanturn',
#  'pichu',
#  'cleffa',
#  'igglybuff',
#  'togepi',
#  'togetic',
#  'natu',
#  'xatu',
#  'mareep',
#  'flaaffy',
#  'ampharos',
#  'bellossom',
#  'marill',
#  'azumarill',
#  'sudowoodo',
#  'politoed',
#  'hoppip',
#  'skiploom',
#  'jumpluff',
#  'aipom',
#  'sunkern',
#  'sunflora',
#  'yanma',
#  'wooper',
#  'quagsire',
#  'espeon',
#  'umbreon',
#  'murkrow',
#  'slowking',
#  'misdreavus',
#  'unown',
#  'wobbuffet',
#  'girafarig',
#  'pineco',
#  'forretress',
#  'dunsparce',
#  'gligar',
#  'steelix',
#  'snubbull',
#  'granbull',
#  'qwilfish',
#  'scizor',
#  'shuckle',
#  'heracross',
#  'sneasel',
#  'teddiursa',
#  'ursaring',
#  'slugma',
#  'magcargo',
#  'swinub',
#  'piloswine',
#  'corsola',
#  'remoraid',
#  'octillery',
#  'delibird',
#  'mantine',
#  'skarmory',
#  'houndour',
#  'houndoom',
#  'kingdra',
#  'phanpy',
#  'donphan',
#  'porygon2',
#  'stantler',
#  'smeargle',
#  'tyrogue',
#  'hitmontop',
#  'smoochum',
#  'elekid',
#  'magby',
#  'miltank',
#  'blissey',
#  'raikou',
#  'entei',
#  'suicune',
#  'larvitar',
#  'pupitar',
#  'tyranitar',
#  'lugia',
#  'ho-oh',
#  'celebi',
#  'treecko',
#  'grovyle',
#  'sceptile',
#  'torchic',
#  'combusken',
#  'blaziken',
#  'mudkip',
#  'marshtomp',
#  'swampert',
#  'poochyena',
#  'mightyena',
#  'zigzagoon',
#  'linoone',
#  'wurmple',
#  'silcoon',
#  'beautifly',
#  'cascoon',
#  'dustox',
#  'lotad',
#  'lombre',
#  'ludicolo',
#  'seedot',
#  'nuzleaf',
#  'shiftry',
#  'taillow',
#  'swellow',
#  'wingull',
#  'pelipper',
#  'ralts',
#  'kirlia',
#  'gardevoir',
#  'surskit',
#  'masquerain',
#  'shroomish',
#  'breloom',
#  'slakoth',
#  'vigoroth',
#  'slaking',
#  'nincada',
#  'ninjask',
#  'shedinja',
#  'whismur',
#  'loudred',
#  'exploud',
#  'makuhita',
#  'hariyama',
#  'azurill',
#  'nosepass',
#  'skitty',
#  'delcatty',
#  'sableye',
#  'mawile',
#  'aron',
#  'lairon',
#  'aggron',
#  'meditite',
#  'medicham',
#  'electrike',
#  'manectric',
#  'plusle',
#  'minun',
#  'volbeat',
#  'illumise',
#  'roselia',
#  'gulpin',
#  'swalot',
#  'carvanha',
#  'sharpedo',
#  'wailmer',
#  'wailord',
#  'numel',
#  'camerupt',
#  'torkoal',
#  'spoink',
#  'grumpig',
#  'spinda',
#  'trapinch',
#  'vibrava',
#  'flygon',
#  'cacnea',
#  'cacturne',
#  'swablu',
#  'altaria',
#  'zangoose',
#  'seviper',
#  'lunatone',
#  'solrock',
#  'barboach',
#  'whiscash',
#  'corphish',
#  'crawdaunt',
#  'baltoy',
#  'claydol',
#  'lileep',
#  'cradily',
#  'anorith',
#  'armaldo',
#  'feebas',
#  'milotic',
#  'castform',
#  'kecleon',
#  'shuppet',
#  'banette',
#  'duskull',
#  'dusclops',
#  'tropius',
#  'chimecho',
#  'absol',
#  'wynaut',
#  'snorunt',
#  'glalie',
#  'spheal',
#  'sealeo',
#  'walrein',
#  'clamperl',
#  'huntail',
#  'gorebyss',
#  'relicanth',
#  'luvdisc',
#  'bagon',
#  'shelgon',
#  'salamence',
#  'beldum',
#  'metang',
#  'metagross',
#  'regirock',
#  'regice',
#  'registeel',
#  'latias',
#  'latios',
#  'kyogre',
#  'groudon',
#  'rayquaza',
#  'jirachi',
#  'deoxys-normal',
#  'turtwig',
#  'grotle',
#  'torterra',
#  'chimchar',
#  'monferno',
#  'infernape',
#  'piplup',
#  'prinplup',
#  'empoleon',
#  'starly',
#  'staravia',
#  'staraptor',
#  'bidoof',
#  'bibarel',
#  'kricketot',
#  'kricketune',
#  'shinx',
#  'luxio',
#  'luxray',
#  'budew',
#  'roserade',
#  'cranidos',
#  'rampardos',
#  'shieldon',
#  'bastiodon',
#  'burmy',
#  'wormadam-plant',
#  'mothim',
#  'combee',
#  'vespiquen',
#  'pachirisu',
#  'buizel',
#  'floatzel',
#  'cherubi',
#  'cherrim',
#  'shellos',
#  'gastrodon',
#  'ambipom',
#  'drifloon',
#  'drifblim',
#  'buneary',
#  'lopunny',
#  'mismagius',
#  'honchkrow',
#  'glameow',
#  'purugly',
#  'chingling',
#  'stunky',
#  'skuntank',
#  'bronzor',
#  'bronzong',
#  'bonsly',
#  'mime-jr',
#  'happiny',
#  'chatot',
#  'spiritomb',
#  'gible',
#  'gabite',
#  'garchomp',
#  'munchlax',
#  'riolu',
#  'lucario',
#  'hippopotas',
#  'hippowdon',
#  'skorupi',
#  'drapion',
#  'croagunk',
#  'toxicroak',
#  'carnivine',
#  'finneon',
#  'lumineon',
#  'mantyke',
#  'snover',
#  'abomasnow',
#  'weavile',
#  'magnezone',
#  'lickilicky',
#  'rhyperior',
#  'tangrowth',
#  'electivire',
#  'magmortar',
#  'togekiss',
#  'yanmega',
#  'leafeon',
#  'glaceon',
#  'gliscor',
#  'mamoswine',
#  'porygon-z',
#  'gallade',
#  'probopass',
#  'dusknoir',
#  'froslass',
#  'rotom',
#  'uxie',
#  'mesprit',
#  'azelf',
#  'dialga',
#  'palkia',
#  'heatran',
#  'regigigas',
#  'giratina-altered',
#  'cresselia',
#  'phione',
#  'manaphy',
#  'darkrai',
#  'shaymin-land',
#  'arceus',
#  'victini',
#  'snivy',
#  'servine',
#  'serperior',
#  'tepig',
#  'pignite',
#  'emboar',
#  'oshawott',
#  'dewott',
#  'samurott',
#  'patrat',
#  'watchog',
#  'lillipup',
#  'herdier',
#  'stoutland',
#  'purrloin',
#  'liepard',
#  'pansage',
#  'simisage',
#  'pansear',
#  'simisear',
#  'panpour',
#  'simipour',
#  'munna',
#  'musharna',
#  'pidove',
#  'tranquill',
#  'unfezant',
#  'blitzle',
#  'zebstrika',
#  'roggenrola',
#  'boldore',
#  'gigalith',
#  'woobat',
#  'swoobat',
#  'drilbur',
#  'excadrill',
#  'audino',
#  'timburr',
#  'gurdurr',
#  'conkeldurr',
#  'tympole',
#  'palpitoad',
#  'seismitoad',
#  'throh',
#  'sawk',
#  'sewaddle',
#  'swadloon',
#  'leavanny',
#  'venipede',
#  'whirlipede',
#  'scolipede',
#  'cottonee',
#  'whimsicott',
#  'petilil',
#  'lilligant',
#  'basculin-red-striped',
#  'sandile',
#  'krokorok',
#  'krookodile',
#  'darumaka',
#  'darmanitan-standard',
#  'maractus',
#  'dwebble',
#  'crustle',
#  'scraggy',
#  'scrafty',
#  'sigilyph',
#  'yamask',
#  'cofagrigus',
#  'tirtouga',
#  'carracosta',
#  'archen',
#  'archeops',
#  'trubbish',
#  'garbodor',
#  'zorua',
#  'zoroark',
#  'minccino',
#  'cinccino',
#  'gothita',
#  'gothorita',
#  'gothitelle',
#  'solosis',
#  'duosion',
#  'reuniclus',
#  'ducklett',
#  'swanna',
#  'vanillite',
#  'vanillish',
#  'vanilluxe',
#  'deerling',
#  'sawsbuck',
#  'emolga',
#  'karrablast',
#  'escavalier',
#  'foongus',
#  'amoonguss',
#  'frillish',
#  'jellicent',
#  'alomomola',
#  'joltik',
#  'galvantula',
#  'ferroseed',
#  'ferrothorn',
#  'klink',
#  'klang',
#  'klinklang',
#  'tynamo',
#  'eelektrik',
#  'eelektross',
#  'elgyem',
#  'beheeyem',
#  'litwick',
#  'lampent',
#  'chandelure',
#  'axew',
#  'fraxure',
#  'haxorus',
#  'cubchoo',
#  'beartic',
#  'cryogonal',
#  'shelmet',
#  'accelgor',
#  'stunfisk',
#  'mienfoo',
#  'mienshao',
#  'druddigon',
#  'golett',
#  'golurk',
#  'pawniard',
#  'bisharp',
#  'bouffalant',
#  'rufflet',
#  'braviary',
#  'vullaby',
#  'mandibuzz',
#  'heatmor',
#  'durant',
#  'deino',
#  'zweilous',
#  'hydreigon',
#  'larvesta',
#  'volcarona',
#  'cobalion',
#  'terrakion',
#  'virizion',
#  'tornadus-incarnate',
#  'thundurus-incarnate',
#  'reshiram',
#  'zekrom',
#  'landorus-incarnate',
#  'kyurem',
#  'keldeo-ordinary',
#  'meloetta-aria',
#  'genesect',
#  'chespin',
#  'quilladin',
#  'chesnaught',
#  'fennekin',
#  'braixen',
#  'delphox',
#  'froakie',
#  'frogadier',
#  'greninja',
#  'bunnelby',
#  'diggersby',
#  'fletchling',
#  'fletchinder',
#  'talonflame',
#  'scatterbug',
#  'spewpa',
#  'vivillon',
#  'litleo',
#  'pyroar',
#  'flabebe',
#  'floette',
#  'florges',
#  'skiddo',
#  'gogoat',
#  'pancham',
#  'pangoro',
#  'furfrou',
#  'espurr',
#  'meowstic-male',
#  'honedge',
#  'doublade',
#  'aegislash-shield',
#  'spritzee',
#  'aromatisse',
#  'swirlix',
#  'slurpuff',
#  'inkay',
#  'malamar',
#  'binacle',
#  'barbaracle',
#  'skrelp',
#  'dragalge',
#  'clauncher',
#  'clawitzer',
#  'helioptile',
#  'heliolisk',
#  'tyrunt',
#  'tyrantrum',
#  'amaura',
#  'aurorus',
#  'sylveon',
#  'hawlucha',
#  'dedenne',
#  'carbink',
#  'goomy',
#  'sliggoo',
#  'goodra',
#  'klefki',
#  'phantump',
#  'trevenant',
#  'pumpkaboo-average',
#  'gourgeist-average',
#  'bergmite',
#  'avalugg',
#  'noibat',
#  'noivern',
#  'xerneas',
#  'yveltal',
#  'zygarde-50',
#  'diancie',
#  'hoopa',
#  'volcanion',
#  'rowlet',
#  'dartrix',
#  'decidueye',
#  'litten',
#  'torracat',
#  'incineroar',
#  'popplio',
#  'brionne',
#  'primarina',
#  'pikipek',
#  'trumbeak',
#  'toucannon',
#  'yungoos',
#  'gumshoos',
#  'grubbin',
#  'charjabug',
#  'vikavolt',
#  'crabrawler',
#  'crabominable',
#  'oricorio-baile',
#  'cutiefly',
#  'ribombee',
#  'rockruff',
#  'lycanroc-midday',
#  'wishiwashi-solo',
#  'mareanie',
#  'toxapex',
#  'mudbray',
#  'mudsdale',
#  'dewpider',
#  'araquanid',
#  'fomantis',
#  'lurantis',
#  'morelull',
#  'shiinotic',
#  'salandit',
#  'salazzle',
#  'stufful',
#  'bewear',
#  'bounsweet',
#  'steenee',
#  'tsareena',
#  'comfey',
#  'oranguru',
#  'passimian',
#  'wimpod',
#  'golisopod',
#  'sandygast',
#  'palossand',
#  'pyukumuku',
#  'type-null',
#  'silvally',
#  'minior-red-meteor',
#  'komala',
#  'turtonator',
#  'togedemaru',
#  'mimikyu-disguised',
#  'bruxish',
#  'drampa',
#  'dhelmise',
#  'jangmo-o',
#  'hakamo-o',
#  'kommo-o',
#  'tapu-koko',
#  'tapu-lele',
#  'tapu-bulu',
#  'tapu-fini',
#  'cosmog',
#  'cosmoem',
#  'solgaleo',
#  'lunala',
#  'nihilego',
#  'buzzwole',
#  'pheromosa',
#  'xurkitree',
#  'celesteela',
#  'kartana',
#  'guzzlord',
#  'necrozma',
#  'magearna',
#  'marshadow',
#  'poipole',
#  'naganadel',
#  'stakataka',
#  'blacephalon',
#  'zeraora',
#  'meltan',
#  'melmetal',
#  'grookey',
#  'thwackey',
#  'rillaboom',
#  'scorbunny',
#  'raboot',
#  'cinderace',
#  'sobble',
#  'drizzile',
#  'inteleon',
#  'skwovet',
#  'greedent',
#  'rookidee',
#  'corvisquire',
#  'corviknight',
#  'blipbug',
#  'dottler',
#  'orbeetle',
#  'nickit',
#  'thievul',
#  'gossifleur',
#  'eldegoss',
#  'wooloo',
#  'dubwool',
#  'chewtle',
#  'drednaw',
#  'yamper',
#  'boltund',
#  'rolycoly',
#  'carkol',
#  'coalossal',
#  'applin',
#  'flapple',
#  'appletun',
#  'silicobra',
#  'sandaconda',
#  'cramorant',
#  'arrokuda',
#  'barraskewda',
#  'toxel',
#  'toxtricity-amped',
#  'sizzlipede',
#  'centiskorch',
#  'clobbopus',
#  'grapploct',
#  'sinistea',
#  'polteageist',
#  'hatenna',
#  'hattrem',
#  'hatterene',
#  'impidimp',
#  'morgrem',
#  'grimmsnarl',
#  'obstagoon',
#  'perrserker',
#  'cursola',
#  'sirfetchd',
#  'mr-rime',
#  'runerigus',
#  'milcery',
#  'alcremie',
#  'falinks',
#  'pincurchin',
#  'snom',
#  'frosmoth',
#  'stonjourner',
#  'eiscue-ice',
#  'indeedee-male',
#  'morpeko-full-belly',
#  'cufant',
#  'copperajah',
#  'dracozolt',
#  'arctozolt',
#  'dracovish',
#  'arctovish',
#  'duraludon',
#  'dreepy',
#  'drakloak',
#  'dragapult',
#  'zacian',
#  'zamazenta',
#  'eternatus',
#  'kubfu',
#  'urshifu-single-strike',
#  'zarude',
#  'regieleki',
#  'regidrago',
#  'glastrier',
#  'spectrier',
#  'calyrex',
#  'wyrdeer',
#  'kleavor',
#  'ursaluna',
#  'basculegion-male',
#  'sneasler',
#  'overqwil',
#  'enamorus-incarnate',
#  'sprigatito',
#  'floragato',
#  'meowscarada',
#  'fuecoco',
#  'crocalor',
#  'skeledirge',
#  'quaxly',
#  'quaxwell',
#  'quaquaval',
#  'lechonk',
#  'oinkologne-male',
#  'tarountula',
#  'spidops',
#  'nymble',
#  'lokix',
#  'pawmi',
#  'pawmo',
#  'pawmot',
#  'tandemaus',
#  'maushold-family-of-four',
#  'fidough',
#  'dachsbun',
#  'smoliv',
#  'dolliv',
#  'arboliva',
#  'squawkabilly-green-plumage',
#  'nacli',
#  'naclstack',
#  'garganacl',
#  'charcadet',
#  'armarouge',
#  'ceruledge',
#  'tadbulb',
#  'bellibolt',
#  'wattrel',
#  'kilowattrel',
#  'maschiff',
#  'mabosstiff',
#  'shroodle',
#  'grafaiai',
#  'bramblin',
#  'brambleghast',
#  'toedscool',
#  'toedscruel',
#  'klawf',
#  'capsakid',
#  'scovillain',
#  'rellor',
#  'rabsca',
#  'flittle',
#  'espathra',
#  'tinkatink',
#  'tinkatuff',
#  'tinkaton',
#  'wiglett',
#  'wugtrio',
#  'bombirdier',
#  'finizen',
#  'palafin-zero',
#  'varoom',
#  'revavroom',
#  'cyclizar',
#  'orthworm',
#  'glimmet',
#  'glimmora',
#  'greavard',
#  'houndstone',
#  'flamigo',
#  'cetoddle',
#  'cetitan',
#  'veluza',
#  'dondozo',
#  'tatsugiri-curly',
#  'annihilape',
#  'clodsire',
#  'farigiraf',
#  'dudunsparce-two-segment',
#  'kingambit',
#  'great-tusk',
#  'scream-tail',
#  'brute-bonnet',
#  'flutter-mane',
#  'slither-wing',
#  'sandy-shocks',
#  'iron-treads',
#  'iron-bundle',
#  'iron-hands',
#  'iron-jugulis',
#  'iron-moth',
#  'iron-thorns',
#  'frigibax',
#  'arctibax',
#  'baxcalibur',
#  'gimmighoul',
#  'gholdengo',
#  ...]

# %%
# Configuration
OUTPUT_DIR = Path("raw")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
MODEL_NAME = "gemini-3-pro-preview"
MAX_WORKERS = 10
ABORT_LIMIT = 20

# Global state
error_count = 0
error_lock = threading.Lock()
abort_event = threading.Event()



def generate_pokemon_data(pokemon_name):
    global error_count
    
    if abort_event.is_set():
        return

    # Optimistic existing file check
    existing = list(OUTPUT_DIR.glob(f"*_{pokemon_name}.md"))
    if existing:
        # print(f"Skipping {pokemon_name} (File exists)")
        return

    # Initialize Clients (Thread-safe)
    pokemon_client = PokemonAPIClient(enable_cache=False)
    llm_client = LLMQuery(model=MODEL_NAME, system_prompt=SYSTEM_PROMPT)
    
    time.sleep(0.5)
    
    try:
        print(f"Processing {pokemon_name}...")
        details = pokemon_client.get_pokemon_details(pokemon_name)
        if "error" in details:
            raise Exception(f"API Error: {details.get('error')}")
            
        type_info = []
        for t in details.get("types", []):
            t_info = pokemon_client.get_type_info(t)
            if "error" not in t_info:
                type_info.append(t_info)

        context = {"pokemon_details": details, "type_info": type_info}
        user_prompt = f"Here is the data for {pokemon_name}:\n```json\n{json.dumps(context, indent=2)}\n```"
        
        response = None
        for attempt in range(3):
            try:
                response = llm_client.query(user_prompt=user_prompt, use_history=False)
                if response: break
            except Exception as e:
                if attempt == 2: raise e
                time.sleep(2 ** attempt)

        p_id = details.get("id", 0)
        file_prefix = f"{p_id:04d}_{pokemon_name}"
        
        with open(OUTPUT_DIR / f"{file_prefix}.json", "w", encoding="utf-8") as f:
            json.dump(context, f, indent=2)
        with open(OUTPUT_DIR / f"{file_prefix}.md", "w", encoding="utf-8") as f:
            f.write(response)
            
        print(f"Saved {file_prefix}.md")
        
    except Exception as e:
        with error_lock:
            error_count += 1
            print(f"Error processing {pokemon_name}: {e} (Count: {error_count})")
            if error_count >= ABORT_LIMIT:
                print("Aborting generation due to error limit.")
                abort_event.set()

# Main Execution
try:
    POKEMON_LIST = get_all_pokemon()
    if POKEMON_LIST:
        print(f"Starting generation for {len(POKEMON_LIST)} Pokemon with {MAX_WORKERS} threads...")
        with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
            list(executor.map(generate_pokemon_data, POKEMON_LIST))
    else:
        print("No Pokemon found to process.")
    print("Generation complete.")
except KeyboardInterrupt:
    print("Generation interrupted.")
except Exception as e:
    print(f"Fatal error: {e}")
# Out:
# Loading Pokemon list from cache...
# Starting generation for 1350 Pokemon with 10 threads...
# Processing bulbasaur...
# Processing ivysaur...
# Processing charmander...
# Processing venusaur...
# Processing charmeleon...
# Processing charizard...
# Processing wartortle...
# Processing blastoise...
# Processing caterpie...
# Processing squirtle...
# Saved 0005_charmeleon.md
# Processing metapod...
# Saved 0004_charmander.md
# Processing butterfree...
# Saved 0009_blastoise.md
# Saved 0008_wartortle.md
# Processing weedle...
# Processing kakuna...
# Saved 0001_bulbasaur.md
# Processing beedrill...
# Saved 0006_charizard.md
# Saved 0002_ivysaur.md
# Saved 0010_caterpie.md
# Processing pidgey...
# Processing pidgeotto...
# Processing pidgeot...
# Saved 0007_squirtle.md
# Saved 0003_venusaur.md
# Processing rattata...
# Processing raticate...
# Saved 0011_metapod.md
# Processing spearow...
# Saved 0012_butterfree.md
# Processing fearow...
# Saved 0014_kakuna.md
# Processing ekans...
# Saved 0016_pidgey.md
# Processing arbok...
# Saved 0013_weedle.md
# Processing pikachu...
# Saved 0017_pidgeotto.md
# Processing raichu...
# Saved 0020_raticate.md
# Processing sandshrew...
# Saved 0019_rattata.md
# Processing sandslash...
# Saved 0015_beedrill.md
# Processing nidoran-f...
# Saved 0018_pidgeot.md
# Processing nidorina...
# Saved 0022_fearow.md
# Processing nidoqueen...
# Saved 0023_ekans.md
# Saved 0021_spearow.md
# Processing nidoran-m...
# Processing nidorino...
# Saved 0024_arbok.md
# Processing nidoking...
# Saved 0025_pikachu.md
# Processing clefairy...
# Saved 0026_raichu.md
# Saved 0029_nidoran-f.md
# Processing clefable...
# Processing vulpix...
# Saved 0027_sandshrew.md
# Processing ninetales...
# Saved 0028_sandslash.md
# Processing jigglypuff...
# Saved 0030_nidorina.md
# Processing wigglytuff...
# Saved 0033_nidorino.md
# Saved 0032_nidoran-m.md
# Processing zubat...
# Processing golbat...
# Saved 0031_nidoqueen.md
# Processing oddish...
# Saved 0035_clefairy.md
# Processing gloom...
# Saved 0036_clefable.md
# Processing vileplume...
# Saved 0038_ninetales.md
# Processing paras...
# Saved 0034_nidoking.md
# Processing parasect...
# Saved 0037_vulpix.md
# Processing venonat...
# Saved 0039_jigglypuff.md
# Processing venomoth...
# Saved 0040_wigglytuff.md
# Processing diglett...
# Saved 0042_golbat.md
# Processing dugtrio...
# Saved 0041_zubat.md
# Processing meowth...
# Saved 0043_oddish.md
# Processing persian...
# Saved 0044_gloom.md
# Processing psyduck...
# Saved 0045_vileplume.md
# Processing golduck...
# Saved 0046_paras.md
# Processing mankey...
# Saved 0047_parasect.md
# Processing primeape...
# Saved 0048_venonat.md
# Saved 0050_diglett.md
# Processing growlithe...
# Processing arcanine...
# Saved 0051_dugtrio.md
# Processing poliwag...
# Saved 0049_venomoth.md
# Processing poliwhirl...
# Saved 0053_persian.md
# Processing poliwrath...
# Saved 0052_meowth.md
# Processing abra...
# Saved 0055_golduck.md
# Processing kadabra...
# Saved 0054_psyduck.md
# Processing alakazam...
# Saved 0056_mankey.md
# Processing machop...
# Saved 0057_primeape.md
# Processing machoke...
# Saved 0060_poliwag.md
# Processing machamp...
# Saved 0058_growlithe.md
# Saved 0059_arcanine.md
# Processing bellsprout...
# Processing weepinbell...
# Saved 0061_poliwhirl.md
# Processing victreebel...
# Saved 0062_poliwrath.md
# Processing tentacool...
# Saved 0063_abra.md
# Processing tentacruel...
# Saved 0064_kadabra.md
# Processing geodude...
# Saved 0065_alakazam.md
# Processing graveler...
# Saved 0066_machop.md
# Processing golem...
# Saved 0068_machamp.md
# Processing ponyta...
# Saved 0067_machoke.md
# Processing rapidash...
# Saved 0069_bellsprout.md
# Processing slowpoke...
# Saved 0070_weepinbell.md
# Processing slowbro...
# Saved 0071_victreebel.md
# Processing magnemite...
# Saved 0072_tentacool.md
# Processing magneton...
# Saved 0073_tentacruel.md
# Processing farfetchd...
# Saved 0074_geodude.md
# Processing doduo...
# Saved 0075_graveler.md
# Processing dodrio...
# Saved 0077_ponyta.md
# Saved 0076_golem.md
# Processing seel...
# Saved 0078_rapidash.md
# Processing dewgong...
# Processing grimer...
# Saved 0079_slowpoke.md
# Processing muk...
# Saved 0080_slowbro.md
# Saved 0081_magnemite.md
# Processing shellder...
# Processing cloyster...
# Saved 0082_magneton.md
# Processing gastly...
# Saved 0084_doduo.md
# Processing haunter...
# Saved 0083_farfetchd.md
# Processing gengar...
# Saved 0085_dodrio.md
# Processing onix...
# Saved 0086_seel.md
# Processing drowzee...
# Saved 0089_muk.md
# Saved 0088_grimer.md
# Processing hypno...
# Processing krabby...
# Saved 0087_dewgong.md
# Processing kingler...
# Saved 0091_cloyster.md
# Processing voltorb...
# Saved 0090_shellder.md
# Processing electrode...
# Saved 0092_gastly.md
# Saved 0093_haunter.md
# Processing exeggcute...
# Processing exeggutor...
# Saved 0094_gengar.md
# Processing cubone...
# Saved 0096_drowzee.md
# Processing marowak...
# Saved 0095_onix.md
# Processing hitmonlee...
# Saved 0098_krabby.md
# Processing hitmonchan...
# Saved 0101_electrode.md
# Saved 0097_hypno.md
# Processing lickitung...
# Processing koffing...
# Saved 0100_voltorb.md
# Processing weezing...
# Saved 0099_kingler.md
# Processing rhyhorn...
# Saved 0102_exeggcute.md
# Saved 0104_cubone.md
# Processing rhydon...
# Processing chansey...
# Saved 0103_exeggutor.md
# Processing tangela...
# Saved 0106_hitmonlee.md
# Processing kangaskhan...
# Saved 0105_marowak.md
# Processing horsea...
# Saved 0107_hitmonchan.md
# Processing seadra...
# Saved 0108_lickitung.md
# Saved 0110_weezing.md
# Processing goldeen...
# Saved 0109_koffing.md
# Processing seaking...
# Processing staryu...
# Saved 0111_rhyhorn.md
# Processing starmie...
# Saved 0113_chansey.md
# Processing mr-mime...
# Saved 0112_rhydon.md
# Processing scyther...
# Saved 0114_tangela.md
# Processing jynx...
# Saved 0115_kangaskhan.md
# Processing electabuzz...
# Saved 0116_horsea.md
# Processing magmar...
# Saved 0118_goldeen.md
# Saved 0119_seaking.md
# Processing pinsir...
# Processing tauros...
# Saved 0120_staryu.md
# Processing magikarp...
# Saved 0121_starmie.md
# Processing gyarados...
# Saved 0123_scyther.md
# Processing lapras...
# Saved 0117_seadra.md
# Processing ditto...
# Saved 0126_magmar.md
# Saved 0124_jynx.md
# Processing eevee...
# Processing vaporeon...
# Saved 0125_electabuzz.md
# Saved 0122_mr-mime.md
# Saved 0127_pinsir.md
# Processing jolteon...
# Processing flareon...
# Processing porygon...
# Saved 0128_tauros.md
# Processing omanyte...
# Saved 0129_magikarp.md
# Processing omastar...
# Saved 0130_gyarados.md
# Processing kabuto...
# Saved 0132_ditto.md
# Processing kabutops...
# Saved 0131_lapras.md
# Processing aerodactyl...
# Saved 0133_eevee.md
# Processing snorlax...
# Saved 0137_porygon.md
# Processing articuno...
# Saved 0136_flareon.md
# Processing zapdos...
# Saved 0134_vaporeon.md
# Processing moltres...
# Saved 0135_jolteon.md
# Processing dratini...
# Saved 0138_omanyte.md
# Processing dragonair...
# Saved 0139_omastar.md
# Processing dragonite...
# Saved 0140_kabuto.md
# Saved 0141_kabutops.md
# Processing mewtwo...
# Processing mew...
# Saved 0142_aerodactyl.md
# Processing chikorita...
# Saved 0143_snorlax.md
# Processing bayleef...
# Saved 0145_zapdos.md
# Saved 0147_dratini.md
# Saved 0144_articuno.md
# Processing meganium...
# Processing cyndaquil...
# Processing quilava...
# Saved 0146_moltres.md
# Processing typhlosion...
# Saved 0148_dragonair.md
# Processing totodile...
# Saved 0149_dragonite.md
# Processing croconaw...
# Saved 0150_mewtwo.md
# Processing feraligatr...
# Saved 0152_chikorita.md
# Processing sentret...
# Saved 0151_mew.md
# Processing furret...
# Saved 0153_bayleef.md
# Processing hoothoot...
# Saved 0154_meganium.md
# Processing noctowl...
# Saved 0155_cyndaquil.md
# Saved 0156_quilava.md
# Processing ledyba...
# Processing ledian...
# Saved 0158_totodile.md
# Processing spinarak...
# Saved 0159_croconaw.md
# Saved 0157_typhlosion.md
# Processing ariados...
# Processing crobat...
# Saved 0160_feraligatr.md
# Processing chinchou...
# Saved 0161_sentret.md
# Processing lanturn...
# Saved 0162_furret.md
# Processing pichu...
# Saved 0163_hoothoot.md
# Processing cleffa...
# Saved 0164_noctowl.md
# Processing igglybuff...
# Saved 0165_ledyba.md
# Processing togepi...
# Saved 0167_spinarak.md
# Processing togetic...
# Saved 0166_ledian.md
# Saved 0169_crobat.md
# Processing natu...
# Processing xatu...
# Saved 0168_ariados.md
# Processing mareep...
# Saved 0170_chinchou.md
# Processing flaaffy...
# Saved 0171_lanturn.md
# Processing ampharos...
# Saved 0172_pichu.md
# Processing bellossom...
# Saved 0173_cleffa.md
# Processing marill...
# Saved 0174_igglybuff.md
# Processing azumarill...
# Saved 0175_togepi.md
# Processing sudowoodo...
# Saved 0176_togetic.md
# Saved 0178_xatu.md
# Processing politoed...
# Processing hoppip...
# Saved 0179_mareep.md
# Processing skiploom...
# Saved 0177_natu.md
# Saved 0180_flaaffy.md
# Processing jumpluff...
# Processing aipom...
# Saved 0181_ampharos.md
# Processing sunkern...
# Saved 0182_bellossom.md
# Processing sunflora...
# Saved 0183_marill.md
# Processing yanma...
# Saved 0185_sudowoodo.md
# Processing wooper...
# Saved 0184_azumarill.md
# Saved 0186_politoed.md
# Processing quagsire...
# Processing espeon...
# Saved 0188_skiploom.md
# Processing umbreon...
# Saved 0190_aipom.md
# Processing murkrow...
# Saved 0189_jumpluff.md
# Processing slowking...
# Saved 0191_sunkern.md
# Processing misdreavus...
# Saved 0192_sunflora.md
# Processing unown...
# Saved 0193_yanma.md
# Processing wobbuffet...
# Saved 0196_espeon.md
# Processing girafarig...
# Saved 0195_quagsire.md
# Processing pineco...
# Saved 0194_wooper.md
# Processing forretress...
# Saved 0197_umbreon.md
# Saved 0187_hoppip.md
# Processing dunsparce...
# Processing gligar...
# Saved 0200_misdreavus.md
# Processing steelix...
# Saved 0198_murkrow.md
# Processing snubbull...
# Saved 0199_slowking.md
# Processing granbull...
# Saved 0201_unown.md
# Processing qwilfish...
# Saved 0204_pineco.md
# Processing scizor...
# Saved 0203_girafarig.md
# Processing shuckle...
# Saved 0202_wobbuffet.md
# Processing heracross...
# Saved 0207_gligar.md
# Processing sneasel...
# Saved 0209_snubbull.md
# Saved 0206_dunsparce.md
# Processing teddiursa...
# Processing ursaring...
# Saved 0205_forretress.md
# Saved 0208_steelix.md
# Processing slugma...
# Processing magcargo...
# Saved 0210_granbull.md
# Processing swinub...
# Saved 0212_scizor.md
# Processing piloswine...
# Saved 0214_heracross.md
# Saved 0213_shuckle.md
# Processing corsola...
# Processing remoraid...
# Saved 0211_qwilfish.md
# Processing octillery...
# Saved 0215_sneasel.md
# Saved 0216_teddiursa.md
# Saved 0217_ursaring.md
# Saved 0218_slugma.md
# Processing delibird...
# Processing mantine...
# Processing skarmory...
# Processing houndour...
# Saved 0220_swinub.md
# Saved 0219_magcargo.md
# Processing houndoom...
# Processing kingdra...
# Saved 0223_remoraid.md
# Processing phanpy...
# Saved 0224_octillery.md
# Saved 0221_piloswine.md
# Processing donphan...
# Processing porygon2...
# Saved 0227_skarmory.md
# Saved 0226_mantine.md
# Processing stantler...
# Processing smeargle...
# Saved 0222_corsola.md
# Processing tyrogue...
# Saved 0225_delibird.md
# Processing hitmontop...
# Saved 0228_houndour.md
# Processing smoochum...
# Saved 0229_houndoom.md
# Processing elekid...
# Saved 0230_kingdra.md
# Processing magby...
# Saved 0231_phanpy.md
# Processing miltank...
# Saved 0233_porygon2.md
# Processing blissey...
# Saved 0232_donphan.md
# Processing raikou...
# Saved 0235_smeargle.md
# Processing entei...
# Saved 0234_stantler.md
# Saved 0236_tyrogue.md
# Processing suicune...
# Processing larvitar...
# Saved 0237_hitmontop.md
# Processing pupitar...
# Saved 0239_elekid.md
# Processing tyranitar...
# Saved 0238_smoochum.md
# Processing lugia...
# Saved 0240_magby.md
# Processing ho-oh...
# Saved 0241_miltank.md
# Processing celebi...
# Saved 0243_raikou.md
# Processing treecko...
# Saved 0242_blissey.md
# Processing grovyle...
# Saved 0245_suicune.md
# Processing sceptile...
# Saved 0246_larvitar.md
# Processing torchic...
# Saved 0247_pupitar.md
# Processing combusken...
# Saved 0248_tyranitar.md
# Processing blaziken...
# Saved 0251_celebi.md
# Saved 0249_lugia.md
# Processing mudkip...
# Processing marshtomp...
# Saved 0250_ho-oh.md
# Processing swampert...
# Error processing combusken: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 1)
# Processing poochyena...
# Error processing blaziken: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 2)
# Saved 0252_treecko.md
# Processing mightyena...
# Processing zigzagoon...
# Saved 0253_grovyle.md
# Processing linoone...
# Error processing marshtomp: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 3)
# Processing wurmple...
# Saved 0244_entei.md
# Error processing mudkip: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 4)
# Processing silcoon...
# Processing beautifly...
# Error processing swampert: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 5)
# Processing cascoon...
# Saved 0255_torchic.md
# Processing dustox...
# Saved 0254_sceptile.md
# Processing lotad...
# Error processing poochyena: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 6)
# Processing lombre...
# Error processing zigzagoon: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 7)
# Processing ludicolo...
# Error processing mightyena: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 8)
# Processing seedot...
# Error processing wurmple: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 9)
# Error processing linoone: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 10)
# Processing nuzleaf...
# Processing shiftry...
# Error processing beautifly: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 11)
# Error processing silcoon: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 12)
# Processing taillow...
# Processing swellow...
# Error processing cascoon: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 13)
# Processing wingull...
# Error processing lotad: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 14)
# Processing pelipper...
# Error processing dustox: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 15)
# Processing ralts...
# Error processing seedot: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 16)
# Processing kirlia...
# Error processing ludicolo: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 17)
# Error processing lombre: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 18)
# Processing gardevoir...
# Processing surskit...
# Error processing shiftry: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 19)
# Error processing nuzleaf: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 20)
# Aborting generation due to error limit.
# Processing masquerain...
# Error processing taillow: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 21)
# Aborting generation due to error limit.
# Error processing swellow: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 22)
# Aborting generation due to error limit.
# Error processing wingull: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 23)
# Aborting generation due to error limit.
# Error processing ralts: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 24)
# Aborting generation due to error limit.
# Error processing pelipper: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 25)
# Aborting generation due to error limit.
# Error processing gardevoir: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 26)
# Aborting generation due to error limit.
# Error processing surskit: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 27)
# Aborting generation due to error limit.
# Error processing kirlia: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 28)
# Aborting generation due to error limit.
# Error processing masquerain: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_requests_per_model_per_day, limit: 0', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model_per_day', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel'}]}]}}] (Count: 29)
# Aborting generation due to error limit.
# Generation complete.

# %%
llm_client.chat_history
# Out:
# [{'role': 'user',
#   'content': 'Here is the data for bulbasaur:\n```json\n{\n  "pokemon_details": {\n    "id": 1,\n    "name": "bulbasaur",\n    "stats": {\n      "hp": 45,\n      "attack": 49,\n      "defense": 49,\n      "special-attack": 65,\n      "special-defense": 65,\n      "speed": 45\n    },\n    "types": [\n      "grass",\n      "poison"\n    ],\n    "height_m": 0.7,\n    "weight_kg": 6.9,\n    "abilities": [\n      {\n        "name": "overgrow",\n        "is_hidden": false,\n        "slot": 1\n      },\n      {\n        "name": "chlorophyll",\n        "is_hidden": true,\n        "slot": 3\n      }\n    ],\n    "forms": [\n      "bulbasaur"\n    ],\n    "moves": [\n      "razor-wind",\n      "swords-dance",\n      "cut",\n      "bind",\n      "vine-whip",\n      "headbutt",\n      "tackle",\n      "body-slam",\n      "take-down",\n      "double-edge",\n      "growl",\n      "strength",\n      "mega-drain",\n      "leech-seed",\n      "growth",\n      "razor-leaf",\n      "solar-beam",\n      "poison-powder",\n      "sleep-powder",\n      "petal-dance",\n      "string-shot",\n      "toxic",\n      "rage",\n      "mimic",\n      "double-team",\n      "defense-curl",\n      "light-screen",\n      "reflect",\n      "bide",\n      "sludge",\n      "skull-bash",\n      "amnesia",\n      "flash",\n      "rest",\n      "substitute",\n      "snore",\n      "curse",\n      "protect",\n      "sludge-bomb",\n      "mud-slap",\n      "outrage",\n      "giga-drain",\n      "endure",\n      "charm",\n      "false-swipe",\n      "swagger",\n      "fury-cutter",\n      "attract",\n      "sleep-talk",\n      "return",\n      "frustration",\n      "safeguard",\n      "sweet-scent",\n      "synthesis",\n      "hidden-power",\n      "sunny-day",\n      "rock-smash",\n      "facade",\n      "nature-power",\n      "helping-hand",\n      "ingrain",\n      "knock-off",\n      "secret-power",\n      "weather-ball",\n      "grass-whistle",\n      "bullet-seed",\n      "magical-leaf",\n      "natural-gift",\n      "worry-seed",\n      "seed-bomb",\n      "energy-ball",\n      "leaf-storm",\n      "power-whip",\n      "captivate",\n      "grass-knot",\n      "venoshock",\n      "acid-spray",\n      "round",\n      "echoed-voice",\n      "grass-pledge",\n      "work-up",\n      "grassy-terrain",\n      "confide",\n      "grassy-glide",\n      "tera-blast",\n      "trailblaze"\n    ],\n    "held_items": [],\n    "base_experience": 64,\n    "is_default": true,\n    "order": 1,\n    "sprites": {\n      "front_default": "https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1.png",\n      "back_default": "https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/back/1.png",\n      "front_shiny": "https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/1.png"\n    },\n    "species_name": "bulbasaur",\n    "flavor_text": "A strange seed was planted on its back at birth. The plant sprouts and grows with this POK\\u00e9MON.",\n    "genus": "Seed Pok\\u00e9mon",\n    "is_legendary": false,\n    "is_mythical": false,\n    "is_baby": false,\n    "capture_rate": 45,\n    "base_happiness": 70,\n    "hatch_counter": 20,\n    "growth_rate": "medium-slow",\n    "habitat": "grassland",\n    "shape": "quadruped",\n    "color": "green",\n    "egg_groups": [\n      "monster",\n      "plant"\n    ],\n    "evolution_chain_url": "https://pokeapi.co/api/v2/evolution-chain/1/",\n    "generation": "generation-i",\n    "generation_info": {\n      "name": "Generation I",\n      "region": "Kanto"\n    },\n    "evolution": {\n      "chain_id": 1,\n      "chain": {\n        "species_name": "bulbasaur",\n        "evolution_details": [],\n        "evolves_to": [\n          {\n            "species_name": "ivysaur",\n            "evolution_details": [\n              {\n                "trigger": "level-up",\n                "min_level": 16\n              }\n            ],\n            "evolves_to": [\n              {\n                "specie ...
#  {'role': 'assistant',
#   'content': "## Identity & Lore\nBulbasaur (Pokedex #001) is the dual-type Grass/Poison Seed Pokémon introduced in Generation I (Kanto). Distinctive for the large plant bulb on its back, this quadrupedal, reptilian Pokémon is born with a strange seed planted on it, which sprouts and grows alongside the creature. It is known to nap in bright sunlight, using the rays to photosynthesize nutrients and swell the bulb on its back. While generally found in grasslands, Bulbasaur is extremely rare in the wild and is best known as one of the three Starter Pokémon offered by Professor Oak in the Kanto region. While Bulbasaur itself does not change form, its final evolution, Venusaur, possesses both a Mega Evolution and a Gigantamax form.\n\n## Combat Profile\n*   **Stats:** HP 45, Attack 49, Defense 49, Sp. Atk 65, Sp. Def 65, Speed 45.\n*   **Archetype:** Bulky Special Attacker / Utility Support.\n*   **Type Matchups:** It is **weak to Fire, Ice, Flying, and Psychic** types. It **resists Water, Electric, Fighting, Fairy, and Grass** types.\n*   **Move Selection:** Capitalizing on its higher Special Attack and utility capabilities, key moves include **Sludge Bomb** (STAB), **Giga Drain** (for sustainability), **Leech Seed** (to sap opponent health), and **Sleep Powder** (for crowd control).\n*   **Abilities:**\n    *   **Overgrow:** Powers up Grass-type moves when the Pokémon's HP is low.\n    *   **Chlorophyll (Hidden):** Doubles the Pokémon's Speed stat during strong sunlight, making it a viable sweeper on Sun teams.\n\n## Evolution & Biology\nBulbasaur is the first stage of a 3-stage evolutionary line. It evolves into **Ivysaur** starting at **Level 16**, which eventually evolves into **Venusaur** starting at **Level 32**. It belongs to the **Monster** and **Plant** Egg Groups, with a hatch counter of approximately 20 cycles. As it prepares to evolve, the bulb on its back is known to flicker with a blue light.",
#   'thought_signature': '...'},
#  {'role': 'user',
#   'content': 'Here is the data for charizard:\n```json\n{\n  "pokemon_details": {\n    "id": 6,\n    "name": "charizard",\n    "stats": {\n      "hp": 78,\n      "attack": 84,\n      "defense": 78,\n      "special-attack": 109,\n      "special-defense": 85,\n      "speed": 100\n    },\n    "types": [\n      "fire",\n      "flying"\n    ],\n    "height_m": 1.7,\n    "weight_kg": 90.5,\n    "abilities": [\n      {\n        "name": "blaze",\n        "is_hidden": false,\n        "slot": 1\n      },\n      {\n        "name": "solar-power",\n        "is_hidden": true,\n        "slot": 3\n      }\n    ],\n    "forms": [\n      "charizard"\n    ],\n    "moves": [\n      "mega-punch",\n      "fire-punch",\n      "thunder-punch",\n      "scratch",\n      "swords-dance",\n      "cut",\n      "wing-attack",\n      "fly",\n      "mega-kick",\n      "headbutt",\n      "body-slam",\n      "take-down",\n      "double-edge",\n      "leer",\n      "bite",\n      "growl",\n      "roar",\n      "ember",\n      "flamethrower",\n      "hyper-beam",\n      "submission",\n      "counter",\n      "seismic-toss",\n      "strength",\n      "solar-beam",\n      "dragon-rage",\n      "fire-spin",\n      "earthquake",\n      "fissure",\n      "dig",\n      "toxic",\n      "rage",\n      "mimic",\n      "double-team",\n      "smokescreen",\n      "defense-curl",\n      "reflect",\n      "bide",\n      "fire-blast",\n      "swift",\n      "skull-bash",\n      "fury-swipes",\n      "rest",\n      "rock-slide",\n      "slash",\n      "substitute",\n      "snore",\n      "curse",\n      "protect",\n      "scary-face",\n      "belly-drum",\n      "mud-slap",\n      "outrage",\n      "sandstorm",\n      "endure",\n      "false-swipe",\n      "swagger",\n      "fury-cutter",\n      "steel-wing",\n      "attract",\n      "sleep-talk",\n      "return",\n      "frustration",\n      "dynamic-punch",\n      "dragon-breath",\n      "iron-tail",\n      "metal-claw",\n      "hidden-power",\n      "twister",\n      "sunny-day",\n      "crunch",\n      "ancient-power",\n      "rock-smash",\n      "beat-up",\n      "heat-wave",\n      "will-o-wisp",\n      "facade",\n      "focus-punch",\n      "helping-hand",\n      "brick-break",\n      "secret-power",\n      "blaze-kick",\n      "blast-burn",\n      "weather-ball",\n      "air-cutter",\n      "overheat",\n      "rock-tomb",\n      "aerial-ace",\n      "dragon-claw",\n      "dragon-dance",\n      "roost",\n      "natural-gift",\n      "tailwind",\n      "fling",\n      "flare-blitz",\n      "air-slash",\n      "dragon-pulse",\n      "dragon-rush",\n      "focus-blast",\n      "giga-impact",\n      "shadow-claw",\n      "fire-fang",\n      "defog",\n      "captivate",\n      "ominous-wind",\n      "hone-claws",\n      "flame-burst",\n      "flame-charge",\n      "round",\n      "echoed-voice",\n      "sky-drop",\n      "incinerate",\n      "acrobatics",\n      "inferno",\n      "fire-pledge",\n      "bulldoze",\n      "dragon-tail",\n      "work-up",\n      "heat-crash",\n      "hurricane",\n      "confide",\n      "mystical-fire",\n      "power-up-punch",\n      "brutal-swing",\n      "breaking-swipe",\n      "scale-shot",\n      "dual-wingbeat",\n      "scorching-sands",\n      "tera-blast",\n      "dragon-cheer",\n      "temper-flare"\n    ],\n    "held_items": [],\n    "base_experience": 240,\n    "is_default": true,\n    "order": 7,\n    "sprites": {\n      "front_default": "https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/6.png",\n      "back_default": "https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/back/6.png",\n      "front_shiny": "https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/6.png"\n    },\n    "species_name": "charizard",\n    "flavor_text": "Spits fire that is hot enough to melt boulders. Known to cause forest fires unintentionally.",\n    "genus": "Flame Pok\\u00e9mon",\n    "is_legendary": false,\n    "is_mythical": false,\n    ...
#  {'role': 'assistant',
#   'content': "## Identity & Lore\nCharizard (Pokedex #006) is the iconic Flame Pokémon introduced in Generation I (Kanto). A powerful, draconic creature with orange scales and large wings, it seeks out strong opponents and breathes fire of such intense heat that it can melt boulders. While generally noble, it is known to unintentionally cause forest fires with its breath. Charizard inhabits rugged mountains and valleys. Though it resembles a dragon, its base form is strictly Fire/Flying; however, it possesses immense latent potential, capable of undergoing Mega Evolution into two distinct forms—**Mega Charizard X** (gaining the Dragon type) and **Mega Charizard Y** (summoning sunlight)—as well as achieving a colossal **Gigantamax** form in the Galar region.\n\n## Combat Profile\n*   **Stats:** HP 78, Attack 84, Defense 78, Sp. Atk 109, Sp. Def 85, Speed 100.\n*   **Archetype:** Fast Special Sweeper / Wallbreaker.\n*   **Type Matchups:** As a dual Fire/Flying type, Charizard possesses a **Double Weakness (4x) to Rock** attacks (such as Stealth Rock). It is also weak to Water and Electric moves. Conversely, it is immune to Ground moves and boasts a **Double Resistance (4x) to Grass and Bug**, while also resisting Steel, Fire, Fairy, and Fighting types.\n*   **Move Selection:** Capitalizing on its superior Special Attack (109) and Speed (100), an optimal move set includes **Fire Blast** or **Flamethrower** for reliable STAB (Same Type Attack Bonus), **Air Slash** (or Hurricane) for Flying coverage, **Solar Beam** to counter Water and Rock types (ideally used in harsh sunlight), and **Roost** or **Focus Blast** for utility and coverage.\n*   **Abilities:**\n    *   **Blaze:** Powers up Fire-type moves when the Pokémon's HP is low.\n    *   **Solar Power (Hidden Ability):** Boosts Special Attack by 1.5x during strong sunlight but drains HP at the end of each turn, making it a premier threat on Sun teams.\n\n## Evolution & Biology\nCharizard is the final stage of a 3-stage evolutionary line. It evolves from **Charmeleon** starting at **Level 36**, which is the evolved form of **Charmander** (acquired at Level 16). It belongs to the **Monster** and **Dragon** Egg Groups, with a hatch counter of 20 cycles.",
#   'thought_signature': '...'}]
