# %%
# imports
import random
import os
import json
import time
import concurrent.futures
from pathlib import Path
import threading
import requests

import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from ai_tools.tools import LLMQuery
from pokemon_tools import PokemonAPIClient

# %%
a = PokemonAPIClient()
a.get_item_info("potion")
# Out:
# {'id': 17,
#  'name': 'potion',
#  'cost': 200,
#  'category': 'healing',
#  'attributes': ['countable',
#   'consumable',
#   'usable-overworld',
#   'usable-in-battle',
#   'holdable'],
#  'effect_entries': [{'effect': 'Used on a friendly Pokémon\n:   Restores 20 HP.',
#    'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#    'short_effect': 'Restores 20 HP.'}],
#  'flavor_text_entries': [{'language': {'name': 'en',
#     'url': 'https://pokeapi.co/api/v2/language/9/'},
#    'text': 'A spray-type medicine for treating wounds. It can be used to restore 20 HP to an injured Pokémon.',
#    'version_group': {'name': 'x-y',
#     'url': 'https://pokeapi.co/api/v2/version-group/15/'}}],
#  'held_by_pokemon': ['zigzagoon', 'linoone'],
#  'total_held_by': 2,
#  'machines': [],
#  'baby_trigger_for': None,
#  'sling_power': 30,
#  'fling_effect': None,
#  'generation': 'generation-iii',
#  'generation_info': {'name': 'Generation III', 'region': 'Hoenn'}}

# %%
SYSTEM_PROMPT = """You are an expert Pokémon Data Analyst and Lorekeeper. Your task is to process raw JSON data into a **semantically dense, natural language profile** optimized for Vector Search retrieval (RAG).

### Core Instruction:
Use the provided JSON as the **primary source** for facts (Stats, Moves, Evolution), but use your **World Knowledge** to expand on behavior, competitive viability, and lore. The goal is to maximize the number of relevant searchable keywords (moves, abilities, behaviors) in the output.

### STRICT Output Constraints:
1.  **NO Conversational Filler:** Start immediately with the Markdown headers. Do not say "Here is the profile."
2.  **Naturalize the ID:** Include the Pokémon's ID (e.g., #006) naturally in the first sentence of the Identity section.
3.  **Omit Empty Data:** If a field is empty (e.g., `held_items` or `forms`), skip it entirely.
4.  **Format:** Use Markdown headers (`##`) for sections.

### Processing Guidelines:

**1. Identity & Lore (Expand this)**
* **Variant Detection:** Check the `name` field. If it contains suffixes like `-alola`, `-galar`, `-hisui`, or `-paldea`, explicitly name it as the **[Region]n Form** (e.g., convert `vulpix-alola` to "Alolan Vulpix").
* **Bio Synthesis:** Combine `genus`, `flavor_text`, `habitat`, `generation`, and `color` into a cohesive summary.
* **Form Potential (World Knowledge):** Explicitly mention if this Pokémon has **Mega Evolutions**, **Gigantamax forms**, or **Paradox forms**, even if they are not listed in the JSON.
* **Context:** Mention the specific region associated with the generation (e.g., "Generation I (Kanto)").

**2. Combat Profile (Detailed Analysis)**
* **Stat Block:** You **MUST** list the specific Base Stats in a list format using these standard abbreviations: **HP, Attack, Defense, Sp. Atk, Sp. Def, Speed**.
* **Archetype:** Analyze the stats to assign a competitive role (e.g., "Fast Special Sweeper," "Physical Tank," "Mixed Attacker").
* **Type Matchups:**
    * Explicitly list **Weaknesses** and **Resistances**.
    * **Logic Check:** If a Pokémon has a double weakness (e.g., Fire/Flying vs. Rock), explicitly label it as a **"Double Weakness (4x)."**
* **Smart Move Selection:** Select 4 specific moves that align with the Pokémon's **highest offensive stat**. (e.g., If Sp. Atk > Attack, list *Flamethrower*, not *Fire Punch*). Include Utility moves (Recover, Roost) if relevant.
* **Abilities:** Name the abilities and briefly explain their tactical effect.

**3. Evolution & Acquisition**
* **Detailed Chain:** Narrate the full evolutionary line.
* **Triggers:** You must specify the **method** found in `evolution_details` (e.g., "when exposed to a Thunder Stone," "leveled up with High Friendship," "at Level 36").
* **Breeding:** Mention Egg Groups and Hatch Counters if relevant.

**4. Evolution & Biology**
* **Detailed Chain:** Narrate the full evolutionary line.
* **Triggers:** You must specify the **method** found in `evolution_details` (e.g., "when exposed to a Thunder Stone," "leveled up with High Friendship," "at Level 36").
* **Breeding:** Mention Egg Groups and Hatch Counters if relevant.

---

### Required Output Structure:

**## Identity & Lore**
[Name] (Pokedex #[ID]) is the [Genus]... [Detailed Description of appearance, habitat, and lore]... [Mention of Mega/G-Max forms if applicable]...

**## Combat Profile**
* **Stats:** HP [Val], Attack [Val], Defense [Val], Sp. Atk [Val], Sp. Def [Val], Speed [Val].
* **Archetype:** [Role Name] (e.g., Fast Special Sweeper).
* **Type Matchups:** It is **weak to [Types]** (mentioning any 4x weaknesses) and **resists [Types]**.
* **Move Selection:** Capitalizing on its stats, key moves include **[Move 1], [Move 2], [Move 3], and [Move 4]**.
* **Abilities:** [Ability Name] ([Effect description])...

**## Evolution & Biology**
[Name] is part of a [Number]-stage evolutionary line. It evolves from [Pre-evo] when [Condition]... It belongs to the [Egg Group] group...

---
**Input Data:**
[JSON Data provided in the user prompt]
"""

# %%
LIST_CACHE_FILE = Path("pokemon_list.json")

def get_all_pokemon():
    if LIST_CACHE_FILE.exists():
        print("Loading Pokemon list from cache...")
        try:
            with open(LIST_CACHE_FILE, "r") as f:
                return json.load(f)
        except Exception as e:
            print(f"Error reading cache, fetching fresh list. Error: {e}")

    print("Fetching list of all Pokemon from API...")
    url = "https://pokeapi.co/api/v2/pokemon?limit=10000"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        pokemon_list = [p["name"] for p in data["results"]]
        
        # Save to cache
        with open(LIST_CACHE_FILE, "w") as f:
            json.dump(pokemon_list, f)
        print(f"Saved {len(pokemon_list)} Pokemon to {LIST_CACHE_FILE}")
        return pokemon_list
    except Exception as e:
        print(f"Error fetching Pokemon list: {e}")
        return []

len(get_all_pokemon())

# %%
# Configuration
OUTPUT_DIR = Path("raw/pokemon")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
MODEL_NAME = "gemini-3-flash-preview"
MAX_WORKERS = 10
ABORT_LIMIT = 20

# Global state
error_count = 0
error_lock = threading.Lock()
abort_event = threading.Event()



def generate_pokemon_data(pokemon_name):
    global error_count
    
    if abort_event.is_set():
        return

    # Optimistic existing file check
    existing = list(OUTPUT_DIR.glob(f"*_{pokemon_name}.md"))
    if existing:
        # print(f"Skipping {pokemon_name} (File exists)")
        return

    # Initialize Clients (Thread-safe)
    pokemon_client = PokemonAPIClient(enable_cache=False)
    llm_client = LLMQuery(model=MODEL_NAME, system_prompt=SYSTEM_PROMPT)
    
    time.sleep(0.5)
    
    try:
        print(f"Processing {pokemon_name}...")
        details = pokemon_client.get_pokemon_details(pokemon_name)
        if "error" in details:
            raise Exception(f"API Error: {details.get('error')}")
            
        type_info = []
        for t in details.get("types", []):
            t_info = pokemon_client.get_type_info(t)
            if "error" not in t_info:
                type_info.append(t_info)

        context = {"pokemon_details": details, "type_info": type_info}
        user_prompt = f"Here is the data for {pokemon_name}:\n```json\n{json.dumps(context, indent=2)}\n```"
        
        response = None
        for attempt in range(3):
            try:
                response = llm_client.query(user_prompt=user_prompt, use_history=False)
                if response: break
            except Exception as e:
                if attempt == 2: raise e
                time.sleep(2 ** attempt)

        p_id = details.get("id", 0)
        file_prefix = f"{p_id:04d}_{pokemon_name}"
        
        with open(OUTPUT_DIR / f"{file_prefix}.json", "w", encoding="utf-8") as f:
            json.dump(context, f, indent=2)
        with open(OUTPUT_DIR / f"{file_prefix}.md", "w", encoding="utf-8") as f:
            f.write(response)
            
        print(f"Saved {file_prefix}.md")
        
    except Exception as e:
        with error_lock:
            error_count += 1
            print(f"Error processing {pokemon_name}: {e} (Count: {error_count})")
            if error_count >= ABORT_LIMIT:
                print("Aborting generation due to error limit.")
                abort_event.set()

# Main Execution
try:
    POKEMON_LIST = get_all_pokemon()
    if POKEMON_LIST:
        print(f"Starting generation for {len(POKEMON_LIST)} Pokemon with {MAX_WORKERS} threads...")
        with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
            list(executor.map(generate_pokemon_data, POKEMON_LIST))
    else:
        print("No Pokemon found to process.")
    print("Generation complete.")
except KeyboardInterrupt:
    print("Generation interrupted.")
except Exception as e:
    print(f"Fatal error: {e}")

# %%
SYSTEM_PROMPT_MOVES = """You are an expert Pokémon Battle Mechanics Analyst. Your task is to process raw JSON data for a specific **Move** into a **semantically dense, comprehensive profile** optimized for Vector Search retrieval (RAG).

### Core Instruction:
Use the JSON as the **primary source** for stats, effects, and the learner list. Use **World Knowledge** to interpret competitive viability, compare it to rival moves, and **expand on the visual/thematic description** to ensure the text is rich with searchable keywords.

### STRICT Output Constraints:
1.  **No Chatter:** Start immediately with the Markdown headers.
2.  **Smart Filtering:** Do NOT list every Pokémon in `learned_by`. Filter the list to **Prominent Users** (Starters, Legendaries, Competitive Staples).
3.  **Terminology:** Use standard competitive terms (STAB, Coverage, Check, Nuke, Pivot, Wallbreaker).

### Processing Guidelines:

**1. Identity & Flavor (Enriched)**
* **Basics:** Combine `name`, `type`, `damage_class`, and `generation`.
* **Visual Description:** Combine the provided `flavor_text` with World Knowledge to describe the **visual execution** of the move. (e.g., "The user clenches its fist to deliver a high-impact blow..."). *Constraint: Describe only the visual, do not invent new mechanics.*
* **Mechanics:** Interpret `effect_description`. Explicitly label **Secondary Effects** (e.g., "10% chance to Burn") and **Mechanics** (e.g., "Bypasses Accuracy," "Sound-based").

**2. Competitive Profile**
* **Stat Block:** List **Power, Accuracy, PP** in a bullet point.
* **Archetype:** Assign a role based on stats:
    * *Power > 100 / Low Acc:* "High-Risk Nuke" / "Wallbreaker."
    * *Power 80-95 / 100 Acc:* "Reliable STAB" / "Consistency Option."
    * *Status Move:* "Utility" / "Setup."
    * *Outclassed:* If the move is strictly worse than another (e.g., Mega Punch vs Return), label it as "Early-game Filler" or "Niche."
* **Context:** Compare it to its main rival (e.g., Flamethrower vs. Fire Blast).
* **Attributes:** Mention if the move makes **Contact** or has tags like **Punching, Biting, Sound, or Slice**. Explicitly name Abilities that interact with it (e.g., "Boosted by Iron Fist").

**3. Distribution & Users**
* **Learner Analysis:** Analyze the `learned_by` list.
    * **Prominent Users:** 2-3 iconic STAB users.
    * **Synergy Users:** **Crucial.** If the move interacts with an Ability (Iron Fist, Strong Jaw, etc.), list Pokémon with that ability who learn it.
    * **Coverage Users:** Non-STAB users who carry it for specific threats.
* **Acquisition:** Mention if it is a common **TM, TR, or Move Tutor** move.

---

### Required Output Structure:

**## Identity & Mechanics**
**[Move Name]** is a [Damage Class] [Type]-type move introduced in [Generation].
* **Description:** [Expanded visual/thematic description for RAG searchability].
* **Effect:** [Detailed description].
* **Secondary Effect:** [Chance]% chance to [Status/Stat Drop] (or "None").
* **Targeting:** [Single/Spread/Self].

**## Competitive Profile**
* **Stats:** Power [Val], Accuracy [Val]%, PP [Val].
* **Role:** [Archetype] (e.g., Reliable STAB / Niche).
* **Usage:** [Comparison to rivals]. It deals **Super Effective** damage to **[Weakness Types]** types.
* **Attributes:** [Contact/Sound/Punching tags]. [Interaction with Abilities if applicable].

**## Distribution & Notable Users**
It has a [Wide/Narrow] distribution ([Total] learners).
* **Prominent Users:** Commonly utilized by **[User 1]**, **[User 2]**, and **[User 3]**.
* **Synergy Users:** [If applicable, users with boosting Abilities like Iron Fist/Strong Jaw].
* **Coverage Utility:** Frequently seen on non-[Type] Pokémon like **[User 4]** to counter [Counter-Type] threats.
* **Acquisition:** Widely available via **[TM/Tutor]** in [Generations].

---
**Input Data:**
[Provided by User]"""

# %%
MOVES_LIST_CACHE_FILE = Path("moves_list.json")

def get_all_moves():
    if MOVES_LIST_CACHE_FILE.exists():
        print("Loading Moves list from cache...")
        try:
            with open(MOVES_LIST_CACHE_FILE, "r") as f:
                return json.load(f)
        except Exception as e:
            print(f"Error reading cache, fetching fresh list. Error: {e}")

    print("Fetching list of all Moves from API...")
    url = "https://pokeapi.co/api/v2/move?limit=10000"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        moves_list = [m["name"] for m in data["results"]]
        
        # Save to cache
        with open(MOVES_LIST_CACHE_FILE, "w") as f:
            json.dump(moves_list, f)
        print(f"Saved {len(moves_list)} Moves to {MOVES_LIST_CACHE_FILE}")
        return moves_list
    except Exception as e:
        print(f"Error fetching Move list: {e}")
        return []

# %%
MOVES_OUTPUT_DIR = Path("raw/move")
MOVES_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

MODEL_NAME = "gemini-3-flash-preview"
MAX_WORKERS = 10
ABORT_LIMIT = 20

# Global state for moves
moves_error_count = 0
moves_error_lock = threading.Lock()
moves_abort_event = threading.Event()



def generate_move_data(move_name):
    global moves_error_count
    
    if moves_abort_event.is_set():
        return

    # Optimistic existing file check
    existing = list(MOVES_OUTPUT_DIR.glob(f"*_{move_name}.md"))
    if existing:
        # print(f"Skipping {move_name} (File exists)")
        return

    # Initialize Clients (Thread-safe)
    pokemon_client = PokemonAPIClient(enable_cache=False)
    llm_client = LLMQuery(model=MODEL_NAME, system_prompt=SYSTEM_PROMT_MOVES)
    
    time.sleep(0.5)
    
    try:
        print(f"Processing Move: {move_name}...")
        details = pokemon_client.get_move_details(move_name, learned_by_limit=-1)
        if "error" in details:
            raise Exception(f"API Error: {details.get('error')}")
            
        context = {"move_details": details}
        user_prompt = f"Here is the data for {move_name}:\n```json\n{json.dumps(context, indent=2)}\n```"
        
        response = None
        for attempt in range(3):
            try:
                response = llm_client.query(user_prompt=user_prompt, use_history=False)
                if response: break
            except Exception as e:
                if attempt == 2: raise e
                time.sleep(2 ** attempt)

        m_id = details.get("id", 0)
        file_prefix = f"{m_id:04d}_{move_name}"
        
        with open(MOVES_OUTPUT_DIR / f"{file_prefix}.json", "w", encoding="utf-8") as f:
            json.dump(context, f, indent=2)
        with open(MOVES_OUTPUT_DIR / f"{file_prefix}.md", "w", encoding="utf-8") as f:
            f.write(response)
            
        print(f"Saved {file_prefix}.md")
        
    except Exception as e:
        with moves_error_lock:
            moves_error_count += 1
            print(f"Error processing {move_name}: {e} (Count: {moves_error_count})")
            if moves_error_count >= ABORT_LIMIT:
                print("Aborting moves generation due to error limit.")
                moves_abort_event.set()

# Main Execution for Moves
try:
    MOVES_LIST = get_all_moves()
    if MOVES_LIST:
        print(f"Starting generation for {len(MOVES_LIST)} Moves with {MAX_WORKERS} threads...")
        with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
            list(executor.map(generate_move_data, MOVES_LIST))
    else:
        print("No Moves found to process.")
    print("Moves Generation complete.")
except KeyboardInterrupt:
    print("Moves Generation interrupted.")
except Exception as e:
    print(f"Fatal error in Moves Generation: {e}")

# %%
SYSTEM_PROMPT_ITEMS = """You are an expert Pokémon Inventory Manager and Competitive Analyst. Your task is to process raw JSON data for a specific **Item** into a **semantically dense, comprehensive profile** optimized for Vector Search retrieval (RAG).

### Core Instruction:
Use the JSON as the **primary source** for costs, effects, and attributes. Use **World Knowledge** to contextualize the item's utility (e.g., "Is this a competitive staple like Leftovers, or a consumable medicine like Potion?").

### STRICT Output Constraints:
1.  **No Chatter:** Start immediately with the Markdown headers.
2.  **Categorization:** Clearly distinguish between **Consumable Medicines**, **Competitive Held Items**, **Poké Balls**, and **Evolution Items**.
3.  **Economy:** Interpret the `cost`. (e.g., 200 is "Cheap/Accessible", 0 usually implies "Key Item" or "Special Acquisition").

### Processing Guidelines:

**1. Identity & Classification**
* **Basics:** Combine `name`, `category`, and `cost`.
* **Description:** Merge the `flavor_text` with the `attributes` (e.g., `usable-overworld`, `holdable`) to describe *how* it is used.
* **World Knowledge:** If the item is part of a hierarchy (e.g., Potion < Super Potion < Hyper Potion), explicitly mention its tier (e.g., "Basic early-game healing").

**2. Effect & Mechanics (Detailed)**
* **Primary Effect:** derived from `effect_entries`. Be specific (e.g., "Restores 20 HP" vs "Restores 200 HP").
* **Secondary Mechanics:**
    * **Fling:** If `sling_power` (Fling Power) is > 0, mention it.
    * **Natural Gift:** If it is a **Berry**, mention its Natural Gift type/power via World Knowledge.
    * **Evolution:** If `baby_trigger_for` is present or it is an Evolution Stone, specify which Pokémon evolve with it.

**3. Acquisition & Context**
* **Availability:** Interpret `held_by_pokemon`. If it is held by common Pokémon (like Zigzagoon), mention it as a farming source.
* **Competitive Viability:**
    * *Medicine:* "Used primarily in playthroughs/Nuzlockes."
    * *Held Item:* "Competitive Staple" (e.g., Life Orb) or "Niche."

---

### Required Output Structure:

**## Identity & Utility**
**[Item Name]** is a [Category] introduced in [Generation].
* **Description:** [Flavor text + usage context]. It is a [Consumable/Held/Key] item that [Can/Cannot] be bought.
* **Cost:** [Cost] Poké Dollars ([Cheap/Expensive/Not for sale]).

**## Effect & Mechanics**
* **Primary Effect:** [Detailed effect description].
* **Battle Attributes:**
    * **Fling Power:** [Value] (Effect if applicable).
    * **Competitive Use:** [Context: Is it used in VGC/Smogon? Or just for the story?].
* **Evolution/Interaction:** [Mentions if it evolves specific Pokémon or interacts with abilities like Pickup/Klutz].

**## Acquisition & Lore**
* **Availability:** [Mart availability or special location].
* **Wild Held Item:** Occasionally found on wild **[Pokemon 1]** and **[Pokemon 2]** (often gathered via the **Pickup** ability).

---
**Input Data:**
[JSON is provided by the user]"""

# %%
ITEMS_LIST_CACHE_FILE = Path("items_list.json")

def get_all_items():
    if ITEMS_LIST_CACHE_FILE.exists():
        print("Loading Items list from cache...")
        try:
            with open(ITEMS_LIST_CACHE_FILE, "r") as f:
                return json.load(f)
        except Exception as e:
            print(f"Error reading cache, fetching fresh list. Error: {e}")

    print("Fetching list of all Items from API...")
    url = "https://pokeapi.co/api/v2/item?limit=10000"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        items_list = [i["name"] for i in data["results"]]
        
        # Save to cache
        with open(ITEMS_LIST_CACHE_FILE, "w") as f:
            json.dump(items_list, f)
        print(f"Saved {len(items_list)} Items to {ITEMS_LIST_CACHE_FILE}")
        return items_list
    except Exception as e:
        print(f"Error fetching Item list: {e}")
        return []

ITEMS_OUTPUT_DIR = Path("raw/item")
ITEMS_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

MODEL_NAME = "gemini-3-flash-preview"
MAX_WORKERS = 10
ABORT_LIMIT = 20

# Global state for items
items_error_count = 0
items_error_lock = threading.Lock()
items_abort_event = threading.Event()

def generate_item_data(item_name):
    global items_error_count
    
    if items_abort_event.is_set():
        return

    # Optimistic existing file check
    existing = list(ITEMS_OUTPUT_DIR.glob(f"*_{item_name}.md"))
    if existing:
        # print(f"Skipping {item_name} (File exists)")
        return

    # Initialize Clients (Thread-safe)
    pokemon_client = PokemonAPIClient(enable_cache=False)
    llm_client = LLMQuery(model=MODEL_NAME, system_prompt=SYSTEM_PROMPT_ITEMS)
    
    time.sleep(0.5)
    
    try:
        print(f"Processing Item: {item_name}...")
        details = pokemon_client.get_item_info(item_name, held_by_limit=-1)
        if "error" in details:
            raise Exception(f"API Error: {details.get('error')}")
            
        context = {"item_details": details}
        user_prompt = f"Here is the data for {item_name}:\n```json\n{json.dumps(context, indent=2)}\n```"
        
        response = None
        for attempt in range(3):
            try:
                response = llm_client.query(user_prompt=user_prompt, use_history=False)
                if response: break
            except Exception as e:
                if attempt == 2: raise e
                time.sleep(2 ** attempt)

        i_id = details.get("id", 0)
        file_prefix = f"{i_id:04d}_{item_name}"
        
        with open(ITEMS_OUTPUT_DIR / f"{file_prefix}.json", "w", encoding="utf-8") as f:
            json.dump(context, f, indent=2)
        with open(ITEMS_OUTPUT_DIR / f"{file_prefix}.md", "w", encoding="utf-8") as f:
            f.write(response)
            
        print(f"Saved {file_prefix}.md")
        
    except Exception as e:
        with items_error_lock:
            items_error_count += 1
            print(f"Error processing {item_name}: {e} (Count: {items_error_count})")
            if items_error_count >= ABORT_LIMIT:
                print("Aborting items generation due to error limit.")
                items_abort_event.set()

# Main Execution for Items
try:
    ITEMS_LIST = get_all_items()
    if ITEMS_LIST:
        print(f"Starting generation for {len(ITEMS_LIST)} Items with {MAX_WORKERS} threads...")
        with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
            list(executor.map(generate_item_data, ITEMS_LIST))
    else:
        print("No Items found to process.")
    print("Items Generation complete.")
except KeyboardInterrupt:
    print("Items Generation interrupted.")
except Exception as e:
    print(f"Fatal error in Items Generation: {e}")
# Out:
# Loading Items list from cache...
# Starting generation for 2180 Items with 10 threads...
# Processing Item: net-ball...
# Processing Item: dive-ball...
# Processing Item: luxury-ball...
# Processing Item: nest-ball...
# Processing Item: repeat-ball...
# Processing Item: heal-ball...
# Processing Item: dusk-ball...
# Processing Item: timer-ball...
# Processing Item: quick-ball...
# Processing Item: premier-ball...
# Saved 0012_premier-ball.md
# Saved 0007_dive-ball.md
# Processing Item: cherish-ball...
# Saved 0015_quick-ball.md
# Saved 0008_nest-ball.md
# Processing Item: potion...
# Saved 0006_net-ball.md
# Saved 0014_heal-ball.md
# Processing Item: antidote...
# Processing Item: burn-heal...
# Processing Item: ice-heal...
# Processing Item: awakening...
# Saved 0010_timer-ball.md
# Saved 0009_repeat-ball.md
# Saved 0011_luxury-ball.md
# Processing Item: paralyze-heal...
# Processing Item: full-restore...
# Saved 0013_dusk-ball.md
# Processing Item: max-potion...
# Processing Item: hyper-potion...
# Saved 0017_potion.md
# Processing Item: super-potion...
# Saved 0020_ice-heal.md
# Processing Item: full-heal...
# Saved 0023_full-restore.md
# Saved 0022_paralyze-heal.md
# Saved 0019_burn-heal.md
# Saved 0018_antidote.md
# Processing Item: revive...
# Saved 0016_cherish-ball.md
# Processing Item: max-revive...
# Processing Item: fresh-water...
# Processing Item: soda-pop...
# Processing Item: lemonade...
# Saved 0024_max-potion.md
# Processing Item: moomoo-milk...
# Saved 0021_awakening.md
# Processing Item: energy-powder...
# Saved 0025_hyper-potion.md
# Processing Item: energy-root...
# Saved 0026_super-potion.md
# Processing Item: heal-powder...
# Saved 0027_full-heal.md
# Processing Item: revival-herb...
# Saved 0032_lemonade.md
# Processing Item: ether...
# Saved 0030_fresh-water.md
# Saved 0031_soda-pop.md
# Processing Item: max-ether...
# Saved 0028_revive.md
# Processing Item: elixir...
# Saved 0033_moomoo-milk.md
# Processing Item: max-elixir...
# Saved 0029_max-revive.md
# Processing Item: lava-cookie...
# Processing Item: berry-juice...
# Saved 0034_energy-powder.md
# Processing Item: sacred-ash...
# Saved 0035_energy-root.md
# Processing Item: hp-up...
# Saved 0036_heal-powder.md
# Processing Item: protein...
# Saved 0037_revival-herb.md
# Saved 0040_elixir.md
# Processing Item: iron...
# Processing Item: carbos...
# Saved 0039_max-ether.md
# Saved 0041_max-elixir.md
# Saved 0043_berry-juice.md
# Processing Item: calcium...
# Processing Item: rare-candy...
# Saved 0038_ether.md
# Processing Item: pp-up...
# Processing Item: zinc...
# Saved 0042_lava-cookie.md
# Processing Item: pp-max...
# Saved 0044_sacred-ash.md
# Processing Item: old-gateau...
# Saved 0045_hp-up.md
# Processing Item: guard-spec...
# Saved 0046_protein.md
# Processing Item: dire-hit...
# Saved 0047_iron.md
# Saved 0053_pp-max.md
# Processing Item: x-attack...
# Saved 0052_zinc.md
# Processing Item: x-defense...
# Processing Item: x-speed...
# Saved 0051_pp-up.md
# Saved 0049_calcium.md
# Saved 0048_carbos.md
# Processing Item: x-accuracy...
# Processing Item: x-sp-atk...
# Saved 0050_rare-candy.md
# Processing Item: x-sp-def...
# Processing Item: poke-doll...
# Saved 0054_old-gateau.md
# Processing Item: fluffy-tail...
# Saved 0055_guard-spec.md
# Processing Item: blue-flute...
# Saved 0056_dire-hit.md
# Processing Item: yellow-flute...
# Saved 0057_x-attack.md
# Processing Item: red-flute...
# Saved 0059_x-speed.md
# Processing Item: black-flute...
# Saved 0058_x-defense.md
# Saved 0061_x-sp-atk.md
# Processing Item: white-flute...
# Saved 0063_poke-doll.md
# Saved 0060_x-accuracy.md
# Processing Item: shoal-salt...
# Processing Item: shoal-shell...
# Processing Item: red-shard...
# Saved 0062_x-sp-def.md
# Processing Item: blue-shard...
# Saved 0065_blue-flute.md
# Processing Item: yellow-shard...
# Saved 0064_fluffy-tail.md
# Processing Item: green-shard...
# Saved 0066_yellow-flute.md
# Processing Item: super-repel...
# Saved 0067_red-flute.md
# Processing Item: max-repel...
# Saved 0068_black-flute.md
# Saved 0071_shoal-shell.md
# Processing Item: escape-rope...
# Processing Item: repel...
# Saved 0070_shoal-salt.md
# Processing Item: sun-stone...
# Saved 0069_white-flute.md
# Processing Item: moon-stone...
# Saved 0073_blue-shard.md
# Processing Item: fire-stone...
# Saved 0072_red-shard.md
# Processing Item: thunder-stone...
# Saved 0074_yellow-shard.md
# Processing Item: water-stone...
# Saved 0075_green-shard.md
# Processing Item: leaf-stone...
# Saved 0076_super-repel.md
# Saved 0077_max-repel.md
# Processing Item: tiny-mushroom...
# Saved 0078_escape-rope.md
# Saved 0079_repel.md
# Processing Item: big-mushroom...
# Processing Item: pearl...
# Processing Item: big-pearl...
# Saved 0080_sun-stone.md
# Processing Item: stardust...
# Saved 0081_moon-stone.md
# Saved 0084_water-stone.md
# Processing Item: star-piece...
# Saved 0083_thunder-stone.md
# Processing Item: nugget...
# Saved 0082_fire-stone.md
# Processing Item: heart-scale...
# Processing Item: honey...
# Saved 0085_leaf-stone.md
# Processing Item: growth-mulch...
# Saved 0086_tiny-mushroom.md
# Saved 0088_pearl.md
# Processing Item: damp-mulch...
# Processing Item: stable-mulch...
# Saved 0087_big-mushroom.md
# Processing Item: gooey-mulch...
# Saved 0089_big-pearl.md
# Processing Item: root-fossil...
# Saved 0090_stardust.md
# Processing Item: claw-fossil...
# Saved 0093_heart-scale.md
# Processing Item: helix-fossil...
# Saved 0092_nugget.md
# Saved 0091_star-piece.md
# Processing Item: dome-fossil...
# Processing Item: old-amber...
# Saved 0094_honey.md
# Saved 0095_growth-mulch.md
# Processing Item: armor-fossil...
# Processing Item: skull-fossil...
# Saved 0097_stable-mulch.md
# Saved 0099_root-fossil.md
# Processing Item: rare-bone...
# Saved 0098_gooey-mulch.md
# Processing Item: shiny-stone...
# Processing Item: dusk-stone...
# Saved 0096_damp-mulch.md
# Processing Item: dawn-stone...
# Saved 0100_claw-fossil.md
# Processing Item: oval-stone...
# Saved 0101_helix-fossil.md
# Processing Item: odd-keystone...
# Saved 0103_old-amber.md
# Processing Item: adamant-orb...
# Saved 0104_armor-fossil.md
# Processing Item: lustrous-orb...
# Saved 0102_dome-fossil.md
# Processing Item: grass-mail...
# Saved 0105_skull-fossil.md
# Processing Item: flame-mail...
# Saved 0108_dusk-stone.md
# Processing Item: bubble-mail...
# Saved 0106_rare-bone.md
# Saved 0107_shiny-stone.md
# Processing Item: bloom-mail...
# Processing Item: tunnel-mail...
# Saved 0109_dawn-stone.md
# Saved 0110_oval-stone.md
# Processing Item: steel-mail...
# Saved 0111_odd-keystone.md
# Processing Item: heart-mail...
# Processing Item: snow-mail...
# Saved 0113_lustrous-orb.md
# Processing Item: space-mail...
# Saved 0112_adamant-orb.md
# Processing Item: air-mail...
# Saved 0114_grass-mail.md
# Processing Item: mosaic-mail...
# Saved 0115_flame-mail.md
# Saved 0116_bubble-mail.md
# Processing Item: brick-mail...
# Saved 0118_tunnel-mail.md
# Processing Item: cheri-berry...
# Processing Item: chesto-berry...
# Saved 0117_bloom-mail.md
# Processing Item: pecha-berry...
# Saved 0119_steel-mail.md
# Processing Item: rawst-berry...
# Saved 0120_heart-mail.md
# Processing Item: aspear-berry...
# Saved 0121_snow-mail.md
# Saved 0123_air-mail.md
# Processing Item: leppa-berry...
# Processing Item: oran-berry...
# Saved 0124_mosaic-mail.md
# Saved 0122_space-mail.md
# Processing Item: persim-berry...
# Processing Item: sitrus-berry...
# Saved 0125_brick-mail.md
# Saved 0126_cheri-berry.md
# Processing Item: figy-berry...
# Processing Item: wiki-berry...
# Saved 0127_chesto-berry.md
# Processing Item: mago-berry...
# Saved 0128_pecha-berry.md
# Processing Item: aguav-berry...
# Saved 0129_rawst-berry.md
# Processing Item: iapapa-berry...
# Saved 0130_aspear-berry.md
# Processing Item: razz-berry...
# Saved 0132_oran-berry.md
# Processing Item: bluk-berry...
# Saved 0135_sitrus-berry.md
# Saved 0133_persim-berry.md
# Processing Item: nanab-berry...
# Saved 0131_leppa-berry.md
# Processing Item: wepear-berry...
# Processing Item: pinap-berry...
# Saved 0136_figy-berry.md
# Saved 0138_mago-berry.md
# Processing Item: pomeg-berry...
# Processing Item: kelpsy-berry...
# Saved 0137_wiki-berry.md
# Processing Item: qualot-berry...
# Saved 0139_aguav-berry.md
# Saved 0142_bluk-berry.md
# Saved 0140_iapapa-berry.md
# Processing Item: hondew-berry...
# Processing Item: grepa-berry...
# Processing Item: tamato-berry...
# Saved 0141_razz-berry.md
# Processing Item: cornn-berry...
# Saved 0144_wepear-berry.md
# Processing Item: magost-berry...
# Saved 0145_pinap-berry.md
# Processing Item: rabuta-berry...
# Saved 0143_nanab-berry.md
# Processing Item: nomel-berry...
# Saved 0147_kelpsy-berry.md
# Saved 0146_pomeg-berry.md
# Processing Item: spelon-berry...
# Processing Item: pamtre-berry...
# Saved 0148_qualot-berry.md
# Saved 0151_tamato-berry.md
# Processing Item: watmel-berry...
# Processing Item: durin-berry...
# Saved 0149_hondew-berry.md
# Saved 0150_grepa-berry.md
# Processing Item: belue-berry...
# Processing Item: occa-berry...
# Saved 0152_cornn-berry.md
# Processing Item: passho-berry...
# Saved 0153_magost-berry.md
# Saved 0155_nomel-berry.md
# Processing Item: wacan-berry...
# Processing Item: rindo-berry...
# Saved 0154_rabuta-berry.md
# Processing Item: yache-berry...
# Saved 0157_pamtre-berry.md
# Processing Item: chople-berry...
# Saved 0160_belue-berry.md
# Saved 0159_durin-berry.md
# Processing Item: kebia-berry...
# Processing Item: shuca-berry...
# Saved 0156_spelon-berry.md
# Processing Item: payapa-berry...
# Saved 0158_watmel-berry.md
# Processing Item: tanga-berry...
# Saved 0162_passho-berry.md
# Processing Item: charti-berry...
# Saved 0161_occa-berry.md
# Processing Item: kasib-berry...
# Saved 0164_rindo-berry.md
# Processing Item: haban-berry...
# Saved 0163_wacan-berry.md
# Processing Item: colbur-berry...
# Saved 0165_yache-berry.md
# Saved 0167_kebia-berry.md
# Processing Item: babiri-berry...
# Processing Item: chilan-berry...
# Saved 0166_chople-berry.md
# Saved 0168_shuca-berry.md
# Processing Item: liechi-berry...
# Processing Item: ganlon-berry...
# Saved 0170_payapa-berry.md
# Processing Item: salac-berry...
# Saved 0171_tanga-berry.md
# Processing Item: petaya-berry...
# Saved 0172_charti-berry.md
# Saved 0174_haban-berry.md
# Processing Item: apicot-berry...
# Processing Item: lansat-berry...
# Saved 0173_kasib-berry.md
# Processing Item: starf-berry...
# Saved 0175_colbur-berry.md
# Processing Item: enigma-berry...
# Saved 0177_chilan-berry.md
# Saved 0176_babiri-berry.md
# Processing Item: micle-berry...
# Processing Item: custap-berry...
# Saved 0178_liechi-berry.md
# Processing Item: jaboca-berry...
# Saved 0179_ganlon-berry.md
# Processing Item: rowap-berry...
# Saved 0180_salac-berry.md
# Processing Item: bright-powder...
# Saved 0181_petaya-berry.md
# Processing Item: white-herb...
# Saved 0182_apicot-berry.md
# Processing Item: macho-brace...
# Saved 0183_lansat-berry.md
# Processing Item: exp-share...
# Saved 0186_micle-berry.md
# Processing Item: quick-claw...
# Saved 0185_enigma-berry.md
# Processing Item: soothe-bell...
# Saved 0184_starf-berry.md
# Processing Item: mental-herb...
# Saved 0188_jaboca-berry.md
# Saved 0187_custap-berry.md
# Processing Item: kings-rock...
# Processing Item: choice-band...
# Saved 0189_rowap-berry.md
# Processing Item: silver-powder...
# Saved 0191_white-herb.md
# Saved 0190_bright-powder.md
# Processing Item: amulet-coin...
# Processing Item: cleanse-tag...
# Saved 0192_macho-brace.md
# Processing Item: soul-dew...
# Saved 0193_exp-share.md
# Saved 0194_quick-claw.md
# Processing Item: deep-sea-tooth...
# Processing Item: deep-sea-scale...
# Saved 0196_mental-herb.md
# Saved 0197_choice-band.md
# Saved 0195_soothe-bell.md
# Processing Item: smoke-ball...
# Processing Item: everstone...
# Processing Item: focus-band...
# Saved 0199_silver-powder.md
# Processing Item: lucky-egg...
# Saved 0198_kings-rock.md
# Processing Item: scope-lens...
# Saved 0200_amulet-coin.md
# Processing Item: metal-coat...
# Saved 0204_deep-sea-scale.md
# Saved 0201_cleanse-tag.md
# Processing Item: leftovers...
# Processing Item: dragon-scale...
# Saved 0203_deep-sea-tooth.md
# Saved 0202_soul-dew.md
# Processing Item: light-ball...
# Processing Item: soft-sand...
# Saved 0205_smoke-ball.md
# Processing Item: hard-stone...
# Saved 0206_everstone.md
# Processing Item: miracle-seed...
# Saved 0209_scope-lens.md
# Processing Item: black-glasses...
# Saved 0207_focus-band.md
# Saved 0208_lucky-egg.md
# Processing Item: black-belt...
# Processing Item: magnet...
# Saved 0212_dragon-scale.md
# Saved 0211_leftovers.md
# Saved 0210_metal-coat.md
# Processing Item: mystic-water...
# Processing Item: sharp-beak...
# Processing Item: poison-barb...
# Saved 0214_soft-sand.md
# Saved 0213_light-ball.md
# Processing Item: never-melt-ice...
# Processing Item: spell-tag...
# Saved 0215_hard-stone.md
# Processing Item: twisted-spoon...
# Saved 0216_miracle-seed.md
# Saved 0217_black-glasses.md
# Processing Item: charcoal...
# Processing Item: dragon-fang...
# Saved 0219_magnet.md
# Saved 0218_black-belt.md
# Processing Item: silk-scarf...
# Processing Item: up-grade...
# Saved 0222_poison-barb.md
# Processing Item: shell-bell...
# Saved 0220_mystic-water.md
# Saved 0221_sharp-beak.md
# Processing Item: sea-incense...
# Processing Item: lax-incense...
# Saved 0223_never-melt-ice.md
# Processing Item: lucky-punch...
# Saved 0224_spell-tag.md
# Processing Item: metal-powder...
# Saved 0226_charcoal.md
# Processing Item: thick-club...
# Saved 0228_silk-scarf.md
# Processing Item: stick...
# Saved 0227_dragon-fang.md
# Saved 0225_twisted-spoon.md
# Saved 0229_up-grade.md
# Processing Item: red-scarf...
# Processing Item: blue-scarf...
# Processing Item: pink-scarf...
# Saved 0230_shell-bell.md
# Saved 0233_lucky-punch.md
# Processing Item: green-scarf...
# Processing Item: yellow-scarf...
# Saved 0234_metal-powder.md
# Saved 0232_lax-incense.md
# Processing Item: wide-lens...
# Processing Item: muscle-band...
# Saved 0231_sea-incense.md
# Processing Item: wise-glasses...
# Saved 0235_thick-club.md
# Processing Item: expert-belt...
# Saved 0236_stick.md
# Saved 0237_red-scarf.md
# Saved 0239_pink-scarf.md
# Processing Item: light-clay...
# Saved 0241_yellow-scarf.md
# Processing Item: life-orb...Processing Item: power-herb...
#
# Processing Item: toxic-orb...
# Saved 0240_green-scarf.md
# Saved 0238_blue-scarf.md
# Processing Item: flame-orb...
# Processing Item: quick-powder...
# Saved 0244_wise-glasses.md
# Saved 0242_wide-lens.md
# Saved 0243_muscle-band.md
# Processing Item: focus-sash...
# Processing Item: zoom-lens...
# Processing Item: metronome...
# Saved 0245_expert-belt.md
# Processing Item: iron-ball...
# Saved 0246_light-clay.md
# Processing Item: lagging-tail...
# Saved 0251_quick-powder.md
# Saved 0248_power-herb.md
# Processing Item: destiny-knot...
# Processing Item: black-sludge...
# Saved 0247_life-orb.md
# Processing Item: icy-rock...
# Saved 0250_flame-orb.md
# Saved 0249_toxic-orb.md
# Processing Item: smooth-rock...
# Processing Item: heat-rock...
# Saved 0252_focus-sash.md
# Saved 0254_metronome.md
# Processing Item: damp-rock...
# Processing Item: grip-claw...
# Saved 0253_zoom-lens.md
# Processing Item: choice-scarf...
# Saved 0255_iron-ball.md
# Processing Item: sticky-barb...
# Saved 0256_lagging-tail.md
# Processing Item: power-bracer...
# Saved 0257_destiny-knot.md
# Processing Item: power-belt...
# Saved 0258_black-sludge.md
# Processing Item: power-lens...
# Saved 0261_heat-rock.md
# Processing Item: power-band...
# Saved 0259_icy-rock.md
# Processing Item: power-anklet...
# Saved 0260_smooth-rock.md
# Saved 0263_grip-claw.md
# Processing Item: power-weight...
# Processing Item: shed-shell...
# Saved 0262_damp-rock.md
# Processing Item: big-root...
# Saved 0264_choice-scarf.md
# Saved 0265_sticky-barb.md
# Processing Item: flame-plate...
# Processing Item: choice-specs...
# Saved 0266_power-bracer.md
# Processing Item: splash-plate...
# Saved 0267_power-belt.md
# Processing Item: zap-plate...
# Saved 0268_power-lens.md
# Saved 0269_power-band.md
# Processing Item: meadow-plate...
# Processing Item: icicle-plate...
# Saved 0270_power-anklet.md
# Processing Item: fist-plate...
# Saved 0271_power-weight.md
# Saved 0272_shed-shell.md
# Processing Item: toxic-plate...
# Processing Item: earth-plate...
# Saved 0273_big-root.md
# Processing Item: sky-plate...
# Saved 0274_choice-specs.md
# Saved 0275_flame-plate.md
# Processing Item: mind-plate...
# Processing Item: insect-plate...
# Saved 0276_splash-plate.md
# Processing Item: stone-plate...
# Saved 0278_meadow-plate.md
# Processing Item: spooky-plate...
# Saved 0279_icicle-plate.md
# Saved 0280_fist-plate.md
# Processing Item: draco-plate...
# Processing Item: dread-plate...
# Saved 0281_toxic-plate.md
# Saved 0277_zap-plate.md
# Processing Item: iron-plate...
# Processing Item: odd-incense...
# Saved 0282_earth-plate.md
# Processing Item: rock-incense...
# Saved 0283_sky-plate.md
# Processing Item: full-incense...
# Saved 0284_mind-plate.md
# Saved 0285_insect-plate.md
# Processing Item: wave-incense...
# Processing Item: rose-incense...
# Saved 0287_spooky-plate.md
# Saved 0286_stone-plate.md
# Processing Item: luck-incense...
# Processing Item: pure-incense...
# Saved 0289_dread-plate.md
# Saved 0291_odd-incense.md
# Saved 0290_iron-plate.md
# Processing Item: electirizer...
# Processing Item: protector...
# Processing Item: magmarizer...
# Saved 0288_draco-plate.md
# Processing Item: dubious-disc...
# Saved 0293_full-incense.md
# Processing Item: reaper-cloth...
# Saved 0292_rock-incense.md
# Saved 0295_rose-incense.md
# Processing Item: razor-claw...
# Processing Item: razor-fang...
# Saved 0294_wave-incense.md
# Processing Item: tm01...
# Saved 0297_pure-incense.md
# Processing Item: tm02...
# Saved 0296_luck-incense.md
# Processing Item: tm03...
# Saved 0298_protector.md
# Saved 0300_magmarizer.md
# Processing Item: tm04...
# Processing Item: tm05...
# Saved 0299_electirizer.md
# Saved 0301_dubious-disc.md
# Processing Item: tm06...
# Processing Item: tm07...
# Saved 0302_reaper-cloth.md
# Saved 0304_razor-fang.md
# Processing Item: tm08...
# Processing Item: tm09...
# Saved 0303_razor-claw.md
# Processing Item: tm10...
# Saved 0305_tm01.md
# Saved 0306_tm02.md
# Processing Item: tm11...
# Processing Item: tm12...
# Saved 0307_tm03.md
# Processing Item: tm13...
# Saved 0308_tm04.md
# Processing Item: tm14...
# Saved 0310_tm06.md
# Processing Item: tm15...
# Saved 0311_tm07.md
# Processing Item: tm16...
# Saved 0309_tm05.md
# Processing Item: tm17...
# Saved 0312_tm08.md
# Saved 0315_tm11.md
# Saved 0313_tm09.md
# Processing Item: tm18...
# Processing Item: tm19...
# Saved 0314_tm10.md
# Processing Item: tm20...
# Processing Item: tm21...
# Saved 0316_tm12.md
# Saved 0317_tm13.md
# Processing Item: tm22...
# Processing Item: tm23...
# Saved 0318_tm14.md
# Processing Item: tm24...
# Saved 0319_tm15.md
# Saved 0320_tm16.md
# Processing Item: tm25...
# Processing Item: tm26...
# Saved 0321_tm17.md
# Processing Item: tm27...
# Saved 0322_tm18.md
# Processing Item: tm28...
# Saved 0323_tm19.md
# Processing Item: tm29...
# Saved 0325_tm21.md
# Processing Item: tm30...
# Saved 0324_tm20.md
# Processing Item: tm31...
# Saved 0327_tm23.md
# Processing Item: tm32...
# Saved 0326_tm22.md
# Processing Item: tm33...
# Saved 0330_tm26.md
# Processing Item: tm34...
# Saved 0328_tm24.md
# Saved 0329_tm25.md
# Processing Item: tm35...
# Processing Item: tm36...
# Saved 0332_tm28.md
# Saved 0335_tm31.md
# Saved 0331_tm27.md
# Processing Item: tm37...
# Processing Item: tm38...
# Processing Item: tm39...
# Saved 0333_tm29.md
# Processing Item: tm40...
# Saved 0334_tm30.md
# Processing Item: tm41...
# Saved 0336_tm32.md
# Processing Item: tm42...
# Saved 0337_tm33.md
# Processing Item: tm43...
# Saved 0338_tm34.md
# Processing Item: tm44...
# Saved 0339_tm35.md
# Saved 0343_tm39.md
# Processing Item: tm46...
# Processing Item: tm47...
# Saved 0340_tm36.md
# Processing Item: tm48...
# Saved 0345_tm41.md
# Saved 0341_tm37.md
# Processing Item: tm49...
# Saved 0344_tm40.md
# Processing Item: tm50...
# Saved 0342_tm38.md
# Processing Item: tm51...
# Processing Item: tm52...
# Saved 0346_tm42.md
# Processing Item: tm53...
# Saved 0347_tm43.md
# Processing Item: tm54...
# Saved 0348_tm44.md
# Saved 0350_tm46.md
# Processing Item: tm55...
# Processing Item: tm56...
# Saved 0351_tm47.md
# Processing Item: tm57...
# Saved 0353_tm49.md
# Saved 0354_tm50.md
# Saved 0352_tm48.md
# Saved 0355_tm51.md
# Processing Item: tm58...
# Processing Item: tm59...
# Processing Item: tm60...
# Processing Item: tm61...
# Saved 0356_tm52.md
# Processing Item: tm62...
# Saved 0357_tm53.md
# Saved 0358_tm54.md
# Processing Item: tm63...
# Processing Item: tm64...
# Saved 0360_tm56.md
# Saved 0359_tm55.md
# Processing Item: tm65...
# Processing Item: tm66...
# Saved 0361_tm57.md
# Processing Item: tm67...
# Saved 0363_tm59.md
# Processing Item: tm68...
# Saved 0366_tm62.md
# Saved 0362_tm58.md
# Processing Item: tm69...
# Processing Item: tm70...
# Saved 0365_tm61.md
# Processing Item: tm71...
# Saved 0364_tm60.md
# Processing Item: tm72...
# Saved 0367_tm63.md
# Saved 0368_tm64.md
# Processing Item: tm73...
# Processing Item: tm74...
# Saved 0369_tm65.md
# Saved 0370_tm66.md
# Processing Item: tm75...
# Processing Item: tm76...
# Saved 0371_tm67.md
# Processing Item: tm77...
# Saved 0372_tm68.md
# Processing Item: tm78...
# Saved 0375_tm71.md
# Saved 0374_tm70.md
# Processing Item: tm79...
# Processing Item: tm80...
# Saved 0373_tm69.md
# Saved 0378_tm74.md
# Saved 0377_tm73.md
# Processing Item: tm81...
# Processing Item: tm82...
# Processing Item: tm83...
# Saved 0376_tm72.md
# Processing Item: tm84...
# Saved 0379_tm75.md
# Processing Item: tm85...
# Saved 0380_tm76.md
# Processing Item: tm86...
# Saved 0384_tm80.md
# Saved 0386_tm82.md
# Saved 0382_tm78.md
# Processing Item: tm87...
# Saved 0381_tm77.md
# Processing Item: tm88...
# Processing Item: tm89...
# Saved 0383_tm79.md
# Processing Item: tm90...
# Processing Item: tm91...
# Saved 0387_tm83.md
# Processing Item: tm92...
# Saved 0388_tm84.md
# Processing Item: hm01...
# Saved 0385_tm81.md
# Processing Item: hm02...
# Saved 0389_tm85.md
# Processing Item: hm03...
# Saved 0393_tm89.md
# Saved 0392_tm88.md
# Saved 0390_tm86.md
# Processing Item: hm04...
# Processing Item: hm05...
# Processing Item: hm06...
# Saved 0391_tm87.md
# Processing Item: hm07...
# Saved 0395_tm91.md
# Processing Item: hm08...
# Saved 0397_hm01.md
# Saved 0394_tm90.md
# Processing Item: explorer-kit...
# Processing Item: loot-sack...
# Saved 0396_tm92.md
# Processing Item: rule-book...
# Saved 0398_hm02.md
# Processing Item: poke-radar...
# Saved 0399_hm03.md
# Processing Item: point-card...
# Saved 0403_hm07.md
# Saved 0400_hm04.md
# Processing Item: journal...
# Saved 0401_hm05.md
# Saved 0402_hm06.md
# Processing Item: seal-case...
# Processing Item: fashion-case...
# Processing Item: seal-bag...
# Saved 0405_explorer-kit.md
# Processing Item: pal-pad...
# Saved 0407_rule-book.md
# Saved 0404_hm08.md
# Processing Item: works-key...
# Saved 0406_loot-sack.md
# Processing Item: old-charm...
# Processing Item: galactic-key...
# Saved 0409_point-card.md
# Processing Item: red-chain...
# Saved 0408_poke-radar.md
# Processing Item: town-map...
# Saved 0411_seal-case.md
# Processing Item: vs-seeker...
# Saved 0410_journal.md
# Saved 0413_seal-bag.md
# Processing Item: coin-case...
# Processing Item: old-rod...
# Saved 0417_galactic-key.md
# Saved 0412_fashion-case.md
# Processing Item: good-rod...
# Processing Item: super-rod...
# Saved 0415_works-key.md
# Saved 0414_pal-pad.md
# Processing Item: sprayduck...
# Processing Item: poffin-case...
# Saved 0416_old-charm.md
# Processing Item: bicycle...
# Saved 0418_red-chain.md
# Processing Item: suite-key...
# Saved 0419_town-map.md
# Processing Item: oaks-letter...
# Saved 0422_old-rod.md
# Saved 0421_coin-case.md
# Processing Item: lunar-wing...
# Saved 0420_vs-seeker.md
# Processing Item: member-card...
# Processing Item: azure-flute...
# Saved 0424_super-rod.md
# Saved 0423_good-rod.md
# Processing Item: ss-ticket...
# Processing Item: contest-pass...
# Saved 0425_sprayduck.md
# Processing Item: magma-stone...
# Saved 0427_bicycle.md
# Saved 0426_poffin-case.md
# Processing Item: parcel...
# Processing Item: coupon-1...
# Saved 0428_suite-key.md
# Saved 0429_oaks-letter.md
# Processing Item: coupon-2...
# Processing Item: coupon-3...
# Saved 0432_azure-flute.md
# Processing Item: storage-key...
# Saved 0430_lunar-wing.md
# Saved 0434_contest-pass.md
# Processing Item: secret-potion...
# Processing Item: griseous-orb...
# Saved 0435_magma-stone.md
# Processing Item: vs-recorder...
# Saved 0433_ss-ticket.md
# Processing Item: gracidea...
# Saved 0431_member-card.md
# Processing Item: secret-key...
# Saved 0436_parcel.md
# Saved 0437_coupon-1.md
# Saved 0438_coupon-2.md
# Processing Item: apricorn-box...
# Processing Item: berry-pots...
# Processing Item: squirt-bottle...
# Saved 0439_coupon-3.md
# Processing Item: lure-ball...
# Saved 0440_storage-key.md
# Processing Item: level-ball...
# Saved 0443_vs-recorder.md
# Saved 0442_griseous-orb.md
# Processing Item: moon-ball...
# Processing Item: heavy-ball...
# Saved 0446_apricorn-box.md
# Processing Item: fast-ball...
# Saved 0447_berry-pots.md
# Saved 0441_secret-potion.md
# Processing Item: friend-ball...
# Processing Item: love-ball...
# Saved 0448_squirt-bottle.md
# Saved 0445_secret-key.md
# Processing Item: park-ball...
# Saved 0444_gracidea.md
# Saved 0449_lure-ball.md
# Processing Item: sport-ball...
# Processing Item: red-apricorn...
# Processing Item: blue-apricorn...
# Saved 0451_moon-ball.md
# Saved 0450_level-ball.md
# Processing Item: yellow-apricorn...
# Processing Item: green-apricorn...
# Saved 0452_heavy-ball.md
# Processing Item: pink-apricorn...
# Saved 0453_fast-ball.md
# Processing Item: white-apricorn...
# Saved 0456_park-ball.md
# Saved 0455_love-ball.md
# Processing Item: black-apricorn...
# Processing Item: dowsing-machine...
# Saved 0454_friend-ball.md
# Saved 0458_red-apricorn.md
# Saved 0457_sport-ball.md
# Processing Item: rage-candy-bar...
# Processing Item: red-orb...
# Processing Item: blue-orb...
# Saved 0459_blue-apricorn.md
# Processing Item: jade-orb...
# Saved 0461_green-apricorn.md
# Processing Item: enigma-stone...
# Saved 0460_yellow-apricorn.md
# Processing Item: unown-report...
# Saved 0462_pink-apricorn.md
# Saved 0465_dowsing-machine.md
# Processing Item: blue-card...
# Saved 0463_white-apricorn.md
# Processing Item: slowpoke-tail...
# Saved 0466_rage-candy-bar.md
# Processing Item: clear-bell...
# Saved 0467_red-orb.md
# Processing Item: card-key...
# Saved 0464_black-apricorn.md
# Processing Item: basement-key...
# Processing Item: red-scale...
# Saved 0469_jade-orb.md
# Processing Item: lost-item...
# Saved 0470_enigma-stone.md
# Saved 0468_blue-orb.md
# Processing Item: pass...
# Processing Item: machine-part...
# Saved 0471_unown-report.md
# Processing Item: silver-wing...
# Saved 0472_blue-card.md
# Saved 0474_clear-bell.md
# Processing Item: rainbow-wing...
# Processing Item: mystery-egg...
# Saved 0475_card-key.md
# Saved 0477_red-scale.md
# Processing Item: gb-sounds...
# Processing Item: tidal-bell...
# Saved 0478_lost-item.md
# Saved 0473_slowpoke-tail.md
# Saved 0476_basement-key.md
# Processing Item: data-card-01...
# Processing Item: data-card-02...
# Saved 0479_pass.md
# Processing Item: data-card-03...
# Processing Item: data-card-04...
# Saved 0480_machine-part.md
# Processing Item: data-card-05...
# Saved 0481_silver-wing.md
# Processing Item: data-card-06...
# Saved 0482_rainbow-wing.md
# Processing Item: data-card-07...
# Saved 0483_mystery-egg.md
# Saved 0485_tidal-bell.md
# Processing Item: data-card-08...
# Processing Item: data-card-09...
# Saved 0484_gb-sounds.md
# Saved 0486_data-card-01.md
# Processing Item: data-card-10...
# Processing Item: data-card-11...
# Saved 0489_data-card-04.md
# Processing Item: data-card-12...
# Saved 0487_data-card-02.md
# Saved 0490_data-card-05.md
# Processing Item: data-card-13...
# Processing Item: data-card-14...
# Saved 0491_data-card-06.md
# Saved 0488_data-card-03.md
# Processing Item: data-card-15...
# Processing Item: data-card-16...
# Saved 0494_data-card-09.md
# Saved 0493_data-card-08.md
# Saved 0492_data-card-07.md
# Processing Item: data-card-17...
# Processing Item: data-card-18...
# Processing Item: data-card-19...
# Saved 0496_data-card-11.md
# Processing Item: data-card-20...
# Saved 0495_data-card-10.md
# Processing Item: data-card-21...
# Saved 0499_data-card-14.md
# Processing Item: data-card-22...
# Saved 0501_data-card-16.mdSaved 0497_data-card-12.md
#
# Saved 0500_data-card-15.md
# Processing Item: data-card-24...
# Processing Item: data-card-23...
# Processing Item: data-card-25...
# Saved 0502_data-card-17.md
# Saved 0504_data-card-19.md
# Saved 0498_data-card-13.md
# Processing Item: data-card-26...
# Saved 0503_data-card-18.md
# Processing Item: lock-capsule...
# Processing Item: data-card-27...
# Processing Item: photo-album...
# Saved 0505_data-card-20.md
# Processing Item: orange-mail...
# Saved 0506_data-card-21.md
# Processing Item: harbor-mail...
# Saved 0507_data-card-22.md
# Processing Item: glitter-mail...
# Saved 0509_data-card-24.md
# Processing Item: mech-mail...
# Saved 0508_data-card-23.md
# Saved 0510_data-card-25.md
# Processing Item: wood-mail...
# Processing Item: wave-mail...
# Saved 0514_photo-album.md
# Processing Item: bead-mail...
# Saved 0512_data-card-27.md
# Saved 0511_data-card-26.md
# Processing Item: shadow-mail...
# Saved 0513_lock-capsule.md
# Processing Item: tropic-mail...
# Processing Item: dream-mail...
# Saved 0515_orange-mail.md
# Processing Item: fab-mail...
# Saved 0516_harbor-mail.md
# Processing Item: retro-mail...
# Saved 0517_glitter-mail.md
# Processing Item: mach-bike...
# Saved 0518_mech-mail.md
# Saved 0520_wave-mail.md
# Processing Item: acro-bike...
# Processing Item: wailmer-pail...
# Saved 0519_wood-mail.md
# Processing Item: devon-goods...
# Saved 0521_bead-mail.md
# Processing Item: soot-sack...
# Saved 0522_shadow-mail.md
# Processing Item: pokeblock-case...
# Saved 0523_tropic-mail.md
# Processing Item: letter...
# Saved 0524_dream-mail.md
# Processing Item: eon-ticket...
# Saved 0527_mach-bike.md
# Saved 0526_retro-mail.md
# Saved 0525_fab-mail.md
# Processing Item: scanner...
# Processing Item: go-goggles...
# Processing Item: meteorite...
# Saved 0530_devon-goods.md
# Processing Item: rm-1-key...
# Saved 0528_acro-bike.md
# Processing Item: rm-2-key...
# Saved 0531_soot-sack.md
# Processing Item: rm-4-key...
# Saved 0529_wailmer-pail.md
# Saved 0532_pokeblock-case.md
# Saved 0533_letter.md
# Processing Item: rm-6-key...
# Processing Item: devon-scope...
# Processing Item: oaks-parcel...
# Saved 0535_scanner.md
# Processing Item: poke-flute...
# Saved 0536_go-goggles.md
# Saved 0534_eon-ticket.md
# Processing Item: bike-voucher...
# Processing Item: gold-teeth...
# Saved 0538_rm-1-key.md
# Saved 0539_rm-2-key.md
# Saved 0537_meteorite.md
# Processing Item: lift-key...
# Processing Item: silph-scope...
# Processing Item: fame-checker...
# Saved 0540_rm-4-key.md
# Saved 0541_rm-6-key.md
# Processing Item: tm-case...
# Processing Item: berry-pouch...
# Saved 0542_devon-scope.md
# Processing Item: teachy-tv...
# Saved 0543_oaks-parcel.md
# Processing Item: tri-pass...
# Saved 0546_gold-teeth.md
# Saved 0545_bike-voucher.md
# Saved 0544_poke-flute.md
# Processing Item: rainbow-pass...
# Processing Item: tea...
# Processing Item: mysticticket...
# Saved 0551_berry-pouch.md
# Saved 0550_tm-case.md
# Saved 0548_silph-scope.md
# Processing Item: auroraticket...
# Processing Item: powder-jar...
# Processing Item: ruby...
# Saved 0549_fame-checker.md
# Processing Item: sapphire...
# Saved 0547_lift-key.md
# Processing Item: magma-emblem...
# Saved 0552_teachy-tv.md
# Saved 0553_tri-pass.md
# Processing Item: old-sea-map...
# Processing Item: douse-drive...
# Saved 0556_mysticticket.md
# Processing Item: shock-drive...
# Saved 0554_rainbow-pass.md
# Processing Item: burn-drive...
# Saved 0555_tea.md
# Saved 0557_auroraticket.md
# Processing Item: chill-drive...
# Processing Item: sweet-heart...
# Saved 0559_ruby.md
# Saved 0560_sapphire.md
# Processing Item: greet-mail...
# Processing Item: favored-mail...
# Saved 0558_powder-jar.md
# Saved 0561_magma-emblem.md
# Saved 0563_douse-drive.md
# Processing Item: rsvp-mail...
# Saved 0562_old-sea-map.md
# Processing Item: thanks-mail...
# Processing Item: inquiry-mail...
# Processing Item: like-mail...
# Saved 0567_sweet-heart.md
# Saved 0564_shock-drive.md
# Processing Item: reply-mail...
# Processing Item: bridge-mail-s...
# Saved 0565_burn-drive.md
# Processing Item: bridge-mail-d...
# Saved 0568_greet-mail.md
# Saved 0566_chill-drive.md
# Processing Item: bridge-mail-t...
# Saved 0572_inquiry-mail.md
# Processing Item: bridge-mail-v...
# Saved 0569_favored-mail.md
# Processing Item: bridge-mail-m...
# Processing Item: prism-scale...
# Saved 0571_thanks-mail.md
# Saved 0570_rsvp-mail.md
# Saved 0573_like-mail.md
# Processing Item: eviolite...
# Processing Item: float-stone...
# Processing Item: rocky-helmet...
# Saved 0577_bridge-mail-t.md
# Saved 0575_bridge-mail-s.md
# Processing Item: air-balloon...
# Processing Item: red-card...
# Saved 0576_bridge-mail-d.md
# Saved 0574_reply-mail.md
# Processing Item: ring-target...
# Processing Item: binding-band...
# Saved 0578_bridge-mail-v.md
# Saved 0579_bridge-mail-m.md
# Saved 0580_prism-scale.md
# Processing Item: absorb-bulb...
# Processing Item: cell-battery...
# Processing Item: eject-button...
# Saved 0581_eviolite.md
# Saved 0582_float-stone.md
# Processing Item: water-gem...
# Processing Item: fire-gem...
# Saved 0583_rocky-helmet.md
# Processing Item: electric-gem...
# Saved 0585_red-card.md
# Processing Item: grass-gem...
# Saved 0587_binding-band.md
# Processing Item: ice-gem...
# Saved 0588_absorb-bulb.md
# Saved 0584_air-balloon.md
# Saved 0589_cell-battery.md
# Saved 0586_ring-target.md
# Saved 0590_eject-button.md
# Processing Item: fighting-gem...
# Processing Item: poison-gem...
# Processing Item: ground-gem...
# Processing Item: flying-gem...
# Processing Item: psychic-gem...
# Saved 0591_fire-gem.md
# Saved 0592_water-gem.md
# Processing Item: bug-gem...
# Processing Item: rock-gem...
# Saved 0593_electric-gem.md
# Processing Item: ghost-gem...
# Saved 0594_grass-gem.md
# Saved 0595_ice-gem.md
# Processing Item: dark-gem...
# Processing Item: steel-gem...
# Saved 0598_ground-gem.md
# Processing Item: health-wing...
# Saved 0597_poison-gem.md
# Saved 0596_fighting-gem.md
# Saved 0600_psychic-gem.md
# Saved 0599_flying-gem.md
# Processing Item: muscle-wing...
# Saved 0601_bug-gem.md
# Processing Item: resist-wing...
# Processing Item: genius-wing...
# Processing Item: clever-wing...
# Processing Item: swift-wing...
# Saved 0602_rock-gem.md
# Processing Item: pretty-wing...
# Saved 0603_ghost-gem.md
# Processing Item: cover-fossil...
# Saved 0604_dark-gem.md
# Processing Item: plume-fossil...
# Saved 0605_steel-gem.md
# Processing Item: liberty-pass...
# Saved 0607_muscle-wing.md
# Saved 0610_clever-wing.md
# Saved 0606_health-wing.md
# Processing Item: pass-orb...
# Processing Item: dream-ball...
# Saved 0608_resist-wing.md
# Processing Item: poke-toy...
# Processing Item: prop-case...
# Saved 0609_genius-wing.md
# Saved 0611_swift-wing.md
# Processing Item: dragon-skull...
# Processing Item: balm-mushroom...
# Saved 0612_pretty-wing.md
# Processing Item: big-nugget...
# Saved 0615_liberty-pass.md
# Saved 0613_cover-fossil.md
# Saved 0614_plume-fossil.md
# Processing Item: pearl-string...
# Processing Item: comet-shard...Processing Item: relic-copper...
#
# Saved 0618_poke-toy.md
# Processing Item: relic-silver...
# Saved 0619_prop-case.md
# Saved 0616_pass-orb.md
# Saved 0621_balm-mushroom.md
# Processing Item: relic-gold...
# Processing Item: relic-vase...
# Processing Item: relic-band...
# Saved 0620_dragon-skull.md
# Processing Item: relic-statue...
# Saved 0617_dream-ball.md
# Processing Item: relic-crown...
# Saved 0623_pearl-string.md
# Processing Item: casteliacone...
# Saved 0625_relic-copper.md
# Saved 0624_comet-shard.md
# Saved 0622_big-nugget.md
# Processing Item: dire-hit-2...
# Processing Item: x-speed-2...
# Processing Item: x-sp-atk-2...
# Saved 0630_relic-statue.md
# Saved 0626_relic-silver.md
# Processing Item: x-sp-def-2...
# Saved 0629_relic-band.md
# Processing Item: x-defense-2...
# Processing Item: x-attack-2...
# Saved 0628_relic-vase.md
# Processing Item: x-accuracy-2...
# Saved 0627_relic-gold.md
# Processing Item: x-speed-3...
# Saved 0631_relic-crown.md
# Saved 0633_dire-hit-2.md
# Saved 0635_x-sp-atk-2.md
# Saved 0632_casteliacone.md
# Processing Item: x-sp-atk-3...
# Saved 0634_x-speed-2.md
# Processing Item: x-sp-def-3...
# Processing Item: x-attack-3...
# Processing Item: x-defense-3...
# Processing Item: x-accuracy-3...
# Saved 0638_x-attack-2.md
# Processing Item: x-speed-6...
# Saved 0637_x-defense-2.md
# Processing Item: x-sp-atk-6...
# Saved 0639_x-accuracy-2.md
# Processing Item: x-sp-def-6...
# Saved 0636_x-sp-def-2.md
# Processing Item: x-defense-6...
# Saved 0643_x-defense-3.md
# Saved 0641_x-sp-atk-3.md
# Saved 0640_x-speed-3.md
# Processing Item: x-attack-6...
# Processing Item: x-accuracy-6...
# Processing Item: ability-urge...
# Saved 0644_x-attack-3.md
# Processing Item: item-drop...
# Saved 0645_x-accuracy-3.md
# Processing Item: item-urge...
# Saved 0642_x-sp-def-3.md
# Processing Item: reset-urge...
# Saved 0647_x-sp-atk-6.md
# Saved 0646_x-speed-6.md
# Processing Item: dire-hit-3...
# Processing Item: light-stone...
# Saved 0648_x-sp-def-6.md
# Processing Item: dark-stone...
# Saved 0651_x-accuracy-6.md
# Saved 0652_ability-urge.md
# Processing Item: tm93...
# Saved 0650_x-attack-6.md
# Processing Item: tm94...
# Saved 0649_x-defense-6.md
# Processing Item: tm95...
# Processing Item: xtransceiver...
# Saved 0654_item-urge.md
# Processing Item: god-stone...
# Saved 0653_item-drop.md
# Processing Item: gram-1...
# Saved 0656_dire-hit-3.md
# Saved 0655_reset-urge.md
# Saved 0657_light-stone.md
# Processing Item: gram-2...
# Processing Item: gram-3...
# Processing Item: dragon-gem...
# Saved 0658_dark-stone.md
# Processing Item: normal-gem...
# Saved 0662_xtransceiver.md
# Saved 0663_god-stone.md
# Processing Item: medal-box...
# Saved 0659_tm93.md
# Processing Item: dna-splicers...
# Saved 0661_tm95.md
# Processing Item: permit...
# Processing Item: oval-charm...
# Saved 0660_tm94.md
# Processing Item: shiny-charm...
# Saved 0664_gram-1.md
# Processing Item: plasma-card...
# Saved 0666_gram-3.md
# Saved 0668_dragon-gem.md
# Processing Item: grubby-hanky...
# Saved 0665_gram-2.md
# Processing Item: colress-machine...
# Processing Item: dropped-item...
# Saved 0670_medal-box.md
# Saved 0673_permit.md
# Processing Item: reveal-glass...
# Processing Item: weakness-policy...
# Saved 0671_dna-splicers.md
# Saved 0669_normal-gem.md
# Processing Item: assault-vest...
# Processing Item: pixie-plate...
# Saved 0675_shiny-charm.md
# Saved 0674_oval-charm.md
# Processing Item: ability-capsule...
# Processing Item: whipped-dream...
# Saved 0676_plasma-card.md
# Processing Item: sachet...
# Saved 0678_colress-machine.md
# Saved 0677_grubby-hanky.md
# Processing Item: luminous-moss...
# Processing Item: snowball...
# Saved 0679_dropped-item.md
# Processing Item: safety-goggles...
# Saved 0681_reveal-glass.md
# Processing Item: rich-mulch...
# Saved 0682_weakness-policy.md
# Saved 0684_pixie-plate.md
# Processing Item: surprise-mulch...
# Processing Item: boost-mulch...
# Saved 0683_assault-vest.md
# Saved 0687_sachet.md
# Saved 0686_whipped-dream.md
# Processing Item: amaze-mulch...
# Processing Item: gengarite...
# Saved 0688_luminous-moss.md
# Processing Item: gardevoirite...
# Processing Item: ampharosite...
# Saved 0685_ability-capsule.md
# Processing Item: venusaurite...
# Saved 0689_snowball.md
# Processing Item: charizardite-x...
# Saved 0690_safety-goggles.md
# Processing Item: blastoisinite...
# Saved 0691_rich-mulch.md
# Processing Item: mewtwonite-x...
# Saved 0693_boost-mulch.md
# Saved 0692_surprise-mulch.md
# Processing Item: mewtwonite-y...
# Processing Item: blazikenite...
# Saved 0694_amaze-mulch.md
# Saved 0697_ampharosite.md
# Saved 0695_gengarite.md
# Processing Item: medichamite...
# Processing Item: houndoominite...
# Processing Item: aggronite...
# Saved 0696_gardevoirite.md
# Saved 0698_venusaurite.md
# Processing Item: banettite...
# Processing Item: tyranitarite...
# Saved 0699_charizardite-x.md
# Saved 0700_blastoisinite.md
# Processing Item: scizorite...
# Processing Item: pinsirite...
# Saved 0704_medichamite.md
# Processing Item: aerodactylite...
# Saved 0701_mewtwonite-x.md
# Processing Item: lucarionite...
# Saved 0702_mewtwonite-y.md
# Saved 0703_blazikenite.md
# Processing Item: abomasite...
# Processing Item: kangaskhanite...
# Saved 0708_tyranitarite.md
# Saved 0705_houndoominite.md
# Processing Item: gyaradosite...
# Processing Item: absolite...
# Saved 0706_aggronite.md
# Processing Item: charizardite-y...
# Saved 0707_banettite.md
# Processing Item: alakazite...
# Saved 0709_scizorite.md
# Processing Item: heracronite...
# Saved 0710_pinsirite.md
# Processing Item: mawilite...
# Saved 0714_kangaskhanite.md
# Saved 0712_lucarionite.md
# Processing Item: manectite...
# Saved 0711_aerodactylite.md
# Processing Item: garchompite...
# Processing Item: roseli-berry...
# Saved 0713_abomasite.md
# Saved 0715_gyaradosite.md
# Saved 0716_absolite.md
# Processing Item: kee-berry...
# Saved 0718_alakazite.md
# Processing Item: maranga-berry...
# Processing Item: discount-coupon...
# Processing Item: strange-souvenir...
# Saved 0717_charizardite-y.md
# Processing Item: lumiose-galette...
# Saved 0720_mawilite.md
# Processing Item: jaw-fossil...
# Saved 0726_discount-coupon.md
# Saved 0719_heracronite.md
# Processing Item: sail-fossil...
# Saved 0721_manectite.md
# Saved 0723_roseli-berry.md
# Processing Item: fairy-gem...
# Processing Item: adventure-rules...
# Processing Item: elevator-key...
# Saved 0722_garchompite.md
# Saved 0728_lumiose-galette.md
# Saved 0725_maranga-berry.md
# Saved 0724_kee-berry.md
# Processing Item: holo-caster...
# Processing Item: honor-of-kalos...
# Processing Item: intriguing-stone...
# Processing Item: lens-case...
# Saved 0727_strange-souvenir.md
# Processing Item: looker-ticket...
# Saved 0733_elevator-key.md
# Saved 0729_jaw-fossil.md
# Processing Item: mega-ring...
# Processing Item: power-plant-pass...
# Saved 0732_adventure-rules.md
# Processing Item: profs-letter...
# Saved 0735_honor-of-kalos.md
# Processing Item: roller-skates...
# Saved 0730_sail-fossil.md
# Saved 0737_lens-case.md
# Processing Item: sprinklotad...
# Processing Item: tmv-pass...
# Saved 0734_holo-caster.md
# Processing Item: tm96...
# Saved 0736_intriguing-stone.md
# Saved 0731_fairy-gem.md
# Saved 0738_looker-ticket.md
# Processing Item: tm97...
# Processing Item: tm98...
# Processing Item: tm99...
# Saved 0740_power-plant-pass.md
# Saved 0739_mega-ring.md
# Saved 0744_tmv-pass.md
# Processing Item: tm100...
# Processing Item: latiasite...
# Processing Item: latiosite...
# Saved 0743_sprinklotad.md
# Saved 0742_roller-skates.md
# Processing Item: common-stone...
# Processing Item: makeup-bag...
# Saved 0741_profs-letter.md
# Processing Item: travel-trunk...
# Saved 0745_tm96.md
# Processing Item: shalour-sable...
# Saved 0748_tm99.md
# Saved 0747_tm98.md
# Saved 0746_tm97.md
# Processing Item: mega-charm...
# Processing Item: mega-glove...
# Processing Item: devon-parts...
# Saved 0749_tm100.md
# Saved 0763_makeup-bag.md
# Processing Item: key-to-room-1...
# Processing Item: key-to-room-2...
# Saved 0762_common-stone.md
# Saved 0761_latiosite.md
# Processing Item: key-to-room-4...
# Saved 0760_latiasite.md
# Processing Item: key-to-room-6...
# Processing Item: devon-scuba-gear...
# Saved 0764_travel-trunk.md
# Saved 0765_shalour-sable.md
# Processing Item: contest-costume--jacket...
# Processing Item: magma-suit...
# Saved 0769_mega-glove.md
# Saved 0770_devon-parts.md
# Processing Item: aqua-suit...
# Processing Item: pair-of-tickets...
# Saved 0774_key-to-room-2.md
# Processing Item: mega-bracelet...
# Saved 0768_mega-charm.md
# Saved 0775_key-to-room-4.md
# Processing Item: mega-pendant...
# Saved 0776_key-to-room-6.md
# Saved 0773_key-to-room-1.md
# Processing Item: mega-glasses...
# Processing Item: mega-anchor...
# Processing Item: mega-stickpin...
# Saved 0780_contest-costume--jacket.md
# Saved 0779_devon-scuba-gear.md
# Processing Item: mega-tiara...
# Saved 0782_magma-suit.md
# Processing Item: mega-anklet...
# Saved 0783_aqua-suit.md
# Processing Item: swampertite...
# Processing Item: sceptilite...
# Saved 0784_pair-of-tickets.md
# Processing Item: sablenite...
# Saved 0787_mega-glasses.md
# Saved 0785_mega-bracelet.md
# Processing Item: altarianite...
# Processing Item: galladite...
# Saved 0786_mega-pendant.md
# Saved 0790_mega-tiara.md
# Processing Item: audinite...
# Processing Item: metagrossite...
# Saved 0789_mega-stickpin.md
# Saved 0788_mega-anchor.md
# Processing Item: sharpedonite...
# Processing Item: slowbronite...
# Saved 0794_sceptilite.md
# Processing Item: steelixite...
# Saved 0793_swampertite.md
# Saved 0795_sablenite.md
# Saved 0791_mega-anklet.md
# Processing Item: pidgeotite...
# Processing Item: glalitite...
# Processing Item: diancite...
# Saved 0796_altarianite.md
# Saved 0800_sharpedonite.md
# Processing Item: prison-bottle...
# Saved 0798_audinite.md
# Saved 0801_slowbronite.md
# Processing Item: mega-cuff...
# Processing Item: cameruptite...
# Saved 0799_metagrossite.md
# Processing Item: lopunnite...
# Processing Item: salamencite...
# Saved 0797_galladite.md
# Processing Item: beedrillite...
# Saved 0802_steelixite.md
# Processing Item: key-stone...
# Saved 0803_pidgeotite.md
# Processing Item: meteorite-shard...
# Saved 0805_diancite.md
# Processing Item: eon-flute...
# Saved 0804_glalitite.md
# Processing Item: normalium-z--held...
# Saved 0806_prison-bottle.md
# Processing Item: firium-z--held...
# Saved 0807_mega-cuff.md
# Saved 0809_lopunnite.md
# Saved 0808_cameruptite.md
# Processing Item: waterium-z--held...
# Processing Item: electrium-z--held...
# Processing Item: grassium-z--held...
# Saved 0810_salamencite.md
# Saved 0811_beedrillite.md
# Processing Item: icium-z--held...
# Saved 0814_key-stone.md
# Processing Item: fightinium-z--held...
# Processing Item: poisonium-z--held...
# Saved 0815_meteorite-shard.md
# Processing Item: groundium-z--held...
# Saved 0817_normalium-z--held.md
# Saved 0816_eon-flute.md
# Processing Item: flyinium-z--held...
# Processing Item: psychium-z--held...
# Saved 0819_waterium-z--held.md
# Saved 0818_firium-z--held.md
# Saved 0820_electrium-z--held.md
# Processing Item: buginium-z--held...
# Processing Item: rockium-z--held...
# Processing Item: ghostium-z--held...
# Saved 0822_icium-z--held.md
# Saved 0823_fightinium-z--held.md
# Processing Item: dragonium-z--held...
# Processing Item: darkinium-z--held...
# Saved 0821_grassium-z--held.md
# Saved 0824_poisonium-z--held.md
# Processing Item: steelium-z--held...
# Processing Item: fairium-z--held...
# Saved 0825_groundium-z--held.md
# Processing Item: pikanium-z--held...
# Saved 0826_flyinium-z--held.md
# Processing Item: bottle-cap...
# Saved 0827_psychium-z--held.md
# Processing Item: gold-bottle-cap...
# Saved 0829_rockium-z--held.md
# Processing Item: z-ring...
# Saved 0828_buginium-z--held.md
# Processing Item: decidium-z--held...
# Saved 0833_steelium-z--held.md
# Processing Item: incinium-z--held...
# Saved 0830_ghostium-z--held.md
# Processing Item: primarium-z--held...
# Saved 0831_dragonium-z--held.md
# Processing Item: tapunium-z--held...
# Saved 0832_darkinium-z--held.md
# Saved 0834_fairium-z--held.md
# Processing Item: marshadium-z--held...
# Processing Item: aloraichium-z--held...
# Saved 0835_pikanium-z--held.md
# Processing Item: snorlium-z--held...
# Saved 0836_bottle-cap.md
# Saved 0837_gold-bottle-cap.md
# Processing Item: eevium-z--held...
# Processing Item: mewnium-z--held...
# Saved 0838_z-ring.md
# Processing Item: pikashunium-z--held...
# Saved 0841_primarium-z--held.md
# Saved 0839_decidium-z--held.md
# Processing Item: forage-bag...
# Processing Item: fishing-rod...
# Saved 0840_incinium-z--held.md
# Saved 0844_aloraichium-z--held.md
# Processing Item: professors-mask...
# Saved 0842_tapunium-z--held.md
# Processing Item: festival-ticket...
# Saved 0843_marshadium-z--held.md
# Processing Item: sparkling-stone...
# Processing Item: adrenaline-orb...
# Saved 0845_snorlium-z--held.md
# Processing Item: zygarde-cube...
# Saved 0846_eevium-z--held.md
# Processing Item: ice-stone...
# Saved 0879_fishing-rod.md
# Saved 0847_mewnium-z--held.md
# Processing Item: ride-pager...
# Saved 0877_pikashunium-z--held.md
# Processing Item: beast-ball...
# Processing Item: big-malasada...
# Saved 0878_forage-bag.md
# Saved 0880_professors-mask.md
# Saved 0881_festival-ticket.md
# Saved 0882_sparkling-stone.md
# Processing Item: red-nectar...
# Processing Item: yellow-nectar...
# Processing Item: pink-nectar...
# Processing Item: purple-nectar...
# Saved 0883_adrenaline-orb.md
# Processing Item: sun-flute...
# Saved 0884_zygarde-cube.md
# Processing Item: moon-flute...
# Saved 0885_ice-stone.md
# Saved 0888_big-malasada.md
# Processing Item: enigmatic-card...
# Processing Item: terrain-extender...
# Saved 0889_red-nectar.md
# Processing Item: protective-pads...
# Saved 0890_yellow-nectar.md
# Saved 0886_ride-pager.md
# Saved 0892_purple-nectar.md
# Processing Item: electric-seed...
# Processing Item: psychic-seed...
# Processing Item: misty-seed...
# Saved 0891_pink-nectar.md
# Processing Item: grassy-seed...
# Saved 0887_beast-ball.md
# Processing Item: fighting-memory...
# Saved 0893_sun-flute.md
# Processing Item: flying-memory...
# Saved 0894_moon-flute.md
# Saved 0895_enigmatic-card.md
# Processing Item: poison-memory...
# Processing Item: ground-memory...
# Saved 0896_terrain-extender.md
# Processing Item: rock-memory...
# Saved 0899_psychic-seed.md
# Saved 0897_protective-pads.md
# Saved 0901_grassy-seed.md
# Saved 0900_misty-seed.md
# Processing Item: bug-memory...
# Processing Item: ghost-memory...
# Processing Item: steel-memory...
# Processing Item: fire-memory...
# Saved 0898_electric-seed.md
# Processing Item: water-memory...
# Saved 0903_flying-memory.md
# Processing Item: grass-memory...
# Saved 0902_fighting-memory.md
# Saved 0905_ground-memory.md
# Processing Item: electric-memory...
# Processing Item: psychic-memory...
# Saved 0906_rock-memory.md
# Processing Item: ice-memory...
# Saved 0904_poison-memory.md
# Processing Item: dragon-memory...
# Saved 0907_bug-memory.md
# Processing Item: dark-memory...
# Saved 0909_steel-memory.md
# Saved 0908_ghost-memory.md
# Processing Item: fairy-memory...
# Saved 0910_fire-memory.md
# Processing Item: bike--green...
# Processing Item: storage-key--galactic-warehouse...
# ...
# Saved 1946_tm103.md
# Saved 1947_tm104.md
# Processing Item: tm113...
# Processing Item: tm114...
# Saved 1948_tm105.md
# Saved 1950_tm107.md
# Processing Item: tm115...
# Processing Item: tm116...
# Saved 1949_tm106.md
# Processing Item: tm117...
# Saved 1951_tm108.md
# Processing Item: tm118...
# Saved 1952_tm109.md
# Processing Item: tm119...
# Saved 1953_tm110.md
# Saved 1954_tm111.md
# Processing Item: tm120...
# Processing Item: tm121...
# Saved 1955_tm112.md
# Saved 1957_tm114.md
# Processing Item: tm122...
# Processing Item: tm123...
# Saved 1956_tm113.md
# Processing Item: tm124...
# Saved 1958_tm115.md
# Processing Item: tm125...
# Saved 1959_tm116.md
# Saved 1962_tm119.md
# Processing Item: tm126...
# Processing Item: tm127...
# Saved 1960_tm117.md
# Saved 1961_tm118.md
# Processing Item: tm128...
# Processing Item: tm129...
# Saved 1963_tm120.md
# Processing Item: tm130...
# Saved 1964_tm121.md
# Saved 1965_tm122.md
# Processing Item: tm131...
# Processing Item: tm132...
# Saved 1966_tm123.md
# Processing Item: tm133...
# Saved 1967_tm124.md
# Saved 1968_tm125.md
# Processing Item: tm134...
# Saved 1969_tm126.md
# Processing Item: tm135...
# Processing Item: tm136...
# Saved 1971_tm128.md
# Saved 1970_tm127.md
# Processing Item: tm137...
# Saved 1973_tm130.md
# Processing Item: tm138...
# Processing Item: tm139...
# Saved 1972_tm129.md
# Processing Item: tm140...
# Saved 1974_tm131.md
# Saved 1975_tm132.md
# Processing Item: tm141...
# Processing Item: tm142...
# Saved 1976_tm133.md
# Processing Item: tm143...
# Saved 1977_tm134.md
# Saved 1978_tm135.md
# Processing Item: tm144...
# Saved 1979_tm136.md
# Processing Item: tm145...
# Processing Item: tm146...
# Saved 1981_tm138.md
# Processing Item: tm147...
# Saved 1980_tm137.md
# Saved 1982_tm139.md
# Processing Item: tm148...
# Processing Item: tm149...
# Saved 1983_tm140.md
# Saved 1984_tm141.md
# Saved 1986_tm143.md
# Processing Item: tm150...
# Processing Item: tm152...
# Processing Item: tm151...
# Saved 1985_tm142.md
# Processing Item: tm153...
# Saved 1987_tm144.md
# Processing Item: tm154...
# Saved 1989_tm146.md
# Saved 1990_tm147.md
# Processing Item: tm155...
# Processing Item: tm156...
# Saved 1988_tm145.md
# Processing Item: tm157...
# Saved 1991_tm148.md
# Processing Item: tm158...
# Saved 1992_tm149.md
# Processing Item: tm159...
# Saved 1994_tm151.md
# Saved 1995_tm152.md
# Processing Item: tm160...
# Processing Item: tm161...
# Saved 1993_tm150.md
# Processing Item: tm162...
# Saved 1998_tm155.md
# Processing Item: tm163...
# Saved 1997_tm154.md
# Saved 1999_tm156.md
# Saved 1996_tm153.md
# Processing Item: tm164...
# Processing Item: tm165...
# Processing Item: tm166...
# Saved 2000_tm157.md
# Processing Item: tm167...
# Saved 2001_tm158.md
# Saved 2002_tm159.md
# Processing Item: tm168...
# Processing Item: tm169...
# Saved 2003_tm160.md
# Processing Item: tm170...
# Saved 2004_tm161.md
# Saved 2005_tm162.md
# Processing Item: tm171...
# Processing Item: picnic-set...
# Saved 2006_tm163.md
# Processing Item: academy-bottle...
# Saved 2008_tm165.md
# Saved 2007_tm164.md
# Processing Item: academy-bottle...
# Processing Item: polka-dot-bottle...
# Saved 2010_tm167.md
# Saved 2009_tm166.md
# Processing Item: striped-bottle...
# Processing Item: diamond-bottle...
# Saved 2011_tm168.md
# Processing Item: academy-cup...
# Saved 2012_tm169.md
# Processing Item: academy-cup...
# Saved 2014_tm171.md
# Processing Item: striped-cup...
# Saved 2013_tm170.md
# Saved 2015_picnic-set.md
# Processing Item: polka-dot-cup...
# Saved 2017_academy-bottle.md
# Processing Item: flower-pattern-cup...
# Processing Item: academy-tablecloth...
# Saved 2019_striped-bottle.md
# Processing Item: academy-tablecloth...
# Saved 2018_polka-dot-bottle.md
# Saved 2017_academy-bottle.md
# Processing Item: whimsical-tablecloth...
# Processing Item: leafy-tablecloth...
# Saved 2020_diamond-bottle.md
# Saved 2022_academy-cup.md
# Processing Item: spooky-tablecloth...
# Processing Item: academy-ball...
# Saved 2022_academy-cup.md
# Processing Item: academy-ball...
# Saved 2023_striped-cup.md
# Processing Item: marill-ball...
# Saved 2024_polka-dot-cup.md
# Processing Item: yarn-ball...
# Saved 2029_leafy-tablecloth.md
# Saved 2027_academy-tablecloth.md
# Processing Item: cyber-ball...
# Processing Item: gold-pick...
# Saved 2028_whimsical-tablecloth.md
# Saved 2025_flower-pattern-cup.md
# Processing Item: silver-pick...
# Saved 2027_academy-tablecloth.md
# Processing Item: red-flag-pick...
# Processing Item: blue-flag-pick...
# Saved 2030_spooky-tablecloth.md
# Processing Item: pika-pika-pick...
# Saved 2032_academy-ball.md
# Processing Item: winking-pika-pick...
# Saved 2033_marill-ball.md
# Saved 2032_academy-ball.md
# Saved 2034_yarn-ball.md
# Processing Item: vee-vee-pick...
# Processing Item: smiling-vee-pick...
# Processing Item: blue-poké-ball-pick...
# Saved 2036_gold-pick.md
# Processing Item: auspicious-armor...
# Error processing blue-poké-ball-pick: API Error: Item not found. (Count: 6)
# Saved 2037_silver-pick.md
# Saved 2039_blue-flag-pick.md
# Saved 2035_cyber-ball.md
# Processing Item: leader’s-crest...
# Processing Item: pink-bottle...
# Saved 2038_red-flag-pick.md
# Processing Item: blue-bottle...
# Processing Item: yellow-bottle...
# Processing Item: steel-bottle-(r)...
# Error processing leader’s-crest: API Error: Item not found. (Count: 7)
# Processing Item: steel-bottle-(y)...
# Error processing steel-bottle-(r): API Error: Item not found. (Count: 8)
# Processing Item: steel-bottle-(b)...
# Error processing steel-bottle-(y): API Error: Item not found. (Count: 9)
# Saved 2040_pika-pika-pick.md
# Processing Item: silver-bottle...
# Processing Item: barred-cup...
# Error processing steel-bottle-(b): API Error: Item not found. (Count: 10)
# Processing Item: diamond-pattern-cup...
# Saved 2041_winking-pika-pick.md
# Processing Item: pink-cup...
# Saved 2047_pink-bottle.md
# Saved 2042_vee-vee-pick.md
# Saved 2049_yellow-bottle.md
# Processing Item: blue-cup...
# Saved 2045_auspicious-armor.md
# Processing Item: yellow-cup...
# Processing Item: pikachu-cup...
# Saved 2048_blue-bottle.md
# Processing Item: eevee-cup...
# Saved 2043_smiling-vee-pick.md
# Processing Item: slowpoke-cup...
# Processing Item: silver-cup...
# Saved 2055_diamond-pattern-cup.md
# Saved 2054_barred-cup.md
# Saved 2053_silver-bottle.md
# Processing Item: exercise-ball...
# Processing Item: plaid-tablecloth-(y)...
# Processing Item: plaid-tablecloth-(b)...
# Saved 2057_pink-cup.md
# Error processing plaid-tablecloth-(b): API Error: Item not found. (Count: 11)
# Processing Item: plaid-tablecloth-(r)...
# Processing Item: b&w-grass-tablecloth...
# Error processing plaid-tablecloth-(r): API Error: Item not found. (Count: 12)
# Error processing plaid-tablecloth-(y): API Error: Item not found. (Count: 13)
# Processing Item: battle-tablecloth...
# Saved 2060_pikachu-cup.md
# Processing Item: monstrous-tablecloth...
# Saved 2058_blue-cup.md
# Processing Item: striped-tablecloth...
# Processing Item: diamond-tablecloth...
# Saved 2059_yellow-cup.md
# Error processing b&w-grass-tablecloth: API Error: Item not found. (Count: 14)
# Processing Item: polka-dot-tablecloth...
# Saved 2061_eevee-cup.md
# Processing Item: lilac-tablecloth...
# Saved 2062_slowpoke-cup.md
# Processing Item: mint-tablecloth...
# Processing Item: peach-tablecloth...
# Saved 2063_silver-cup.md
# Processing Item: yellow-tablecloth...
# Saved 2064_exercise-ball.md
# Processing Item: blue-tablecloth...
# Saved 2069_battle-tablecloth.md
# Saved 2071_striped-tablecloth.md
# Processing Item: pink-tablecloth...
# Saved 2070_monstrous-tablecloth.md
# Processing Item: gold-bottle...
# Saved 2072_diamond-tablecloth.md
# Saved 2075_mint-tablecloth.md
# Processing Item: bronze-bottle...
# Processing Item: gold-cup...
# Processing Item: bronze-cup...
# Saved 2073_polka-dot-tablecloth.md
# Saved 2074_lilac-tablecloth.md
# Saved 2076_peach-tablecloth.md
# Processing Item: green-poké-ball-pick...
# Processing Item: red-poké-ball-pick...
# Processing Item: party-sparkler-pick...
# Error processing green-poké-ball-pick: API Error: Item not found. (Count: 15)
# Saved 2077_yellow-tablecloth.md
# Processing Item: heroic-sword-pick...
# Error processing red-poké-ball-pick: API Error: Item not found. (Count: 16)
# Processing Item: magical-star-pick...
# Processing Item: magical-heart-pick...
# Saved 2078_blue-tablecloth.md
# Processing Item: parasol-pick...
# Saved 2079_pink-tablecloth.md
# Processing Item: blue-sky-flower-pick...
# Saved 2083_bronze-cup.md
# Processing Item: sunset-flower-pick...
# Saved 2082_gold-cup.md
# Processing Item: sunrise-flower-pick...
# Saved 2081_bronze-bottle.md
# Saved 2086_party-sparkler-pick.md
# Saved 2088_magical-star-pick.md
# Processing Item: blue-dish...
# Processing Item: green-dish...
# Saved 2080_gold-bottle.md
# Processing Item: orange-dish...
# Processing Item: red-dish...
# Saved 2089_magical-heart-pick.md
# Saved 2087_heroic-sword-pick.md
# Processing Item: white-dish...
# Processing Item: yellow-dish...
# Saved 2090_parasol-pick.md
# Saved 2091_blue-sky-flower-pick.md
# Processing Item: roto-stick...
# Processing Item: teal-style-card...
# Saved 2092_sunset-flower-pick.md
# Processing Item: teal-mask...
# Saved 2094_blue-dish.md
# Saved 2096_orange-dish.md
# Processing Item: glimmering-charm...
# Processing Item: crystal-cluster...
# Saved 2095_green-dish.md
# Processing Item: wellspring-mask...
# Saved 2097_red-dish.md
# Saved 2099_yellow-dish.md
# Saved 2093_sunrise-flower-pick.md
# Saved 2098_white-dish.md
# Processing Item: hearthflame-mask...
# Processing Item: cornerstone-mask...
# Processing Item: unremarkable-teacup...
# Processing Item: syrupy-apple...
# Saved 2101_teal-style-card.md
# Saved 2102_teal-mask.md
# Processing Item: masterpiece-teacup...
# Processing Item: health-mochi...
# Saved 2103_glimmering-charm.md
# Processing Item: muscle-mochi...
# Saved 2100_roto-stick.md
# Processing Item: resist-mochi...
# Saved 2106_wellspring-mask.md
# Saved 2104_crystal-cluster.md
# Processing Item: clever-mochi...
# Processing Item: genius-mochi...
# Saved 2109_syrupy-apple.md
# Processing Item: swift-mochi...
# Saved 2107_hearthflame-mask.md
# Saved 2110_unremarkable-teacup.md
# Processing Item: fresh-start-mochi...
# Processing Item: ekans-fang...
# Saved 2111_masterpiece-teacup.md
# Processing Item: sandshrew-claw...
# Saved 2108_cornerstone-mask.md
# Processing Item: cleffa-fur...
# Saved 2112_health-mochi.md
# Processing Item: vulpix-fur...
# Saved 2114_resist-mochi.md
# Saved 2115_genius-mochi.md
# Processing Item: poliwag-slime...
# Saved 2113_muscle-mochi.md
# Processing Item: bellsprout-vine...
# Processing Item: geodude-fragment...
# Saved 2117_swift-mochi.md
# Processing Item: koffing-gas...
# Saved 2120_sandshrew-claw.md
# Saved 2116_clever-mochi.md
# Processing Item: munchlax-fang...
# Processing Item: sentret-fur...
# Saved 2119_ekans-fang.md
# Saved 2118_fresh-start-mochi.md
# Saved 2122_vulpix-fur.md
# Processing Item: hoothoot-feather...
# Saved 2121_cleffa-fur.md
# Processing Item: spinarak-thread...
# Processing Item: aipom-hair...
# Processing Item: yanma-spike...
# Saved 2124_bellsprout-vine.md
# Processing Item: gligar-fang...
# Saved 2123_poliwag-slime.md
# Processing Item: slugma-lava...
# Saved 2125_geodude-fragment.md
# Saved 2126_koffing-gas.md
# Processing Item: swinub-hair...
# Saved 2128_sentret-fur.md
# Processing Item: poochyena-fang...
# Processing Item: lotad-leaf...
# Saved 2131_aipom-hair.md
# Saved 2130_spinarak-thread.md
# Saved 2129_hoothoot-feather.md
# Processing Item: seedot-stem...
# Saved 2127_munchlax-fang.md
# Processing Item: nosepass-fragment...
# Processing Item: volbeat-fluid...
# Processing Item: illumise-fluid...
# Saved 2134_slugma-lava.md
# Saved 2132_yanma-spike.md
# Processing Item: corphish-shell...
# Saved 2136_poochyena-fang.md
# Processing Item: feebas-scales...
# Saved 2133_gligar-fang.md
# Saved 2135_swinub-hair.md
# Processing Item: duskull-fragment...
# Processing Item: chingling-fragment...
# Processing Item: timburr-sweat...
# Saved 2140_volbeat-fluid.md
# Saved 2137_lotad-leaf.md
# Processing Item: sewaddle-leaf...
# Processing Item: ducklett-feather...
# Saved 2138_seedot-stem.md
# Saved 2139_nosepass-fragment.md
# Processing Item: litwick-soot...
# Processing Item: mienfoo-claw...
# Saved 2141_illumise-fluid.md
# Saved 2142_corphish-shell.md
# Processing Item: vullaby-feather...
# Processing Item: carbink-jewel...
# Saved 2144_duskull-fragment.md
# Saved 2145_chingling-fragment.md
# Processing Item: phantump-twig...
# Processing Item: grubbin-thread...
# Saved 2146_timburr-sweat.md
# Saved 2143_feebas-scales.md
# Processing Item: cutiefly-powder...
# Processing Item: jangmo-o-scales...
# Saved 2147_sewaddle-leaf.md
# Saved 2148_ducklett-feather.md
# Processing Item: cramorant-down...
# Processing Item: morpeko-snack...
# Saved 2149_litwick-soot.md
# Processing Item: poltchageist-powder...
# Saved 2150_mienfoo-claw.md
# Processing Item: linking-cord...
# Saved 2151_vullaby-feather.md
# Processing Item: tm172...
# Saved 2152_carbink-jewel.md
# Processing Item: tm173...
# Saved 2155_cutiefly-powder.md
# Saved 2154_grubbin-thread.md
# Processing Item: tm174...
# Processing Item: tm175...
# Saved 2153_phantump-twig.md
# Saved 2156_jangmo-o-scales.md
# Processing Item: tm176...
# Processing Item: tm177...
# Saved 2157_cramorant-down.md
# Processing Item: tm178...
# Saved 2159_poltchageist-powder.md
# Saved 2158_morpeko-snack.md
# Processing Item: tm179...
# Processing Item: tm180...
# Saved 2161_tm172.md
# Processing Item: tm181...
# Saved 2160_linking-cord.md
# Processing Item: tm182...
# Saved 2163_tm174.md
# Processing Item: tm183...
# Saved 2165_tm176.md
# Saved 2164_tm175.md
# Processing Item: tm184...
# Saved 2162_tm173.md
# Processing Item: tm185...
# Processing Item: tm186...
# Saved 2166_tm177.md
# Saved 2167_tm178.md
# Processing Item: tm187...
# Processing Item: tm188...
# Saved 2168_tm179.md
# Processing Item: tm189...
# Saved 2169_tm180.md
# Processing Item: tm190...
# Saved 2171_tm182.md
# Saved 2172_tm183.md
# Processing Item: tm191...
# Saved 2170_tm181.md
# Processing Item: tm192...
# Processing Item: tm193...
# Saved 2173_tm184.md
# Saved 2175_tm186.md
# Processing Item: tm194...
# Processing Item: tm195...
# Saved 2174_tm185.md
# Processing Item: tm196...
# Saved 2176_tm187.md
# Processing Item: tm197...
# Saved 2179_tm190.md
# Saved 2178_tm189.md
# Processing Item: tm198...
# Processing Item: tm199...
# Saved 2177_tm188.md
# Processing Item: tm200...
# Saved 2182_tm193.md
# Processing Item: tm201...
# Saved 2180_tm191.md
# Processing Item: tm202...
# Saved 2183_tm194.md
# Saved 2181_tm192.md
# Processing Item: tm203...
# Processing Item: tm204...
# Saved 2184_tm195.md
# Saved 2186_tm197.md
# Saved 2185_tm196.md
# Processing Item: tm205...
# Processing Item: tm206...
# Processing Item: tm207...
# Saved 2188_tm199.md
# Saved 2187_tm198.md
# Saved 2189_tm200.md
# Processing Item: tm208...
# Processing Item: tm209...
# Processing Item: tm210...
# Saved 2191_tm202.md
# Processing Item: tm211...
# Saved 2190_tm201.md
# Processing Item: tm212...
# Saved 2192_tm203.md
# Saved 2195_tm206.md
# Processing Item: tm213...
# Saved 2196_tm207.md
# Processing Item: tm214...
# Saved 2193_tm204.md
# Processing Item: tm215...
# Saved 2194_tm205.md
# Processing Item: tm216...
# Processing Item: tm217...
# Saved 2197_tm208.md
# Processing Item: tm218...
# Saved 2199_tm210.md
# Processing Item: tm219...
# Saved 2198_tm209.md
# Processing Item: tm220...
# Saved 2201_tm212.md
# Saved 2200_tm211.md
# Processing Item: tm221...
# Processing Item: tm222...
# Saved 2203_tm214.md
# Processing Item: tm223...
# Saved 2202_tm213.md
# Processing Item: tm224...
# Saved 2205_tm216.md
# Processing Item: tm225...
# Saved 2206_tm217.md
# Saved 2207_tm218.md
# Processing Item: tm226...
# Processing Item: tm227...
# Saved 2208_tm219.md
# Saved 2209_tm220.md
# Saved 2204_tm215.md
# Processing Item: tm228...
# Processing Item: tm229...
# Processing Item: lastrange-ball...
# Saved 2210_tm221.md
# Processing Item: lapoke-ball...
# Saved 2211_tm222.md
# Processing Item: lagreat-ball...
# Saved 2212_tm223.md
# Processing Item: laultra-ball...
# Saved 2213_tm224.md
# Saved 2214_tm225.md
# Saved 2215_tm226.md
# Processing Item: laheavy-ball...
# Processing Item: laleaden-ball...
# Saved 2216_tm227.md
# Processing Item: lagigaton-ball...
# Processing Item: lafeather-ball...
# Saved 2219_lastrange-ball.md
# Saved 2218_tm229.md
# Saved 2217_tm228.md
# Processing Item: lawing-ball...
# Processing Item: laorigin-ball...
# Processing Item: black-augurite...
# Saved 2221_lagreat-ball.md
# Processing Item: peat-block...
# Saved 2220_lapoke-ball.md
# Saved 2222_laultra-ball.md
# Saved 2223_laheavy-ball.md
# Saved 2225_lagigaton-ball.md
# Saved 2224_laleaden-ball.md
# Saved 2226_lafeather-ball.md
# Saved 10001_black-augurite.md
# Saved 2229_laorigin-ball.md
# Saved 10002_peat-block.md
# Saved 2227_lawing-ball.md
# Items Generation complete.
