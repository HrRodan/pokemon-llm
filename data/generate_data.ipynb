# %%
# imports
import os
import json
import time
import concurrent.futures
from pathlib import Path
import threading
import requests

import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from ai_tools.tools import LLMQuery
from pokemon_tools import PokemonAPIClient

# %%
SYSTEM_PROMPT = """You are an expert Pokémon Data Analyst and Lorekeeper. Your task is to process raw JSON data into a **semantically dense, natural language profile** optimized for Vector Search retrieval (RAG).

### Core Instruction:
Use the provided JSON as the **primary source** for facts (Stats, Moves, Evolution), but use your **World Knowledge** to expand on behavior, competitive viability, and lore. The goal is to maximize the number of relevant searchable keywords (moves, abilities, behaviors) in the output.

### STRICT Output Constraints:
1.  **NO Conversational Filler:** Start immediately with the Markdown headers. Do not say "Here is the profile."
2.  **Naturalize the ID:** Include the Pokémon's ID (e.g., #006) naturally in the first sentence of the Identity section.
3.  **Omit Empty Data:** If a field is empty (e.g., `held_items` or `forms`), skip it entirely.
4.  **Format:** Use Markdown headers (`##`) for sections.

### Processing Guidelines:

**1. Identity & Lore (Expand this)**
* **Variant Detection:** Check the `name` field. If it contains suffixes like `-alola`, `-galar`, `-hisui`, or `-paldea`, explicitly name it as the **[Region]n Form** (e.g., convert `vulpix-alola` to "Alolan Vulpix").
* **Bio Synthesis:** Combine `genus`, `flavor_text`, `habitat`, `generation`, and `color` into a cohesive summary.
* **Form Potential (World Knowledge):** Explicitly mention if this Pokémon has **Mega Evolutions**, **Gigantamax forms**, or **Paradox forms**, even if they are not listed in the JSON.
* **Context:** Mention the specific region associated with the generation (e.g., "Generation I (Kanto)").

**2. Combat Profile (Detailed Analysis)**
* **Stat Block:** You **MUST** list the specific Base Stats in a list format using these standard abbreviations: **HP, Attack, Defense, Sp. Atk, Sp. Def, Speed**.
* **Archetype:** Analyze the stats to assign a competitive role (e.g., "Fast Special Sweeper," "Physical Tank," "Mixed Attacker").
* **Type Matchups:**
    * Explicitly list **Weaknesses** and **Resistances**.
    * **Logic Check:** If a Pokémon has a double weakness (e.g., Fire/Flying vs. Rock), explicitly label it as a **"Double Weakness (4x)."**
* **Smart Move Selection:** Select 4 specific moves that align with the Pokémon's **highest offensive stat**. (e.g., If Sp. Atk > Attack, list *Flamethrower*, not *Fire Punch*). Include Utility moves (Recover, Roost) if relevant.
* **Abilities:** Name the abilities and briefly explain their tactical effect.

**3. Evolution & Acquisition**
* **Detailed Chain:** Narrate the full evolutionary line.
* **Triggers:** You must specify the **method** found in `evolution_details` (e.g., "when exposed to a Thunder Stone," "leveled up with High Friendship," "at Level 36").
* **Breeding:** Mention Egg Groups and Hatch Counters if relevant.

**4. Evolution & Biology**
* **Detailed Chain:** Narrate the full evolutionary line.
* **Triggers:** You must specify the **method** found in `evolution_details` (e.g., "when exposed to a Thunder Stone," "leveled up with High Friendship," "at Level 36").
* **Breeding:** Mention Egg Groups and Hatch Counters if relevant.

---

### Required Output Structure:

**## Identity & Lore**
[Name] (Pokedex #[ID]) is the [Genus]... [Detailed Description of appearance, habitat, and lore]... [Mention of Mega/G-Max forms if applicable]...

**## Combat Profile**
* **Stats:** HP [Val], Attack [Val], Defense [Val], Sp. Atk [Val], Sp. Def [Val], Speed [Val].
* **Archetype:** [Role Name] (e.g., Fast Special Sweeper).
* **Type Matchups:** It is **weak to [Types]** (mentioning any 4x weaknesses) and **resists [Types]**.
* **Move Selection:** Capitalizing on its stats, key moves include **[Move 1], [Move 2], [Move 3], and [Move 4]**.
* **Abilities:** [Ability Name] ([Effect description])...

**## Evolution & Biology**
[Name] is part of a [Number]-stage evolutionary line. It evolves from [Pre-evo] when [Condition]... It belongs to the [Egg Group] group...

---
**Input Data:**
[JSON Data provided in the user prompt]
"""

# %%
LIST_CACHE_FILE = Path("pokemon_list.json")

def get_all_pokemon():
    if LIST_CACHE_FILE.exists():
        print("Loading Pokemon list from cache...")
        try:
            with open(LIST_CACHE_FILE, "r") as f:
                return json.load(f)
        except Exception as e:
            print(f"Error reading cache, fetching fresh list. Error: {e}")

    print("Fetching list of all Pokemon from API...")
    url = "https://pokeapi.co/api/v2/pokemon?limit=10000"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        pokemon_list = [p["name"] for p in data["results"]]
        
        # Save to cache
        with open(LIST_CACHE_FILE, "w") as f:
            json.dump(pokemon_list, f)
        print(f"Saved {len(pokemon_list)} Pokemon to {LIST_CACHE_FILE}")
        return pokemon_list
    except Exception as e:
        print(f"Error fetching Pokemon list: {e}")
        return []

len(get_all_pokemon())

# %%
# Configuration
OUTPUT_DIR = Path("raw/pokemon")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
MODEL_NAME = "gemini-3-flash-preview"
MAX_WORKERS = 10
ABORT_LIMIT = 20

# Global state
error_count = 0
error_lock = threading.Lock()
abort_event = threading.Event()



def generate_pokemon_data(pokemon_name):
    global error_count
    
    if abort_event.is_set():
        return

    # Optimistic existing file check
    existing = list(OUTPUT_DIR.glob(f"*_{pokemon_name}.md"))
    if existing:
        # print(f"Skipping {pokemon_name} (File exists)")
        return

    # Initialize Clients (Thread-safe)
    pokemon_client = PokemonAPIClient(enable_cache=False)
    llm_client = LLMQuery(model=MODEL_NAME, system_prompt=SYSTEM_PROMPT)
    
    time.sleep(0.5)
    
    try:
        print(f"Processing {pokemon_name}...")
        details = pokemon_client.get_pokemon_details(pokemon_name)
        if "error" in details:
            raise Exception(f"API Error: {details.get('error')}")
            
        type_info = []
        for t in details.get("types", []):
            t_info = pokemon_client.get_type_info(t)
            if "error" not in t_info:
                type_info.append(t_info)

        context = {"pokemon_details": details, "type_info": type_info}
        user_prompt = f"Here is the data for {pokemon_name}:\n```json\n{json.dumps(context, indent=2)}\n```"
        
        response = None
        for attempt in range(3):
            try:
                response = llm_client.query(user_prompt=user_prompt, use_history=False)
                if response: break
            except Exception as e:
                if attempt == 2: raise e
                time.sleep(2 ** attempt)

        p_id = details.get("id", 0)
        file_prefix = f"{p_id:04d}_{pokemon_name}"
        
        with open(OUTPUT_DIR / f"{file_prefix}.json", "w", encoding="utf-8") as f:
            json.dump(context, f, indent=2)
        with open(OUTPUT_DIR / f"{file_prefix}.md", "w", encoding="utf-8") as f:
            f.write(response)
            
        print(f"Saved {file_prefix}.md")
        
    except Exception as e:
        with error_lock:
            error_count += 1
            print(f"Error processing {pokemon_name}: {e} (Count: {error_count})")
            if error_count >= ABORT_LIMIT:
                print("Aborting generation due to error limit.")
                abort_event.set()

# Main Execution
try:
    POKEMON_LIST = get_all_pokemon()
    if POKEMON_LIST:
        print(f"Starting generation for {len(POKEMON_LIST)} Pokemon with {MAX_WORKERS} threads...")
        with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
            list(executor.map(generate_pokemon_data, POKEMON_LIST))
    else:
        print("No Pokemon found to process.")
    print("Generation complete.")
except KeyboardInterrupt:
    print("Generation interrupted.")
except Exception as e:
    print(f"Fatal error: {e}")

# %%
SYSTEM_PROMPT_MOVES = """You are an expert Pokémon Battle Mechanics Analyst. Your task is to process raw JSON data for a specific **Move** into a **semantically dense, comprehensive profile** optimized for Vector Search retrieval (RAG).

### Core Instruction:
Use the JSON as the **primary source** for stats, effects, and the learner list. Use **World Knowledge** to interpret competitive viability, compare it to rival moves, and **expand on the visual/thematic description** to ensure the text is rich with searchable keywords.

### STRICT Output Constraints:
1.  **No Chatter:** Start immediately with the Markdown headers.
2.  **Smart Filtering:** Do NOT list every Pokémon in `learned_by`. Filter the list to **Prominent Users** (Starters, Legendaries, Competitive Staples).
3.  **Terminology:** Use standard competitive terms (STAB, Coverage, Check, Nuke, Pivot, Wallbreaker).

### Processing Guidelines:

**1. Identity & Flavor (Enriched)**
* **Basics:** Combine `name`, `type`, `damage_class`, and `generation`.
* **Visual Description:** Combine the provided `flavor_text` with World Knowledge to describe the **visual execution** of the move. (e.g., "The user clenches its fist to deliver a high-impact blow..."). *Constraint: Describe only the visual, do not invent new mechanics.*
* **Mechanics:** Interpret `effect_description`. Explicitly label **Secondary Effects** (e.g., "10% chance to Burn") and **Mechanics** (e.g., "Bypasses Accuracy," "Sound-based").

**2. Competitive Profile**
* **Stat Block:** List **Power, Accuracy, PP** in a bullet point.
* **Archetype:** Assign a role based on stats:
    * *Power > 100 / Low Acc:* "High-Risk Nuke" / "Wallbreaker."
    * *Power 80-95 / 100 Acc:* "Reliable STAB" / "Consistency Option."
    * *Status Move:* "Utility" / "Setup."
    * *Outclassed:* If the move is strictly worse than another (e.g., Mega Punch vs Return), label it as "Early-game Filler" or "Niche."
* **Context:** Compare it to its main rival (e.g., Flamethrower vs. Fire Blast).
* **Attributes:** Mention if the move makes **Contact** or has tags like **Punching, Biting, Sound, or Slice**. Explicitly name Abilities that interact with it (e.g., "Boosted by Iron Fist").

**3. Distribution & Users**
* **Learner Analysis:** Analyze the `learned_by` list.
    * **Prominent Users:** 2-3 iconic STAB users.
    * **Synergy Users:** **Crucial.** If the move interacts with an Ability (Iron Fist, Strong Jaw, etc.), list Pokémon with that ability who learn it.
    * **Coverage Users:** Non-STAB users who carry it for specific threats.
* **Acquisition:** Mention if it is a common **TM, TR, or Move Tutor** move.

---

### Required Output Structure:

**## Identity & Mechanics**
**[Move Name]** is a [Damage Class] [Type]-type move introduced in [Generation].
* **Description:** [Expanded visual/thematic description for RAG searchability].
* **Effect:** [Detailed description].
* **Secondary Effect:** [Chance]% chance to [Status/Stat Drop] (or "None").
* **Targeting:** [Single/Spread/Self].

**## Competitive Profile**
* **Stats:** Power [Val], Accuracy [Val]%, PP [Val].
* **Role:** [Archetype] (e.g., Reliable STAB / Niche).
* **Usage:** [Comparison to rivals]. It deals **Super Effective** damage to **[Weakness Types]** types.
* **Attributes:** [Contact/Sound/Punching tags]. [Interaction with Abilities if applicable].

**## Distribution & Notable Users**
It has a [Wide/Narrow] distribution ([Total] learners).
* **Prominent Users:** Commonly utilized by **[User 1]**, **[User 2]**, and **[User 3]**.
* **Synergy Users:** [If applicable, users with boosting Abilities like Iron Fist/Strong Jaw].
* **Coverage Utility:** Frequently seen on non-[Type] Pokémon like **[User 4]** to counter [Counter-Type] threats.
* **Acquisition:** Widely available via **[TM/Tutor]** in [Generations].

---
**Input Data:**
[Provided by User]"""

# %%
MOVES_LIST_CACHE_FILE = Path("moves_list.json")

def get_all_moves():
    if MOVES_LIST_CACHE_FILE.exists():
        print("Loading Moves list from cache...")
        try:
            with open(MOVES_LIST_CACHE_FILE, "r") as f:
                return json.load(f)
        except Exception as e:
            print(f"Error reading cache, fetching fresh list. Error: {e}")

    print("Fetching list of all Moves from API...")
    url = "https://pokeapi.co/api/v2/move?limit=10000"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        moves_list = [m["name"] for m in data["results"]]
        
        # Save to cache
        with open(MOVES_LIST_CACHE_FILE, "w") as f:
            json.dump(moves_list, f)
        print(f"Saved {len(moves_list)} Moves to {MOVES_LIST_CACHE_FILE}")
        return moves_list
    except Exception as e:
        print(f"Error fetching Move list: {e}")
        return []

# %%
MOVES_OUTPUT_DIR = Path("raw/moves")
MOVES_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

MODEL_NAME = "gemini-3-flash-preview"
MAX_WORKERS = 10
ABORT_LIMIT = 20

# Global state for moves
moves_error_count = 0
moves_error_lock = threading.Lock()
moves_abort_event = threading.Event()



def generate_move_data(move_name):
    global moves_error_count
    
    if moves_abort_event.is_set():
        return

    # Optimistic existing file check
    existing = list(MOVES_OUTPUT_DIR.glob(f"*_{move_name}.md"))
    if existing:
        # print(f"Skipping {move_name} (File exists)")
        return

    # Initialize Clients (Thread-safe)
    pokemon_client = PokemonAPIClient(enable_cache=False)
    llm_client = LLMQuery(model=MODEL_NAME, system_prompt=SYSTEM_PROMT_MOVES)
    
    time.sleep(0.5)
    
    try:
        print(f"Processing Move: {move_name}...")
        details = pokemon_client.get_move_details(move_name, learned_by_limit=-1)
        if "error" in details:
            raise Exception(f"API Error: {details.get('error')}")
            
        context = {"move_details": details}
        user_prompt = f"Here is the data for {move_name}:\n```json\n{json.dumps(context, indent=2)}\n```"
        
        response = None
        for attempt in range(3):
            try:
                response = llm_client.query(user_prompt=user_prompt, use_history=False)
                if response: break
            except Exception as e:
                if attempt == 2: raise e
                time.sleep(2 ** attempt)

        m_id = details.get("id", 0)
        file_prefix = f"{m_id:04d}_{move_name}"
        
        with open(MOVES_OUTPUT_DIR / f"{file_prefix}.json", "w", encoding="utf-8") as f:
            json.dump(context, f, indent=2)
        with open(MOVES_OUTPUT_DIR / f"{file_prefix}.md", "w", encoding="utf-8") as f:
            f.write(response)
            
        print(f"Saved {file_prefix}.md")
        
    except Exception as e:
        with moves_error_lock:
            moves_error_count += 1
            print(f"Error processing {move_name}: {e} (Count: {moves_error_count})")
            if moves_error_count >= ABORT_LIMIT:
                print("Aborting moves generation due to error limit.")
                moves_abort_event.set()

# Main Execution for Moves
try:
    MOVES_LIST = get_all_moves()
    if MOVES_LIST:
        print(f"Starting generation for {len(MOVES_LIST)} Moves with {MAX_WORKERS} threads...")
        with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
            list(executor.map(generate_move_data, MOVES_LIST))
    else:
        print("No Moves found to process.")
    print("Moves Generation complete.")
except KeyboardInterrupt:
    print("Moves Generation interrupted.")
except Exception as e:
    print(f"Fatal error in Moves Generation: {e}")
# Out:
# Loading Moves list from cache...
# Starting generation for 937 Moves with 10 threads...
# Processing Move: pay-day...
# Processing Move: fire-punch...
# Processing Move: vice-grip...
# Processing Move: scratch...
# Processing Move: ice-punch...
# Processing Move: thunder-punch...
# Processing Move: guillotine...
# Processing Move: cut...
# Processing Move: swords-dance...
# Processing Move: razor-wind...
# Saved 0014_swords-dance.md
# Processing Move: gust...
# Saved 0011_vice-grip.md
# Saved 0008_ice-punch.md
# Saved 0015_cut.md
# Saved 0006_pay-day.md
# Processing Move: wing-attack...
# Saved 0007_fire-punch.md
# Processing Move: whirlwind...
# Processing Move: fly...Processing Move: bind...
#
# Processing Move: slam...
# Saved 0010_scratch.md
# Saved 0012_guillotine.md
# Processing Move: vine-whip...
# Saved 0013_razor-wind.md
# Processing Move: stomp...
# Processing Move: double-kick...
# Saved 0009_thunder-punch.md
# Processing Move: mega-kick...
# Saved 0016_gust.md
# Saved 0017_wing-attack.md
# Processing Move: jump-kick...
# Processing Move: rolling-kick...
# Saved 0020_bind.md
# Saved 0018_whirlwind.md
# Saved 0019_fly.md
# Saved 0021_slam.md
# Processing Move: sand-attack...
# Processing Move: headbutt...
# Processing Move: horn-attack...
# Processing Move: fury-attack...
# Saved 0022_vine-whip.md
# Processing Move: horn-drill...
# Saved 0024_double-kick.md
# Processing Move: tackle...
# Saved 0023_stomp.md
# Processing Move: body-slam...
# Saved 0025_mega-kick.md
# Processing Move: wrap...
# Saved 0027_rolling-kick.md
# Saved 0026_jump-kick.md
# Processing Move: take-down...
# Processing Move: thrash...
# Saved 0030_horn-attack.md
# Processing Move: double-edge...
# Saved 0028_sand-attack.md
# Saved 0029_headbutt.md
# Processing Move: tail-whip...
# Processing Move: poison-sting...
# Saved 0033_tackle.md
# Saved 0031_fury-attack.md
# Saved 0032_horn-drill.md
# Processing Move: twineedle...
# Processing Move: pin-missile...
# Processing Move: leer...
# Saved 0034_body-slam.md
# Saved 0035_wrap.md
# Processing Move: bite...
# Processing Move: growl...
# Saved 0036_take-down.md
# Processing Move: roar...
# Saved 0037_thrash.md
# Processing Move: sing...
# Saved 0040_poison-sting.md
# Saved 0038_double-edge.md
# Saved 0039_tail-whip.md
# Processing Move: supersonic...
# Processing Move: sonic-boom...
# Processing Move: disable...
# Saved 0043_leer.md
# Processing Move: acid...
# Saved 0042_pin-missile.md
# Processing Move: ember...
# Saved 0041_twineedle.md
# Saved 0044_bite.md
# Processing Move: flamethrower...
# Processing Move: mist...
# Saved 0045_growl.md
# Processing Move: water-gun...
# Saved 0046_roar.md
# Processing Move: hydro-pump...
# Saved 0047_sing.md
# Processing Move: surf...
# Saved 0049_sonic-boom.md
# Processing Move: ice-beam...
# Saved 0052_ember.md
# Processing Move: blizzard...
# Saved 0048_supersonic.md
# Saved 0051_acid.md
# Saved 0053_flamethrower.md
# Saved 0050_disable.md
# Processing Move: psybeam...
# Processing Move: bubble-beam...
# Processing Move: aurora-beam...
# Processing Move: hyper-beam...
# Saved 0054_mist.md
# Processing Move: peck...
# Saved 0055_water-gun.md
# Processing Move: drill-peck...
# Saved 0056_hydro-pump.md
# Saved 0057_surf.md
# Processing Move: submission...
# Processing Move: low-kick...
# Saved 0058_ice-beam.md
# Processing Move: counter...
# Saved 0059_blizzard.md
# Processing Move: seismic-toss...
# Saved 0063_hyper-beam.md
# Processing Move: strength...
# Saved 0060_psybeam.md
# Saved 0061_bubble-beam.md
# Processing Move: absorb...
# Processing Move: mega-drain...
# Saved 0062_aurora-beam.md
# Processing Move: leech-seed...
# Saved 0064_peck.md
# Processing Move: growth...
# Saved 0065_drill-peck.md
# Saved 0066_submission.md
# Processing Move: razor-leaf...
# Processing Move: solar-beam...
# Saved 0067_low-kick.md
# Processing Move: poison-powder...
# Saved 0068_counter.md
# Saved 0069_seismic-toss.md
# Saved 0072_mega-drain.md
# Processing Move: stun-spore...
# Processing Move: sleep-powder...
# Processing Move: petal-dance...
# Saved 0070_strength.md
# Processing Move: string-shot...
# Saved 0071_absorb.md
# Processing Move: dragon-rage...
# Saved 0075_razor-leaf.md
# Saved 0074_growth.md
# Processing Move: fire-spin...
# Saved 0073_leech-seed.md
# Processing Move: thunder-shock...
# Processing Move: thunderbolt...
# Saved 0076_solar-beam.md
# Processing Move: thunder-wave...
# Saved 0077_poison-powder.md
# Processing Move: thunder...
# Saved 0080_petal-dance.md
# Saved 0078_stun-spore.md
# Saved 0079_sleep-powder.md
# Processing Move: rock-throw...
# Processing Move: earthquake...
# Processing Move: fissure...
# Saved 0081_string-shot.md
# Saved 0084_thunder-shock.md
# Processing Move: dig...
# Processing Move: toxic...
# Saved 0083_fire-spin.md
# Processing Move: confusion...
# Saved 0086_thunder-wave.md
# Saved 0082_dragon-rage.md
# Processing Move: psychic...
# Processing Move: hypnosis...
# Saved 0085_thunderbolt.md
# Processing Move: meditate...
# Saved 0091_dig.md
# Saved 0088_rock-throw.md
# Saved 0087_thunder.md
# Saved 0089_earthquake.md
# Processing Move: agility...
# Processing Move: rage...
# Processing Move: quick-attack...
# Processing Move: teleport...
# Saved 0093_confusion.md
# Saved 0094_psychic.md
# Processing Move: night-shade...
# Processing Move: mimic...
# Saved 0090_fissure.md
# Saved 0095_hypnosis.md
# Processing Move: screech...
# Processing Move: double-team...
# Saved 0092_toxic.md
# Processing Move: recover...
# Saved 0096_meditate.md
# Processing Move: harden...
# Saved 0097_agility.md
# Processing Move: minimize...
# Saved 0100_teleport.md
# Saved 0098_quick-attack.md
# Saved 0099_rage.md
# Processing Move: smokescreen...
# Processing Move: withdraw...
# Processing Move: confuse-ray...
# Saved 0102_mimic.md
# Saved 0101_night-shade.md
# Processing Move: defense-curl...
# Processing Move: barrier...
# Saved 0104_double-team.md
# Saved 0103_screech.md
# Processing Move: light-screen...
# Processing Move: haze...
# Saved 0105_recover.md
# Processing Move: reflect...
# Saved 0106_harden.md
# Processing Move: focus-energy...
# Saved 0107_minimize.md
# Saved 0110_withdraw.md
# Processing Move: bide...
# Saved 0111_defense-curl.md
# Processing Move: metronome...
# Saved 0109_confuse-ray.md
# Saved 0108_smokescreen.md
# Processing Move: mirror-move...
# Saved 0112_barrier.md
# Processing Move: self-destruct...
# Processing Move: egg-bomb...
# Processing Move: lick...
# Saved 0114_haze.md
# Processing Move: smog...
# Saved 0115_reflect.md
# Processing Move: sludge...
# Saved 0113_light-screen.md
# Processing Move: bone-club...
# Saved 0118_metronome.md
# Saved 0122_lick.md
# Processing Move: fire-blast...
# Processing Move: waterfall...
# Saved 0121_egg-bomb.md
# Saved 0117_bide.md
# Saved 0120_self-destruct.md
# Processing Move: clamp...
# Processing Move: swift...
# Saved 0116_focus-energy.md
# Processing Move: skull-bash...
# Saved 0119_mirror-move.md
# Processing Move: spike-cannon...
# Processing Move: constrict...
# Saved 0123_smog.md
# Processing Move: amnesia...
# Saved 0125_bone-club.md
# Saved 0124_sludge.md
# Processing Move: kinesis...
# Processing Move: soft-boiled...
# Saved 0126_fire-blast.md
# Processing Move: high-jump-kick...
# Saved 0127_waterfall.md
# Saved 0128_clamp.md
# Processing Move: glare...
# Saved 0129_swift.md
# Processing Move: dream-eater...
# Saved 0130_skull-bash.md
# Processing Move: poison-gas...
# Processing Move: barrage...
# Saved 0132_constrict.md
# Saved 0131_spike-cannon.md
# Processing Move: lovely-kiss...Processing Move: leech-life...
#
# Saved 0133_amnesia.md
# Processing Move: sky-attack...
# Saved 0135_soft-boiled.md
# Saved 0134_kinesis.md
# Processing Move: transform...
# Processing Move: bubble...
# Saved 0136_high-jump-kick.md
# Saved 0138_dream-eater.md
# Saved 0140_barrage.md
# Processing Move: dizzy-punch...
# Processing Move: spore...
# Saved 0139_poison-gas.md
# Processing Move: flash...
# Processing Move: psywave...
# Saved 0137_glare.md
# Saved 0141_leech-life.md
# Saved 0143_sky-attack.md
# Processing Move: splash...
# Processing Move: acid-armor...
# Processing Move: crabhammer...
# Saved 0142_lovely-kiss.md
# Processing Move: explosion...
# Saved 0144_transform.md
# Saved 0145_bubble.md
# Processing Move: fury-swipes...
# Processing Move: bonemerang...
# Saved 0146_dizzy-punch.md
# Processing Move: rest...
# Saved 0147_spore.md
# Processing Move: rock-slide...
# Saved 0152_crabhammer.md
# Saved 0148_flash.md
# Saved 0151_acid-armor.md
# Saved 0150_splash.md
# Processing Move: hyper-fang...
# Processing Move: sharpen...
# Processing Move: conversion...
# Saved 0149_psywave.md
# Processing Move: tri-attack...
# Processing Move: super-fang...
# Saved 0155_bonemerang.md
# Processing Move: slash...
# Saved 0153_explosion.md
# Saved 0154_fury-swipes.md
# Processing Move: substitute...
# Processing Move: struggle...
# Saved 0157_rock-slide.md
# Saved 0159_sharpen.md
# Processing Move: sketch...
# Saved 0161_tri-attack.md
# Processing Move: triple-kick...
# Saved 0156_rest.md
# Processing Move: thief...
# Processing Move: spider-web...
# Saved 0158_hyper-fang.md
# Processing Move: mind-reader...
# Saved 0160_conversion.md
# Saved 0162_super-fang.md
# Processing Move: nightmare...
# Processing Move: flame-wheel...
# Saved 0163_slash.md
# Processing Move: snore...
# Saved 0165_struggle.md
# Processing Move: curse...
# Saved 0164_substitute.md
# Processing Move: flail...
# Saved 0168_thief.md
# Processing Move: conversion-2...
# Saved 0166_sketch.md
# Saved 0169_spider-web.md
# Processing Move: aeroblast...
# Saved 0167_triple-kick.md
# Processing Move: cotton-spore...
# Processing Move: reversal...
# Saved 0172_flame-wheel.md
# Processing Move: spite...
# Saved 0170_mind-reader.md
# Saved 0171_nightmare.md
# Processing Move: powder-snow...
# Processing Move: protect...
# Saved 0173_snore.md
# Processing Move: mach-punch...
# Saved 0175_flail.md
# Saved 0174_curse.md
# Saved 0177_aeroblast.md
# Processing Move: scary-face...
# Processing Move: feint-attack...
# Processing Move: sweet-kiss...
# Saved 0179_reversal.md
# Processing Move: belly-drum...
# Saved 0178_cotton-spore.md
# Processing Move: sludge-bomb...
# Saved 0176_conversion-2.md
# Saved 0181_powder-snow.md
# Saved 0180_spite.md
# Processing Move: mud-slap...
# Processing Move: octazooka...
# Processing Move: spikes...
# Saved 0183_mach-punch.md
# Processing Move: zap-cannon...
# Saved 0182_protect.md
# Saved 0185_feint-attack.md
# Processing Move: foresight...
# Processing Move: destiny-bond...
# Saved 0184_scary-face.md
# Processing Move: perish-song...
# Saved 0186_sweet-kiss.md
# Processing Move: icy-wind...
# Saved 0187_belly-drum.md
# Saved 0188_sludge-bomb.md
# Processing Move: detect...
# Processing Move: bone-rush...
# Saved 0189_mud-slap.md
# Processing Move: lock-on...
# Saved 0190_octazooka.md
# Processing Move: outrage...
# Saved 0191_spikes.md
# Processing Move: sandstorm...
# Saved 0192_zap-cannon.md
# Processing Move: giga-drain...
# Saved 0193_foresight.md
# Processing Move: endure...
# Saved 0194_destiny-bond.md
# Processing Move: charm...
# Saved 0196_icy-wind.md
# Processing Move: rollout...
# Saved 0195_perish-song.md
# Processing Move: false-swipe...
# Saved 0197_detect.md
# Processing Move: swagger...
# Saved 0200_outrage.md
# Processing Move: milk-drink...
# Saved 0198_bone-rush.md
# Saved 0201_sandstorm.md
# Saved 0199_lock-on.md
# Processing Move: spark...
# Processing Move: fury-cutter...
# Processing Move: steel-wing...
# Saved 0202_giga-drain.md
# Processing Move: mean-look...
# Saved 0204_charm.md
# Processing Move: attract...
# Saved 0203_endure.md
# Saved 0206_false-swipe.md
# Processing Move: sleep-talk...
# Processing Move: heal-bell...
# Saved 0205_rollout.md
# Processing Move: return...
# Saved 0211_steel-wing.md
# Saved 0207_swagger.md
# Processing Move: present...
# Saved 0208_milk-drink.md
# Processing Move: frustration...
# Processing Move: safeguard...
# Saved 0210_fury-cutter.md
# Saved 0209_spark.md
# Processing Move: pain-split...
# Processing Move: sacred-fire...
# Saved 0212_mean-look.md
# Processing Move: magnitude...
# Saved 0213_attract.md
# Saved 0215_heal-bell.md
# Processing Move: dynamic-punch...
# Processing Move: megahorn...
# Saved 0216_return.md
# Processing Move: dragon-breath...
# Saved 0214_sleep-talk.md
# Processing Move: baton-pass...
# Saved 0217_present.md
# Saved 0218_frustration.md
# Processing Move: encore...
# Processing Move: pursuit...
# Saved 0219_safeguard.md
# Saved 0222_magnitude.md
# Processing Move: rapid-spin...
# Saved 0221_sacred-fire.md
# Processing Move: sweet-scent...
# Saved 0220_pain-split.md
# Processing Move: iron-tail...
# Processing Move: metal-claw...
# Saved 0223_dynamic-punch.md
# Processing Move: vital-throw...
# Saved 0224_megahorn.md
# Processing Move: morning-sun...
# Saved 0225_dragon-breath.md
# Processing Move: synthesis...
# Saved 0226_baton-pass.md
# Processing Move: moonlight...
# Saved 0230_sweet-scent.md
# Saved 0227_encore.md
# Processing Move: hidden-power...
# Saved 0229_rapid-spin.md
# Processing Move: cross-chop...
# Processing Move: twister...
# Saved 0232_metal-claw.md
# Processing Move: rain-dance...
# Saved 0228_pursuit.md
# Saved 0231_iron-tail.md
# Processing Move: sunny-day...
# Processing Move: crunch...
# Saved 0233_vital-throw.md
# Processing Move: mirror-coat...
# Saved 0235_synthesis.md
# Saved 0234_morning-sun.md
# Processing Move: psych-up...
# Processing Move: extreme-speed...
# Saved 0236_moonlight.md
# Saved 0239_twister.md
# Processing Move: ancient-power...
# Saved 0238_cross-chop.md
# Processing Move: shadow-ball...
# Processing Move: future-sight...
# Saved 0237_hidden-power.md
# Processing Move: rock-smash...
# Saved 0242_crunch.md
# Processing Move: whirlpool...
# Saved 0240_rain-dance.md
# Saved 0243_mirror-coat.md
# Processing Move: beat-up...
# Processing Move: fake-out...
# Saved 0241_sunny-day.md
# Processing Move: uproar...
# Saved 0245_extreme-speed.md
# Saved 0244_psych-up.md
# Processing Move: stockpile...
# Processing Move: spit-up...
# Saved 0247_shadow-ball.md
# Saved 0246_ancient-power.md
# Processing Move: swallow...
# Processing Move: heat-wave...
# Saved 0249_rock-smash.md
# Processing Move: hail...
# Saved 0248_future-sight.md
# Processing Move: torment...
# Saved 0250_whirlpool.md
# Processing Move: flatter...
# Saved 0251_beat-up.md
# Saved 0252_fake-out.md
# Processing Move: will-o-wisp...
# Processing Move: memento...
# Saved 0254_stockpile.md
# Saved 0253_uproar.md
# Processing Move: facade...
# Saved 0255_spit-up.md
# Processing Move: focus-punch...
# Processing Move: smelling-salts...
# Saved 0256_swallow.md
# Saved 0257_heat-wave.md
# Processing Move: follow-me...
# Processing Move: nature-power...
# Saved 0259_torment.md
# Processing Move: charge...
# Saved 0258_hail.md
# Processing Move: taunt...
# Saved 0262_memento.md
# Saved 0260_flatter.md
# Processing Move: helping-hand...
# Processing Move: trick...
# Saved 0261_will-o-wisp.md
# Processing Move: role-play...
# Saved 0264_focus-punch.md
# Saved 0265_smelling-salts.md
# Processing Move: wish...
# Processing Move: assist...
# Saved 0266_follow-me.md
# Processing Move: ingrain...
# Saved 0263_facade.md
# Processing Move: superpower...
# Saved 0267_nature-power.md
# Processing Move: magic-coat...
# Saved 0268_charge.md
# Processing Move: recycle...
# Saved 0269_taunt.md
# Saved 0272_role-play.md
# Processing Move: revenge...
# Saved 0270_helping-hand.md
# Processing Move: brick-break...
# Processing Move: yawn...
# Saved 0271_trick.md
# Saved 0273_wish.md
# Processing Move: knock-off...
# Processing Move: endeavor...
# Saved 0274_assist.md
# Saved 0275_ingrain.md
# Processing Move: eruption...
# Saved 0276_superpower.md
# Processing Move: skill-swap...
# Saved 0277_magic-coat.md
# Processing Move: imprison...
# Processing Move: refresh...
# Saved 0278_recycle.md
# Processing Move: grudge...
# Saved 0280_brick-break.md
# Saved 0279_revenge.md
# Processing Move: snatch...
# Processing Move: secret-power...
# Saved 0281_yawn.md
# Processing Move: dive...
# Saved 0283_endeavor.md
# Processing Move: arm-thrust...
# Saved 0282_knock-off.md
# Processing Move: camouflage...
# Saved 0287_refresh.md
# Processing Move: tail-glow...
# Saved 0286_imprison.md
# Processing Move: luster-purge...
# Saved 0285_skill-swap.md
# Saved 0284_eruption.md
# Processing Move: mist-ball...
# Processing Move: feather-dance...
# Saved 0288_grudge.md
# Processing Move: teeter-dance...
# Saved 0289_snatch.md
# Processing Move: blaze-kick...
# Saved 0291_dive.md
# Processing Move: mud-sport...
# Saved 0290_secret-power.md
# Saved 0292_arm-thrust.md
# Processing Move: ice-ball...
# Processing Move: needle-arm...
# Saved 0293_camouflage.md
# Saved 0294_tail-glow.md
# Processing Move: slack-off...
# Processing Move: hyper-voice...
# Saved 0295_luster-purge.md
# Processing Move: poison-fang...
# Saved 0296_mist-ball.md
# Processing Move: crush-claw...
# Saved 0297_feather-dance.md
# Processing Move: blast-burn...
# Saved 0299_blaze-kick.md
# Processing Move: hydro-cannon...
# Saved 0298_teeter-dance.md
# Processing Move: meteor-mash...
# Saved 0300_mud-sport.md
# Processing Move: astonish...
# Saved 0301_ice-ball.md
# Processing Move: weather-ball...
# Saved 0302_needle-arm.md
# Processing Move: aromatherapy...
# Saved 0305_poison-fang.md
# Processing Move: fake-tears...
# Saved 0303_slack-off.md
# Processing Move: air-cutter...
# Saved 0304_hyper-voice.md
# Processing Move: overheat...
# Saved 0306_crush-claw.md
# Processing Move: odor-sleuth...
# Saved 0307_blast-burn.md
# Processing Move: rock-tomb...
# Saved 0308_hydro-cannon.md
# Processing Move: silver-wind...
# Saved 0309_meteor-mash.md
# Processing Move: metal-sound...
# Saved 0310_astonish.md
# Processing Move: grass-whistle...
# Saved 0311_weather-ball.md
# Processing Move: tickle...
# Saved 0313_fake-tears.md
# Saved 0314_air-cutter.md
# Processing Move: cosmic-power...
# Saved 0312_aromatherapy.md
# Processing Move: water-spout...
# Processing Move: signal-beam...
# Saved 0315_overheat.md
# Processing Move: shadow-punch...
# Saved 0317_rock-tomb.md
# Processing Move: extrasensory...
# Saved 0316_odor-sleuth.md
# Processing Move: sky-uppercut...
# Saved 0318_silver-wind.md
# Processing Move: sand-tomb...
# Saved 0319_metal-sound.md
# Processing Move: sheer-cold...
# Saved 0320_grass-whistle.md
# Saved 0321_tickle.md
# Saved 0322_cosmic-power.md
# Processing Move: muddy-water...
# Processing Move: bullet-seed...
# Processing Move: aerial-ace...
# Saved 0323_water-spout.md
# Processing Move: icicle-spear...
# Saved 0324_signal-beam.md
# Saved 0326_extrasensory.md
# Processing Move: iron-defense...
# Processing Move: block...
# Saved 0327_sky-uppercut.md
# Saved 0325_shadow-punch.md
# Processing Move: howl...
# Processing Move: dragon-claw...
# Saved 0328_sand-tomb.md
# Processing Move: frenzy-plant...
# Saved 0329_sheer-cold.md
# Saved 0332_aerial-ace.md
# Saved 0330_muddy-water.md
# Processing Move: bulk-up...
# Processing Move: bounce...
# Processing Move: mud-shot...
# Saved 0331_bullet-seed.md
# Saved 0333_icicle-spear.md
# Processing Move: poison-tail...
# Processing Move: covet...
# Saved 0334_iron-defense.mdSaved 0335_block.md
#
# Processing Move: volt-tackle...
# Processing Move: magical-leaf...
# Saved 0336_howl.md
# Saved 0337_dragon-claw.md
# Processing Move: water-sport...
# Processing Move: calm-mind...
# Saved 0338_frenzy-plant.md
# Processing Move: leaf-blade...
# Saved 0341_mud-shot.md
# Processing Move: dragon-dance...
# Saved 0339_bulk-up.md
# Saved 0340_bounce.md
# Saved 0342_poison-tail.md
# Processing Move: rock-blast...
# Processing Move: shock-wave...
# Processing Move: water-pulse...
# Saved 0344_volt-tackle.md
# Processing Move: doom-desire...
# Saved 0347_calm-mind.md
# Saved 0343_covet.md
# Processing Move: psycho-boost...
# Processing Move: roost...
# Saved 0345_magical-leaf.md
# Processing Move: gravity...
# Saved 0346_water-sport.md
# Processing Move: miracle-eye...
# Saved 0348_leaf-blade.md
# Processing Move: wake-up-slap...
# Saved 0351_shock-wave.md
# Saved 0349_dragon-dance.md
# Processing Move: hammer-arm...
# Processing Move: gyro-ball...
# Saved 0352_water-pulse.md
# Saved 0350_rock-blast.md
# Processing Move: healing-wish...
# Processing Move: brine...
# Saved 0355_roost.md
# Processing Move: natural-gift...
# Saved 0354_psycho-boost.md
# Processing Move: feint...
# Saved 0357_miracle-eye.md
# Saved 0353_doom-desire.md
# Processing Move: pluck...
# Processing Move: tailwind...
# Saved 0358_wake-up-slap.md
# Processing Move: acupressure...
# Saved 0356_gravity.md
# Processing Move: metal-burst...
# Saved 0359_hammer-arm.md
# Processing Move: u-turn...
# Saved 0361_healing-wish.md
# Saved 0362_brine.md
# Saved 0360_gyro-ball.md
# Processing Move: close-combat...
# Processing Move: payback...
# Processing Move: assurance...
# Saved 0364_feint.md
# Saved 0365_pluck.md
# Saved 0366_tailwind.md
# Processing Move: embargo...
# Saved 0363_natural-gift.md
# Processing Move: fling...
# Processing Move: psycho-shift...
# Processing Move: trump-card...
# Saved 0367_acupressure.md
# Processing Move: heal-block...
# Saved 0368_metal-burst.md
# Processing Move: wring-out...
# Saved 0369_u-turn.md
# Processing Move: power-trick...
# Saved 0372_assurance.md
# Saved 0370_close-combat.md
# Processing Move: gastro-acid...
# Saved 0371_payback.md
# Processing Move: lucky-chant...
# Processing Move: me-first...
# Saved 0375_psycho-shift.md
# Processing Move: copycat...
# Saved 0376_trump-card.md
# Processing Move: power-swap...
# Saved 0374_fling.md
# Processing Move: guard-swap...
# Saved 0373_embargo.md
# Processing Move: punishment...
# Saved 0377_heal-block.md
# Processing Move: last-resort...
# Saved 0378_wring-out.md
# Saved 0379_power-trick.md
# Processing Move: worry-seed...
# Processing Move: sucker-punch...
# Saved 0382_me-first.md
# Saved 0381_lucky-chant.md
# Processing Move: toxic-spikes...
# Processing Move: heart-swap...
# Saved 0380_gastro-acid.md
# Processing Move: aqua-ring...
# Saved 0383_copycat.md
# Processing Move: magnet-rise...
# Saved 0384_power-swap.md
# Processing Move: flare-blitz...
# Saved 0385_guard-swap.md
# Processing Move: force-palm...
# Saved 0386_punishment.md
# Saved 0387_last-resort.md
# Processing Move: aura-sphere...
# Processing Move: rock-polish...
# Saved 0388_worry-seed.md
# Processing Move: poison-jab...
# Saved 0390_toxic-spikes.md
# Saved 0389_sucker-punch.md
# Processing Move: dark-pulse...
# Processing Move: night-slash...
# Saved 0392_aqua-ring.md
# Processing Move: aqua-tail...
# Saved 0391_heart-swap.md
# Saved 0393_magnet-rise.md
# Processing Move: seed-bomb...
# Processing Move: air-slash...
# Saved 0395_force-palm.md
# Saved 0394_flare-blitz.md
# Processing Move: x-scissor...
# Processing Move: bug-buzz...
# Saved 0397_rock-polish.md
# Processing Move: dragon-pulse...
# Saved 0399_dark-pulse.md
# Saved 0396_aura-sphere.md
# Processing Move: dragon-rush...
# Processing Move: power-gem...
# Saved 0398_poison-jab.md
# Processing Move: drain-punch...
# Saved 0401_aqua-tail.md
# Saved 0400_night-slash.md
# Saved 0402_seed-bomb.md
# Processing Move: vacuum-wave...
# Processing Move: focus-blast...
# Processing Move: energy-ball...
# Saved 0403_air-slash.md
# Saved 0404_x-scissor.md
# Processing Move: brave-bird...
# Processing Move: earth-power...
# Saved 0405_bug-buzz.md
# Processing Move: switcheroo...
# Saved 0406_dragon-pulse.md
# Processing Move: giga-impact...
# Saved 0408_power-gem.md
# Saved 0407_dragon-rush.md
# Processing Move: nasty-plot...
# Saved 0412_energy-ball.md
# Saved 0409_drain-punch.md
# Processing Move: bullet-punch...
# Processing Move: avalanche...
# Processing Move: ice-shard...
# Saved 0410_vacuum-wave.md
# Processing Move: shadow-claw...
# Saved 0411_focus-blast.md
# Processing Move: thunder-fang...
# Saved 0414_earth-power.md
# Processing Move: ice-fang...
# Saved 0413_brave-bird.md
# Processing Move: fire-fang...
# Saved 0416_giga-impact.md
# Saved 0415_switcheroo.md
# Processing Move: shadow-sneak...
# Processing Move: mud-bomb...
# Saved 0418_bullet-punch.md
# Processing Move: psycho-cut...
# Saved 0417_nasty-plot.md
# Processing Move: zen-headbutt...
# Saved 0420_ice-shard.md
# Processing Move: mirror-shot...
# Saved 0421_shadow-claw.md
# Saved 0419_avalanche.md
# Processing Move: flash-cannon...
# Processing Move: rock-climb...
# Saved 0422_thunder-fang.md
# Processing Move: defog...
# Saved 0423_ice-fang.md
# Saved 0424_fire-fang.md
# Processing Move: trick-room...
# Processing Move: draco-meteor...
# Saved 0425_shadow-sneak.md
# Saved 0426_mud-bomb.md
# Processing Move: discharge...
# Processing Move: lava-plume...
# Saved 0429_mirror-shot.md
# Saved 0427_psycho-cut.md
# Processing Move: leaf-storm...
# Processing Move: power-whip...
# Saved 0430_flash-cannon.md
# Saved 0428_zen-headbutt.md
# Processing Move: rock-wrecker...
# Processing Move: cross-poison...
# Saved 0431_rock-climb.md
# Processing Move: gunk-shot...
# Saved 0434_draco-meteor.md
# Processing Move: iron-head...
# Saved 0433_trick-room.md
# Processing Move: magnet-bomb...
# Saved 0436_lava-plume.md
# Saved 0432_defog.md
# Processing Move: stone-edge...
# Processing Move: captivate...
# Saved 0438_power-whip.md
# Saved 0435_discharge.md
# Processing Move: stealth-rock...
# Processing Move: grass-knot...
# Saved 0439_rock-wrecker.md
# Saved 0437_leaf-storm.md
# Saved 0440_cross-poison.md
# Processing Move: chatter...
# Processing Move: judgment...
# Processing Move: bug-bite...
# Saved 0441_gunk-shot.md
# Processing Move: charge-beam...
# Saved 0443_magnet-bomb.md
# Processing Move: wood-hammer...
# Saved 0444_stone-edge.md
# Saved 0442_iron-head.md
# Processing Move: aqua-jet...
# Processing Move: attack-order...
# Saved 0445_captivate.md
# Processing Move: defend-order...
# Saved 0446_stealth-rock.md
# Processing Move: heal-order...
# Saved 0450_bug-bite.md
# Saved 0449_judgment.md
# Processing Move: head-smash...
# Processing Move: double-hit...
# Saved 0448_chatter.md
# Saved 0447_grass-knot.md
# Processing Move: spacial-rend...
# Processing Move: roar-of-time...
# Saved 0451_charge-beam.md
# Saved 0452_wood-hammer.md
# Processing Move: lunar-dance...
# Processing Move: crush-grip...
# Saved 0454_attack-order.md
# Saved 0455_defend-order.md
# Processing Move: magma-storm...
# Processing Move: dark-void...
# Saved 0453_aqua-jet.md
# Processing Move: seed-flare...
# Saved 0459_roar-of-time.md
# Saved 0456_heal-order.md
# Processing Move: ominous-wind...
# Saved 0457_head-smash.md
# Saved 0458_double-hit.md
# Processing Move: shadow-force...
# Processing Move: hone-claws...
# Processing Move: wide-guard...
# Saved 0460_spacial-rend.md
# Processing Move: guard-split...
# Saved 0461_lunar-dance.md
# Saved 0462_crush-grip.md
# Processing Move: power-split...
# Processing Move: wonder-room...
# Saved 0463_magma-storm.md
# Processing Move: psyshock...
# Saved 0464_dark-void.md
# Processing Move: venoshock...
# Saved 0465_seed-flare.md
# Processing Move: autotomize...
# Saved 0468_hone-claws.md
# Processing Move: rage-powder...
# Saved 0466_ominous-wind.md
# Saved 0467_shadow-force.md
# Processing Move: telekinesis...
# Processing Move: magic-room...
# Saved 0470_guard-split.md
# Processing Move: smack-down...
# Saved 0469_wide-guard.md
# Processing Move: storm-throw...
# Saved 0471_power-split.md
# Processing Move: flame-burst...
# Saved 0472_wonder-room.md
# Processing Move: sludge-wave...
# Saved 0473_psyshock.md
# Processing Move: quiver-dance...
# Saved 0474_venoshock.md
# Processing Move: heavy-slam...
# Saved 0477_telekinesis.md
# Processing Move: synchronoise...
# Saved 0476_rage-powder.md
# Saved 0478_magic-room.md
# Saved 0475_autotomize.md
# Processing Move: electro-ball...
# Processing Move: soak...
# Processing Move: flame-charge...
# Saved 0479_smack-down.md
# Processing Move: coil...
# Saved 0481_flame-burst.md
# Saved 0480_storm-throw.md
# Processing Move: low-sweep...
# Processing Move: acid-spray...
# Saved 0482_sludge-wave.md
# Processing Move: foul-play...
# Saved 0483_quiver-dance.md
# Saved 0485_synchronoise.md
# Processing Move: simple-beam...
# Processing Move: entrainment...
# Saved 0484_heavy-slam.md
# Processing Move: after-you...
# Saved 0486_electro-ball.md
# Saved 0488_flame-charge.md
# Processing Move: round...
# Processing Move: echoed-voice...
# Saved 0487_soak.md
# Processing Move: chip-away...
# Saved 0489_coil.md
# Saved 0490_low-sweep.md
# Processing Move: clear-smog...
# Processing Move: stored-power...
# Saved 0491_acid-spray.md
# Processing Move: quick-guard...
# Saved 0492_foul-play.md
# Processing Move: ally-switch...
# Saved 0495_after-you.md
# Saved 0494_entrainment.md
# Processing Move: scald...
# Processing Move: shell-smash...
# Saved 0493_simple-beam.md
# Processing Move: heal-pulse...
# Saved 0497_echoed-voice.md
# Saved 0496_round.md
# Processing Move: hex...
# Saved 0498_chip-away.md
# Processing Move: sky-drop...
# Processing Move: shift-gear...
# Saved 0500_stored-power.md
# Processing Move: circle-throw...
# Saved 0499_clear-smog.md
# Processing Move: incinerate...
# Saved 0501_quick-guard.md
# Processing Move: quash...
# Saved 0502_ally-switch.md
# Processing Move: acrobatics...
# Saved 0503_scald.md
# Processing Move: reflect-type...
# Saved 0504_shell-smash.md
# Processing Move: retaliate...
# Saved 0505_heal-pulse.md
# Saved 0508_shift-gear.md
# Processing Move: final-gambit...
# Saved 0507_sky-drop.md
# Processing Move: bestow...
# Processing Move: inferno...
# Saved 0506_hex.md
# Saved 0509_circle-throw.md
# Processing Move: water-pledge...
# Processing Move: fire-pledge...
# Saved 0510_incinerate.md
# Processing Move: grass-pledge...
# Saved 0511_quash.md
# Processing Move: volt-switch...
# Saved 0512_acrobatics.md
# Processing Move: struggle-bug...
# Saved 0513_reflect-type.md
# Processing Move: bulldoze...
# Saved 0515_final-gambit.md
# Saved 0516_bestow.md
# Processing Move: frost-breath...
# Saved 0517_inferno.md
# Processing Move: dragon-tail...
# Saved 0520_grass-pledge.md
# Saved 0518_water-pledge.md
# Processing Move: work-up...
# Processing Move: electroweb...
# Processing Move: wild-charge...
# Saved 0514_retaliate.md
# Processing Move: drill-run...
# Saved 0519_fire-pledge.md
# Saved 0521_volt-switch.md
# Processing Move: dual-chop...
# Processing Move: heart-stamp...
# Saved 0522_struggle-bug.md
# Saved 0523_bulldoze.md
# Processing Move: horn-leech...
# Processing Move: sacred-sword...
# Saved 0526_work-up.md
# Processing Move: razor-shell...
# Saved 0529_drill-run.md
# Saved 0525_dragon-tail.md
# Saved 0528_wild-charge.md
# Saved 0527_electroweb.md
# Processing Move: heat-crash...
# Processing Move: leaf-tornado...
# Processing Move: steamroller...
# Processing Move: cotton-guard...
# Saved 0530_dual-chop.md
# Saved 0524_frost-breath.md
# Processing Move: night-daze...
# Processing Move: psystrike...
# Saved 0531_heart-stamp.md
# Processing Move: tail-slap...
# Saved 0532_horn-leech.md
# Processing Move: hurricane...
# Saved 0533_sacred-sword.md
# Processing Move: head-charge...
# Saved 0534_razor-shell.md
# Processing Move: gear-grind...
# Saved 0536_leaf-tornado.md
# Saved 0539_night-daze.md
# Processing Move: searing-shot...
# Saved 0537_steamroller.md
# Processing Move: techno-blast...
# Saved 0535_heat-crash.md
# Processing Move: relic-song...
# Processing Move: secret-sword...
# Saved 0538_cotton-guard.md
# Saved 0540_psystrike.md
# Processing Move: glaciate...
# Processing Move: bolt-strike...
# Saved 0541_tail-slap.md
# Saved 0543_head-charge.md
# Saved 0542_hurricane.md
# Processing Move: blue-flare...
# Processing Move: fiery-dance...
# Processing Move: freeze-shock...
# Saved 0545_searing-shot.md
# Saved 0544_gear-grind.md
# Processing Move: ice-burn...
# Processing Move: snarl...
# Saved 0547_relic-song.md
# Processing Move: icicle-crash...
# Saved 0546_techno-blast.md
# Saved 0548_secret-sword.md
# Processing Move: fusion-flare...
# Processing Move: v-create...
# Saved 0550_bolt-strike.md
# Processing Move: fusion-bolt...
# Saved 0549_glaciate.md
# Saved 0552_fiery-dance.md
# Saved 0551_blue-flare.md
# Processing Move: flying-press...
# Processing Move: mat-block...
# Saved 0553_freeze-shock.md
# Processing Move: belch...
# Processing Move: rototiller...
# Saved 0555_snarl.md
# Saved 0554_ice-burn.md
# Processing Move: sticky-web...
# Processing Move: fell-stinger...
# Saved 0556_icicle-crash.md
# Processing Move: phantom-force...
# Saved 0557_v-create.md
# Saved 0558_fusion-flare.md
# Processing Move: trick-or-treat...
# Processing Move: noble-roar...
# Saved 0559_fusion-bolt.md
# Processing Move: ion-deluge...
# Saved 0562_belch.md
# Saved 0560_flying-press.md
# Processing Move: parabolic-charge...
# Processing Move: forests-curse...
# Saved 0563_rototiller.md
# Saved 0561_mat-block.md
# Processing Move: petal-blizzard...
# Processing Move: freeze-dry...
# Saved 0565_fell-stinger.mdSaved 0564_sticky-web.md
#
# Processing Move: disarming-voice...Processing Move: parting-shot...
#
# Saved 0567_trick-or-treat.md
# Saved 0566_phantom-force.md
# Processing Move: topsy-turvy...
# Saved 0568_noble-roar.md
# Processing Move: draining-kiss...
# Processing Move: crafty-shield...
# Saved 0569_ion-deluge.md
# Saved 0571_forests-curse.md
# Processing Move: flower-shield...
# Processing Move: grassy-terrain...
# Saved 0572_petal-blizzard.md
# Saved 0570_parabolic-charge.md
# Processing Move: misty-terrain...
# Saved 0573_freeze-dry.md
# Processing Move: electrify...
# Processing Move: play-rough...
# Saved 0574_disarming-voice.md
# Processing Move: fairy-wind...
# Saved 0575_parting-shot.md
# Processing Move: moonblast...
# Saved 0577_draining-kiss.md
# Saved 0576_topsy-turvy.md
# Processing Move: boomburst...
# Processing Move: fairy-lock...
# Saved 0578_crafty-shield.md
# Processing Move: kings-shield...
# Saved 0584_fairy-wind.md
# Saved 0581_misty-terrain.md
# Processing Move: play-nice...
# Saved 0579_flower-shield.md
# Processing Move: confide...
# Saved 0580_grassy-terrain.md
# Processing Move: diamond-storm...
# Processing Move: steam-eruption...
# Saved 0582_electrify.md
# Processing Move: hyperspace-hole...
# Saved 0583_play-rough.md
# Processing Move: water-shuriken...
# Saved 0585_moonblast.md
# Processing Move: mystical-fire...
# Saved 0586_boomburst.md
# Processing Move: spiky-shield...
# Saved 0588_kings-shield.md
# Saved 0587_fairy-lock.md
# Processing Move: aromatic-mist...
# Processing Move: eerie-impulse...
# Saved 0592_steam-eruption.md
# Saved 0589_play-nice.md
# Processing Move: venom-drench...
# Processing Move: powder...
# Saved 0591_diamond-storm.md
# Processing Move: geomancy...
# Saved 0590_confide.md
# Processing Move: magnetic-flux...
# Saved 0594_water-shuriken.md
# Saved 0593_hyperspace-hole.md
# Processing Move: happy-hour...
# Processing Move: electric-terrain...
# Saved 0595_mystical-fire.md
# Processing Move: dazzling-gleam...
# Saved 0596_spiky-shield.md
# Processing Move: celebrate...
# Saved 0598_eerie-impulse.md
# Processing Move: hold-hands...
# Saved 0601_geomancy.md
# Saved 0597_aromatic-mist.md
# Processing Move: nuzzle...
# Processing Move: baby-doll-eyes...
# Saved 0599_venom-drench.md
# Saved 0600_powder.md
# Processing Move: hold-back...
# Processing Move: infestation...
# Saved 0602_magnetic-flux.md
# Saved 0603_happy-hour.md
# Processing Move: power-up-punch...
# Saved 0604_electric-terrain.md
# Processing Move: oblivion-wing...
# Processing Move: thousand-arrows...
# Saved 0605_dazzling-gleam.md
# Processing Move: thousand-waves...
# Saved 0606_celebrate.md
# Processing Move: lands-wrath...
# Saved 0607_hold-hands.md
# Processing Move: light-of-ruin...
# Saved 0608_baby-doll-eyes.md
# Saved 0609_nuzzle.md
# Processing Move: origin-pulse...
# Processing Move: precipice-blades...
# Saved 0610_hold-back.md
# Processing Move: dragon-ascent...
# Saved 0611_infestation.md
# Processing Move: hyperspace-fury...
# Saved 0612_power-up-punch.md
# Saved 0613_oblivion-wing.md
# Processing Move: breakneck-blitz--physical...
# Processing Move: breakneck-blitz--special...
# Saved 0614_thousand-arrows.md
# Processing Move: all-out-pummeling--physical...
# Saved 0615_thousand-waves.md
# Saved 0616_lands-wrath.md
# Processing Move: all-out-pummeling--special...
# Processing Move: supersonic-skystrike--physical...
# Saved 0618_origin-pulse.md
# Processing Move: supersonic-skystrike--special...
# Saved 0619_precipice-blades.md
# Saved 0617_light-of-ruin.md
# Processing Move: acid-downpour--physical...
# Processing Move: acid-downpour--special...
# Saved 0620_dragon-ascent.md
# Processing Move: tectonic-rage--physical...
# Saved 0621_hyperspace-fury.md
# Processing Move: tectonic-rage--special...
# Saved 0622_breakneck-blitz--physical.md
# Saved 0624_all-out-pummeling--physical.md
# Processing Move: continental-crush--physical...
# Saved 0623_breakneck-blitz--special.md
# Processing Move: continental-crush--special...
# Processing Move: savage-spin-out--physical...
# Saved 0626_supersonic-skystrike--physical.md
# Processing Move: savage-spin-out--special...
# Saved 0625_all-out-pummeling--special.md
# Saved 0627_supersonic-skystrike--special.md
# Processing Move: never-ending-nightmare--physical...
# Saved 0629_acid-downpour--special.md
# Processing Move: never-ending-nightmare--special...
# Processing Move: corkscrew-crash--physical...
# Saved 0630_tectonic-rage--physical.md
# Saved 0628_acid-downpour--physical.md
# Processing Move: corkscrew-crash--special...
# Processing Move: inferno-overdrive--physical...
# Saved 0631_tectonic-rage--special.md
# Processing Move: inferno-overdrive--special...
# Saved 0633_continental-crush--special.md
# Saved 0632_continental-crush--physical.md
# Processing Move: hydro-vortex--physical...
# Processing Move: hydro-vortex--special...
# Saved 0635_savage-spin-out--special.md
# Processing Move: bloom-doom--physical...
# Saved 0634_savage-spin-out--physical.md
# Processing Move: bloom-doom--special...
# Saved 0637_never-ending-nightmare--special.md
# Saved 0638_corkscrew-crash--physical.md
# Saved 0639_corkscrew-crash--special.md
# Processing Move: gigavolt-havoc--physical...
# Processing Move: gigavolt-havoc--special...
# Processing Move: shattered-psyche--physical...
# Saved 0636_never-ending-nightmare--physical.md
# Processing Move: shattered-psyche--special...
# Saved 0640_inferno-overdrive--physical.md
# Processing Move: subzero-slammer--physical...
# Saved 0643_hydro-vortex--special.md
# Saved 0641_inferno-overdrive--special.md
# Processing Move: subzero-slammer--special...
# Processing Move: devastating-drake--physical...
# Saved 0642_hydro-vortex--physical.md
# Processing Move: devastating-drake--special...
# Saved 0644_bloom-doom--physical.md
# Saved 0645_bloom-doom--special.md
# Processing Move: black-hole-eclipse--physical...
# Processing Move: black-hole-eclipse--special...
# Saved 0646_gigavolt-havoc--physical.md
# Saved 0648_shattered-psyche--physical.md
# Processing Move: twinkle-tackle--physical...
# Saved 0647_gigavolt-havoc--special.md
# Processing Move: twinkle-tackle--special...
# Saved 0649_shattered-psyche--special.md
# Processing Move: catastropika...
# Processing Move: shore-up...
# Saved 0650_subzero-slammer--physical.md
# Processing Move: first-impression...
# Saved 0653_devastating-drake--special.md
# Processing Move: baneful-bunker...
# Saved 0652_devastating-drake--physical.md
# Saved 0651_subzero-slammer--special.md
# Processing Move: spirit-shackle...
# Processing Move: darkest-lariat...
# Saved 0654_black-hole-eclipse--physical.md
# Processing Move: sparkling-aria...
# Saved 0655_black-hole-eclipse--special.md
# Saved 0657_twinkle-tackle--special.md
# Processing Move: ice-hammer...
# Processing Move: floral-healing...
# Saved 0659_shore-up.md
# Saved 0656_twinkle-tackle--physical.md
# Saved 0658_catastropika.md
# Processing Move: high-horsepower...
# Processing Move: strength-sap...
# Processing Move: solar-blade...
# Saved 0660_first-impression.md
# Processing Move: leafage...
# Saved 0661_baneful-bunker.md
# Processing Move: spotlight...
# Saved 0663_darkest-lariat.md
# Processing Move: toxic-thread...
# Saved 0662_spirit-shackle.md
# Processing Move: laser-focus...
# Saved 0665_ice-hammer.md
# Saved 0667_high-horsepower.md
# Processing Move: gear-up...
# Saved 0664_sparkling-aria.md
# Saved 0670_leafage.md
# Processing Move: throat-chop...
# Saved 0666_floral-healing.md
# Processing Move: pollen-puff...
# Processing Move: anchor-shot...
# Processing Move: psychic-terrain...
# Saved 0669_solar-blade.md
# Processing Move: lunge...
# Saved 0668_strength-sap.md
# Processing Move: fire-lash...
# Saved 0672_toxic-thread.md
# Processing Move: power-trip...
# Saved 0671_spotlight.md
# Processing Move: burn-up...
# Saved 0674_gear-up.md
# Saved 0675_throat-chop.md
# Processing Move: speed-swap...
# Processing Move: smart-strike...
# Saved 0680_fire-lash.md
# Saved 0673_laser-focus.md
# Processing Move: purify...
# Saved 0677_anchor-shot.md
# Processing Move: revelation-dance...
# Saved 0679_lunge.md
# Processing Move: core-enforcer...
# Saved 0676_pollen-puff.md
# Processing Move: trop-kick...
# Saved 0678_psychic-terrain.md
# Processing Move: instruct...
# Processing Move: beak-blast...
# Saved 0682_burn-up.md
# Processing Move: clanging-scales...
# Saved 0681_power-trip.md
# Saved 0685_purify.md
# Saved 0690_beak-blast.md
# Processing Move: dragon-hammer...
# Processing Move: brutal-swing...
# Processing Move: aurora-veil...
# Saved 0686_revelation-dance.md
# Saved 0684_smart-strike.md
# Processing Move: sinister-arrow-raid...
# Saved 0687_core-enforcer.md
# Saved 0688_trop-kick.md
# Processing Move: malicious-moonsault...
# Saved 0689_instruct.md
# Processing Move: oceanic-operetta...
# Processing Move: guardian-of-alola...
# Processing Move: soul-stealing-7-star-strike...
# Saved 0683_speed-swap.md
# Processing Move: stoked-sparksurfer...
# Saved 0692_dragon-hammer.md
# Processing Move: pulverizing-pancake...
# Saved 0691_clanging-scales.md
# Processing Move: extreme-evoboost...
# Saved 0694_aurora-veil.md
# Saved 0693_brutal-swing.md
# Saved 0699_soul-stealing-7-star-strike.md
# Processing Move: genesis-supernova...
# Saved 0696_malicious-moonsault.md
# Saved 0695_sinister-arrow-raid.md
# Processing Move: shell-trap...
# Processing Move: fleur-cannon...
# Processing Move: psychic-fangs...
# Processing Move: stomping-tantrum...
# Saved 0697_oceanic-operetta.md
# Processing Move: shadow-bone...
# Saved 0698_guardian-of-alola.md
# Processing Move: accelerock...
# Saved 0700_stoked-sparksurfer.md
# Processing Move: liquidation...
# Saved 0705_fleur-cannon.md
# Saved 0702_extreme-evoboost.md
# Processing Move: prismatic-laser...
# Processing Move: spectral-thief...
# Saved 0706_psychic-fangs.md
# Saved 0703_genesis-supernova.md
# Processing Move: sunsteel-strike...
# Processing Move: moongeist-beam...
# Saved 0710_liquidation.md
# Saved 0707_stomping-tantrum.md
# Saved 0709_accelerock.md
# Processing Move: tearful-look...
# Processing Move: zing-zap...
# Saved 0708_shadow-bone.md
# Processing Move: natures-madness...
# Processing Move: multi-attack...
# Saved 0701_pulverizing-pancake.md
# Saved 0704_shell-trap.md
# Processing Move: 10-000-000-volt-thunderbolt...
# Processing Move: mind-blown...
# Saved 0712_spectral-thief.md
# Processing Move: plasma-fists...
# Saved 0711_prismatic-laser.md
# Saved 0714_moongeist-beam.md
# Processing Move: photon-geyser...
# Saved 0713_sunsteel-strike.md
# Processing Move: light-that-burns-the-sky...
# Processing Move: searing-sunraze-smash...
# Saved 0716_zing-zap.md
# Processing Move: menacing-moonraze-maelstrom...
# Saved 0719_10-000-000-volt-thunderbolt.md
# Saved 0715_tearful-look.md
# Saved 0720_mind-blown.md
# Processing Move: lets-snuggle-forever...
# Processing Move: splintered-stormshards...
# Processing Move: clangorous-soulblaze...
# Saved 0718_multi-attack.md
# Processing Move: zippy-zap...
# Saved 0717_natures-madness.md
# Processing Move: splishy-splash...
# Saved 0721_plasma-fists.md
# Saved 0722_photon-geyser.md
# Processing Move: floaty-fall...
# Processing Move: pika-papow...
# Saved 0724_searing-sunraze-smash.md
# Saved 0723_light-that-burns-the-sky.md
# Processing Move: bouncy-bubble...
# Processing Move: buzzy-buzz...
# Saved 0725_menacing-moonraze-maelstrom.md
# Saved 0726_lets-snuggle-forever.md
# Saved 0728_clangorous-soulblaze.md
# Processing Move: sizzly-slide...
# Processing Move: glitzy-glow...
# Processing Move: baddy-bad...
# Saved 0727_splintered-stormshards.md
# Processing Move: sappy-seed...
# Saved 0730_splishy-splash.md
# Saved 0729_zippy-zap.md
# Processing Move: freezy-frost...
# Processing Move: sparkly-swirl...
# Saved 0734_buzzy-buzz.md
# Processing Move: veevee-volley...
# Saved 0731_floaty-fall.md
# Saved 0732_pika-papow.md
# Processing Move: double-iron-bash...
# Processing Move: max-guard...
# Saved 0733_bouncy-bubble.md
# Processing Move: dynamax-cannon...
# Saved 0737_baddy-bad.md
# Saved 0736_glitzy-glow.md
# Processing Move: snipe-shot...
# Processing Move: jaw-lock...
# Saved 0738_sappy-seed.md
# Saved 0735_sizzly-slide.md
# Processing Move: stuff-cheeks...
# Processing Move: no-retreat...
# Saved 0740_sparkly-swirl.md
# Saved 0739_freezy-frost.md
# Processing Move: tar-shot...
# Processing Move: magic-powder...
# Saved 0741_veevee-volley.md
# Processing Move: dragon-darts...
# Saved 0744_dynamax-cannon.md
# Saved 0743_max-guard.md
# Processing Move: teatime...
# Processing Move: octolock...
# Saved 0742_double-iron-bash.md
# Processing Move: bolt-beak...
# Saved 0745_snipe-shot.md
# Saved 0746_jaw-lock.md
# Processing Move: fishious-rend...
# Processing Move: court-change...
# Saved 0748_no-retreat.md
# Saved 0749_tar-shot.md
# Processing Move: max-flare...
# Processing Move: max-flutterby...
# Saved 0747_stuff-cheeks.md
# Processing Move: max-lightning...
# Saved 0750_magic-powder.md
# Processing Move: max-strike...
# Saved 0752_teatime.md
# Saved 0751_dragon-darts.md
# Processing Move: max-knuckle...
# Processing Move: max-phantasm...
# Saved 0754_bolt-beak.md
# Saved 0756_court-change.md
# Saved 0753_octolock.md
# Processing Move: max-hailstorm...
# Processing Move: max-ooze...
# Processing Move: max-geyser...
# Saved 0758_max-flutterby.md
# Saved 0755_fishious-rend.md
# Processing Move: max-airstream...
# Processing Move: max-starfall...
# Saved 0759_max-lightning.md
# Processing Move: max-wyrmwind...
# Saved 0760_max-strike.md
# Saved 0757_max-flare.md
# Processing Move: max-mindstorm...
# Processing Move: max-rockfall...
# Saved 0761_max-knuckle.md
# Processing Move: max-quake...
# Saved 0762_max-phantasm.md
# Processing Move: max-darkness...
# Saved 0763_max-hailstorm.md
# Saved 0764_max-ooze.md
# Processing Move: max-overgrowth...
# Saved 0765_max-geyser.md
# Processing Move: max-steelspike...
# Processing Move: clangorous-soul...
# Saved 0766_max-airstream.md
# Saved 0767_max-starfall.md
# Processing Move: body-press...
# Processing Move: decorate...
# Saved 0769_max-mindstorm.md
# Saved 0770_max-rockfall.md
# Processing Move: drum-beating...
# Processing Move: snap-trap...
# Saved 0768_max-wyrmwind.md
# Processing Move: pyro-ball...
# Saved 0771_max-quake.md
# Processing Move: behemoth-blade...
# Saved 0772_max-darkness.md
# Processing Move: behemoth-bash...
# Saved 0773_max-overgrowth.md
# Processing Move: aura-wheel...
# Saved 0774_max-steelspike.md
# Processing Move: breaking-swipe...
# Saved 0775_clangorous-soul.md
# Saved 0776_body-press.md
# Processing Move: branch-poke...
# Saved 0778_drum-beating.md
# Processing Move: overdrive...
# Saved 0777_decorate.md
# Processing Move: apple-acid...
# Processing Move: grav-apple...
# Saved 0779_snap-trap.md
# Processing Move: spirit-break...
# Saved 0781_behemoth-blade.md
# Processing Move: strange-steam...
# Saved 0780_pyro-ball.md
# Processing Move: life-dew...
# Saved 0782_behemoth-bash.md
# Processing Move: obstruct...
# Saved 0787_apple-acid.md
# Processing Move: false-surrender...
# Saved 0784_breaking-swipe.md
# Saved 0785_branch-poke.md
# Saved 0783_aura-wheel.md
# Processing Move: meteor-assault...
# Processing Move: eternabeam...
# Saved 0788_grav-apple.md
# Processing Move: steel-beam...
# Processing Move: expanding-force...
# Saved 0786_overdrive.md
# Processing Move: steel-roller...
# Saved 0789_spirit-break.md
# Saved 0790_strange-steam.md
# Processing Move: scale-shot...
# Processing Move: meteor-beam...
# Saved 0791_life-dew.md
# Saved 0792_obstruct.md
# Processing Move: shell-side-arm...
# Processing Move: misty-explosion...
# Saved 0793_false-surrender.md
# Processing Move: grassy-glide...
# Saved 0794_meteor-assault.md
# Processing Move: rising-voltage...
# Saved 0795_eternabeam.md
# Saved 0797_expanding-force.md
# Processing Move: terrain-pulse...
# Saved 0796_steel-beam.md
# Processing Move: skitter-smack...
# Processing Move: burning-jealousy...
# Saved 0798_steel-roller.md
# Saved 0799_scale-shot.md
# Processing Move: lash-out...
# Processing Move: poltergeist...
# Saved 0800_meteor-beam.md
# Saved 0802_misty-explosion.md
# Processing Move: corrosive-gas...
# Processing Move: coaching...
# Saved 0801_shell-side-arm.md
# Processing Move: flip-turn...
# Saved 0803_grassy-glide.md
# Processing Move: triple-axel...
# Saved 0804_rising-voltage.md
# Processing Move: dual-wingbeat...
# Saved 0806_skitter-smack.md
# Processing Move: scorching-sands...
# Saved 0805_terrain-pulse.md
# Processing Move: jungle-healing...
# Saved 0809_poltergeist.md
# Processing Move: wicked-blow...
# Saved 0808_lash-out.md
# Saved 0807_burning-jealousy.md
# Processing Move: surging-strikes...
# Processing Move: thunder-cage...
# Saved 0811_coaching.md
# Saved 0812_flip-turn.md
# Processing Move: dragon-energy...
# Processing Move: freezing-glare...
# Saved 0810_corrosive-gas.md
# Saved 0813_triple-axel.md
# Processing Move: fiery-wrath...
# Processing Move: thunderous-kick...
# Saved 0814_dual-wingbeat.md
# Processing Move: glacial-lance...
# Saved 0815_scorching-sands.md
# Processing Move: astral-barrage...
# Saved 0816_jungle-healing.md
# Saved 0818_surging-strikes.md
# Processing Move: eerie-spell...
# Saved 0817_wicked-blow.md
# Saved 0819_thunder-cage.md
# Processing Move: dire-claw...
# Processing Move: psyshield-bash...
# Processing Move: power-shift...
# Saved 0820_dragon-energy.md
# Saved 0822_fiery-wrath.md
# Processing Move: stone-axe...
# Saved 0823_thunderous-kick.md
# Processing Move: springtide-storm...
# Saved 0821_freezing-glare.md
# Processing Move: mystical-power...
# Processing Move: raging-fury...
# Saved 0824_glacial-lance.md
# Processing Move: wave-crash...
# Saved 0825_astral-barrage.md
# Processing Move: chloroblast...
# Saved 0826_eerie-spell.md
# Saved 0829_power-shift.md
# Saved 0828_psyshield-bash.md
# Processing Move: mountain-gale...
# Processing Move: victory-dance...
# Processing Move: headlong-rush...
# Saved 0827_dire-claw.md
# Processing Move: barb-barrage...
# Saved 0831_springtide-storm.md
# Saved 0830_stone-axe.md
# Saved 0832_mystical-power.md
# Processing Move: esper-wing...
# Processing Move: bitter-malice...
# Saved 0833_raging-fury.md
# Processing Move: shelter...
# Processing Move: triple-arrows...
# Saved 0834_wave-crash.md
# Processing Move: infernal-parade...
# Saved 0835_chloroblast.md
# Processing Move: ceaseless-edge...
# Saved 0836_mountain-gale.md
# Processing Move: bleakwind-storm...
# Saved 0838_headlong-rush.md
# Processing Move: wildbolt-storm...
# Saved 0837_victory-dance.md
# Processing Move: sandsear-storm...
# Saved 0840_esper-wing.md
# Saved 0839_barb-barrage.md
# Processing Move: lunar-blessing...
# Processing Move: take-heart...
# Saved 0842_shelter.md
# Processing Move: tera-blast...
# Saved 0844_infernal-parade.md
# Saved 0841_bitter-malice.md
# Processing Move: silk-trap...
# Saved 0843_triple-arrows.md
# Processing Move: axe-kick...
# Processing Move: last-respects...
# Saved 0845_ceaseless-edge.md
# Processing Move: lumina-crash...
# Saved 0846_bleakwind-storm.md
# Processing Move: order-up...
# Saved 0847_wildbolt-storm.md
# Processing Move: jet-punch...
# Saved 0848_sandsear-storm.md
# Processing Move: spicy-extract...
# Saved 0849_lunar-blessing.md
# Processing Move: spin-out...
# Saved 0850_take-heart.md
# Saved 0851_tera-blast.md
# Processing Move: population-bomb...
# Processing Move: ice-spinner...
# Saved 0852_silk-trap.md
# Processing Move: glaive-rush...
# Saved 0855_lumina-crash.md
# Saved 0854_last-respects.md
# Saved 0853_axe-kick.md
# Saved 0856_order-up.md
# Processing Move: revival-blessing...
# Processing Move: salt-cure...
# Processing Move: triple-dive...
# Processing Move: mortal-spin...
# Saved 0857_jet-punch.md
# Processing Move: doodle...
# Saved 0859_spin-out.md
# Processing Move: fillet-away...
# Saved 0858_spicy-extract.md
# Processing Move: kowtow-cleave...
# Saved 0861_ice-spinner.md
# Processing Move: flower-trick...
# Saved 0862_glaive-rush.md
# Saved 0860_population-bomb.md
# Processing Move: torch-song...
# Processing Move: aqua-step...
# Saved 0865_triple-dive.md
# Saved 0863_revival-blessing.md
# Processing Move: raging-bull...
# Processing Move: make-it-rain...
# Saved 0866_mortal-spin.md
# Processing Move: psyblade...
# Saved 0864_salt-cure.md
# Processing Move: hydro-steam...
# Saved 0868_fillet-away.md
# Saved 0867_doodle.md
# Processing Move: ruination...
# Processing Move: collision-course...
# Saved 0872_aqua-step.md
# Saved 0869_kowtow-cleave.md
# Processing Move: electro-drift...
# Processing Move: shed-tail...
# Saved 0871_torch-song.md
# Processing Move: chilly-reception...
# Saved 0870_flower-trick.md
# Saved 0874_make-it-rain.md
# Processing Move: tidy-up...
# Processing Move: snowscape...
# Saved 0873_raging-bull.md
# Saved 0875_psyblade.md
# Processing Move: pounce...
# Processing Move: trailblaze...
# Saved 0876_hydro-steam.md
# Processing Move: chilling-water...
# Saved 0877_ruination.md
# Processing Move: hyper-drill...
# Saved 0878_collision-course.md
# Processing Move: twin-beam...
# Saved 0879_electro-drift.md
# Processing Move: rage-fist...
# Saved 0880_shed-tail.md
# Processing Move: armor-cannon...
# Saved 0881_chilly-reception.md
# Saved 0884_pounce.md
# Processing Move: bitter-blade...
# Processing Move: double-shock...
# Saved 0882_tidy-up.md
# Saved 0883_snowscape.md
# Saved 0885_trailblaze.md
# Processing Move: gigaton-hammer...
# Processing Move: comeuppance...
# Processing Move: aqua-cutter...
# Saved 0886_chilling-water.md
# Processing Move: blazing-torque...
# Saved 0887_hyper-drill.md
# Processing Move: wicked-torque...
# Saved 0888_twin-beam.md
# Saved 0891_bitter-blade.md
# Saved 0890_armor-cannon.md
# Saved 0889_rage-fist.md
# Processing Move: noxious-torque...
# Processing Move: combat-torque...
# Processing Move: magical-torque...
# Processing Move: blood-moon...
# Saved 0895_aqua-cutter.md
# Saved 0894_comeuppance.md
# Saved 0892_double-shock.md
# Processing Move: matcha-gotcha...
# Processing Move: syrup-bomb...
# Saved 0893_gigaton-hammer.md
# Saved 0896_blazing-torque.md
# Processing Move: ivy-cudgel...
# Processing Move: electro-shot...
# Processing Move: tera-starstorm...
# Saved 0897_wicked-torque.md
# Processing Move: fickle-beam...
# Saved 0899_combat-torque.md
# Processing Move: burning-bulwark...
# Saved 0900_magical-torque.md
# Saved 0898_noxious-torque.md
# Processing Move: thunderclap...
# Processing Move: mighty-cleave...
# Saved 0901_blood-moon.md
# Saved 0906_tera-starstorm.md
# Processing Move: tachyon-cutter...
# Processing Move: hard-press...
# Saved 0905_electro-shot.md
# Processing Move: dragon-cheer...
# Saved 0903_syrup-bomb.md
# Saved 0902_matcha-gotcha.md
# Saved 0904_ivy-cudgel.md
# Processing Move: alluring-voice...
# Processing Move: temper-flare...
# Processing Move: supercell-slam...
# Saved 0907_fickle-beam.md
# Processing Move: psychic-noise...
# Saved 0909_thunderclap.md
# Processing Move: upper-hand...
# Saved 0908_burning-bulwark.md
# Processing Move: malignant-chain...
# Saved 0910_mighty-cleave.md
# Saved 0912_hard-press.md
# Processing Move: shadow-rush...
# Processing Move: shadow-blast...
# Saved 0911_tachyon-cutter.md
# Saved 0913_dragon-cheer.md
# Processing Move: shadow-blitz...
# Processing Move: shadow-bolt...
# Saved 0916_supercell-slam.md
# Saved 0915_temper-flare.md
# Saved 0914_alluring-voice.md
# Processing Move: shadow-break...
# Processing Move: shadow-chill...
# Processing Move: shadow-end...
# Saved 0917_psychic-noise.md
# Processing Move: shadow-fire...
# Saved 0918_upper-hand.md
# Saved 0919_malignant-chain.md
# Processing Move: shadow-rave...
# Processing Move: shadow-storm...
# Saved 10002_shadow-blast.md
# Saved 10001_shadow-rush.md
# Processing Move: shadow-wave...
# Processing Move: shadow-down...
# Saved 10004_shadow-bolt.md
# Processing Move: shadow-half...
# Saved 10005_shadow-break.md
# Saved 10007_shadow-end.md
# Saved 10003_shadow-blitz.md
# Processing Move: shadow-hold...
# Processing Move: shadow-mist...
# Processing Move: shadow-panic...
# Saved 10006_shadow-chill.md
# Saved 10008_shadow-fire.md
# Processing Move: shadow-shed...
# Processing Move: shadow-sky...
# Saved 10010_shadow-storm.md
# Saved 10009_shadow-rave.md
# Saved 10012_shadow-down.md
# Saved 10016_shadow-panic.md
# Saved 10013_shadow-half.md
# Saved 10015_shadow-mist.md
# Saved 10011_shadow-wave.md
# Saved 10014_shadow-hold.md
# Saved 10017_shadow-shed.md
# Saved 10018_shadow-sky.md
# Moves Generation complete.
