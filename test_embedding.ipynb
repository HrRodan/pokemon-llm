# %%
from IPython.core.display import Markdown
from IPython.core.display_functions import display
from ingest import query_database

# %%
display(Markdown(query_database("Pokemon  number 133", n_results=10,category=["pokemon"], max_generation=2, only_default_version=True)))
# Out:
# ### Entity: eevee
# - **Category**: pokemon
# - **ID**: 133
# - **Generation**: Generation I
#
# ## Identity & Lore
# Eevee (Pokedex #133) is the Normal-type Evolution Pokémon introduced in Generation I (Kanto). Renowned for its unique biological instability, Eevee possesses an irregular genetic code that allows it to mutate instantly when exposed to the radiation of elemental stones or specific environmental conditions. This small, brown, quadrupedal mammal is highly adaptive and is often found in urban environments where it can interact with humans. While typically small in stature, Eevee is capable of undergoing **Gigantamax**, transforming into a colossal form with fluffy fur that entraps opponents. It is the distinct precursor to eight different evolutionary possibilities, collectively known as "Eeveelutions."
#
# ## Combat Profile
# *   **Stats:** HP 55, Attack 55, Defense 50, Sp. Atk 45, Sp. Def 65, Speed 55.
# *   **Archetype:** Little Cup Pivot / Baton Pass Support.
# *   **Type Matchups:** It is **weak to Fighting** and possesses a valuable **immunity to Ghost**. It has no natural resistances.
# *   **Move Selection:** Capitalizing on its Attack stat and supportive capabilities, key moves include **Double-Edge** (maximized by Adaptability), **Quick Attack** for priority execution, **Wish** for health recovery, and **Baton Pass** to transfer stat changes or safely pivot teammates in.
# *   **Abilities:**
#     *   **Run Away:** Ensures escape from wild Pokémon battles.
#     *   **Adaptability:** Increases the Same Type Attack Bonus (STAB) from 1.5x to 2x, significantly boosting the power of its Normal-type moves.
#     *   **Anticipation (Hidden):** The Pokémon shudders when it senses a super-effective or one-hit KO move from an opponent.
#
# ## Evolution & Biology
# Eevee is the base of a complex, branched evolutionary line offering eight distinct outcomes based on specific triggers. It belongs to the **Ground** Egg Group.
# *   It evolves into **Vaporeon** when exposed to a **Water Stone**.
# *   It evolves into **Jolteon** when exposed to a **Thunder Stone**.
# *   It evolves into **Flareon** when exposed to a **Fire Stone**.
# *   It evolves into **Espeon** when leveled up with **High Friendship during the day**.
# *   It evolves into **Umbreon** when leveled up with **High Friendship during the night**.
# *   It evolves into **Leafeon** when exposed to a **Leaf Stone** (or near a Mossy Rock).
# *   It evolves into **Glaceon** when exposed to an **Ice Stone** (or near an Icy Rock).
# *   It evolves into **Sylveon** when leveled up while knowing a **Fairy-type move** and having **High Friendship/Affection**.
#
# ---
#
# ### Entity: pikachu
# - **Category**: pokemon
# - **ID**: 25
# - **Generation**: Generation I
#
# ## Identity & Lore
# Pikachu (Pokedex #025) is the Electric-type Mouse Pokémon originally discovered in the Kanto region (Generation I). Characterized by its yellow fur and jagged, lightning-bolt tail, this quadruped typically inhabits **forest** environments. Biological lore indicates that when several of these Pokémon gather, their combined electricity can build up intense power, potentially causing lightning storms. While standard specimens appear as described, Pikachu possesses a unique **Gigantamax** potential (typically involving specific factors not listed in standard forms) and is the mascot of the franchise. It is arguably the most recognized Pokémon in existence.
#
# ## Combat Profile
# *   **Stats:** HP 35, Attack 55, Defense 40, Sp. Atk 50, Sp. Def 50, Speed 90.
# *   **Archetype:** Fast Mixed Attacker / Glass Cannon. While its base stats are modest, Pikachu is distinctively defined by its signature held item, the **Light Ball**, which doubles its offensive stats, allowing it to function as a fragile but potent sweeper.
# *   **Type Matchups:** It is **weak to Ground** and **resists Electric, Flying, and Steel**.
# *   **Move Selection:** Capitalizing on its Speed and Mixed attacking stats, key moves include **Volt Tackle** (Signature Physical STAB), **Thunderbolt** (Reliable Special STAB), **Surf** (Crucial coverage against Ground-types), and **Nuzzle** (Utility for speed control and paralysis).
# *   **Abilities:** **Static** (May paralyze attackers upon contact) and **Lightning Rod** (Hidden Ability; draws in Electric-type moves to grant immunity and raise Special Attack).
#
# ## Evolution & Biology
# Pikachu is the middle stage of a 3-stage evolutionary line. It evolves from the baby Pokémon **Pichu** when leveled up with **High Friendship**. Pikachu evolves into **Raichu** only when exposed to a **Thunder Stone**. It belongs to the **Ground** (Field) and **Fairy** Egg Groups.
#
# ---
#
# ### Entity: phanpy
# - **Category**: pokemon
# - **ID**: 231
# - **Generation**: Generation II
#
# ## Identity & Lore
# Phanpy (Pokedex #231) is the Long Nose Pokémon, a ground-dwelling species first discovered in **Generation II (Johto)**. Small, blue, and quadrupedal, Phanpy is characterized by the red pads on its large ears and its expressive snout. It typically inhabits **rough terrain** where it can utilize its natural hardiness. While generally spirited and affectionate, Phanpy possesses deceptively high physical strength; it is known to swing its long snout around playfully, which can be dangerous enough to send an adult human flying if they are struck. Although Phanpy itself does not possess alternate forms, its evolution, Donphan, is biologically linked to the Paradox Pokémon **Great Tusk** (Ancient) and **Iron Treads** (Future) discovered in the Paldea region.
#
# ## Combat Profile
# *   **Stats:** HP 90, Attack 60, Defense 60, Sp. Atk 40, Sp. Def 40, Speed 40.
# *   **Archetype:** Bulky Physical Attacker / Little Cup Tank.
# *   **Type Matchups:** As a pure **Ground** type, it is **weak to Water, Grass, and Ice**. It possesses a natural **immunity to Electric** attacks and **resists Poison and Rock**.
# *   **Move Selection:** Capitalizing on its surprisingly high HP and decent Attack for an unevolved Pokémon, its optimal moveset includes **Earthquake** (powerful STAB), **Ice Shard** (priority coverage against Flying types), **Play Rough** (coverage against Fighting and Dark types), and **Knock Off** (utility to remove opponent items).
# *   **Abilities:**
#     *   **Pickup:** The Pokémon may gather items used during battle or found while adventuring.
#     *   **Sand Veil (Hidden):** Boosts the Pokémon's evasion inside a sandstorm, making it harder to hit in weather teams.
#
# ## Evolution & Biology
# Phanpy is the first stage of a two-stage evolutionary line. It evolves into the Armor Pokémon, **Donphan**, when it reaches **Level 25**. It belongs to the **Ground** (Field) Egg Group and has a base hatch counter of 20 cycles.
#
# ---
#
# ### Entity: caterpie
# - **Category**: pokemon
# - **ID**: 10
# - **Generation**: Generation I
#
# ## Identity & Lore
# Caterpie (Pokedex #010) is the Worm Pokémon, a ubiquitous Bug-type native to the Kanto region (Generation I). This small, green larva is a common sight in forests and wooded areas, where it camouflages among foliage. According to ecological research, its short feet are tipped with suction pads that enable it to tirelessly climb slopes and walls to reach its primary diet of leaves. While Caterpie itself does not possess alternate forms, its final evolution, Butterfree, is capable of achieving a **Gigantamax** form in regions like Galar. It is recognized by the red antenna (osmeterium) on its head, which releases a stench to repel predators.
#
# ## Combat Profile
# *   **Stats:** HP 45, Attack 30, Defense 35, Sp. Atk 20, Sp. Def 20, Speed 45.
# *   **Archetype:** Early-Game Physical Attacker / Evolving Larva.
# *   **Type Matchups:** As a pure Bug-type, it is **weak to Flying, Rock, and Fire**. It **resists Fighting, Grass, and Ground** moves.
# *   **Move Selection:** Due to its limited move pool and slightly higher Attack stat, its optimal loadout includes **Bug Bite** (STAB), **Tackle**, **String Shot** (for Speed control), and **Electroweb** (provides rare coverage and speed reduction despite being a Special move).
# *   **Abilities:**
#     *   **Shield Dust:** Blocks the additional effects of attacks taken (e.g., prevents paralysis from Body Slam).
#     *   **Run Away (Hidden):** Enables a sure getaway from wild Pokémon battles.
#
# ## Evolution & Biology
# Caterpie is the first stage of a classic 3-stage evolutionary line known for its extremely rapid growth cycle. It evolves into **Metapod** starting at **Level 7**. Subsequently, Metapod evolves into the dual-type Bug/Flying **Butterfree** starting at **Level 10**. This quick maturation allows trainers to access a fully evolved Pokémon very early in their journey. Caterpie belongs to the **Bug** Egg Group and has a hatch counter of 15 cycles.
#
# ---
#
# ### Entity: nidoran-m
# - **Category**: pokemon
# - **ID**: 32
# - **Generation**: Generation I
#
# ## Identity & Lore
# Nidoran♂ (Pokedex #032) is the Poison Pin Pokémon, a small, quadrupedal creature distinct for its purple coloration and large ears. Indigenous to the **Generation I (Kanto)** region, this Pokémon frequents grassland habitats where it uses its sensitive ears to monitor its surroundings for potential threats. Its biology is centered around toxicity; the larger its horns grow, the more potent the secreted venom becomes. Uniquely, Nidoran♂ was one of the first Pokémon to display distinct sexual dimorphism, serving as the male counterpart to Nidoran♀.
#
# ## Combat Profile
# *   **Stats:** HP 46, Attack 57, Defense 40, Sp. Atk 40, Sp. Def 40, Speed 50.
# *   **Archetype:** Physical Attacker / Little Cup Wallbreaker.
# *   **Type Matchups:** As a pure Poison-type, it is **weak to Ground and Psychic** moves. It defensively **resists Fighting, Poison, Bug, Grass, and Fairy** types.
# *   **Move Selection:** Capitalizing on its higher Attack stat and wide movepool, key moves include **Poison Jab** for reliable STAB (Same Type Attack Bonus), **Drill Run** or **Earth Power** to handle Steel and Poison types, **Sucker Punch** for priority, and **Double Kick** or **Head Smash** for heavy damage.
# *   **Abilities:**
#     *   **Poison Point:** Contact with this Pokémon may poison the attacker.
#     *   **Rivalry:** Deals more damage to Pokémon of the same gender, but less damage to the opposite gender.
#     *   **Hustle (Hidden Ability):** Boosts Attack by 50% but lowers physical move accuracy by 20%, turning Nidoran♂ into a high-risk, high-reward physical threat.
#
# ## Evolution & Biology
# Nidoran♂ is the first stage of a 3-stage evolutionary line. It evolves into **Nidorino** starting at **Level 16**. Nidorino can then evolve into the powerhouse **Nidoking** when exposed to a **Moon Stone**. It belongs to the **Monster** and **Ground** Egg Groups.
#
# ---
#
# ### Entity: pupitar
# - **Category**: pokemon
# - **ID**: 247
# - **Generation**: Generation II
#
# ## Identity & Lore
# Pupitar (Pokédex #247) is the Hard Shell Pokémon, introduced in Generation II (Johto). This Rock/Ground-type serves as the transitional pupal stage for the pseudo-legendary Tyranitar line. Unlike most pupa-stage Pokémon that remain stationary, Pupitar is extremely active and dangerous; its gray shell is described as being as hard as sheet rock. It possesses enough power to topple a mountain with its thrashing capabilities and propels itself around its mountain habitat using compressed gas. While it has no specific alternate forms, its final evolution, Tyranitar, is capable of Mega Evolution.
#
# ## Combat Profile
# *   **Stats:** HP 70, Attack 84, Defense 70, Sp. Atk 65, Sp. Def 70, Speed 51.
# *   **Archetype:** Physical Setup Attacker / NFE Tank.
# *   **Type Matchups:** As a dual Rock/Ground type, it suffers from **Double Weaknesses (4x) to Water and Grass**. It is also weak to Fighting, Ground, Steel, and Ice. However, it is **immune to Electric** and resists Normal, Flying, Rock, Fire, and Poison types.
# *   **Move Selection:** Capitalizing on its naturally high Attack stat and setup potential, key moves include **Dragon Dance** (to boost speed and power), **Earthquake** (strong STAB), **Stone Edge** (strong STAB), and **Crunch** (coverage). Utility options like **Stealth Rock** are also viable.
# *   **Abilities:** **Shed Skin** (At the end of each turn, this Pokémon has a 33% chance to heal any non-volatile status condition).
#
# ## Evolution & Biology
# Pupitar is the middle stage of a 3-stage evolutionary line. It evolves from **Larvitar** starting at **Level 30** and evolves into **Tyranitar** starting at **Level 55**. It belongs to the **Monster** Egg Group and has a slow maturation process, requiring a high amount of experience to level up.
#
# ---
#
# ### Entity: sandshrew
# - **Category**: pokemon
# - **ID**: 27
# - **Generation**: Generation I
#
# ## Identity & Lore
# Sandshrew (Pokedex #027) is the Ground-type Mouse Pokémon introduced in Generation I (Kanto). Distinguished by its yellow, brick-patterned hide, Sandshrew possesses a dry, tough skin that minimizes water loss, allowing it to survive in arid locations and rough terrain. It is a burrowing creature that digs deep underground to avoid the heat of the day, only emerging to hunt for food. When threatened, it curls into a tight ball, exposing only its hard back to predators while protecting its soft, white underbelly. While this profile details the standard Ground-type form, Sandshrew possesses a notable regional variant found in the Alola region, which adapts to snowy mountains as an Ice/Steel type.
#
# ## Combat Profile
# *   **Stats:** HP 50, Attack 75, Defense 85, Sp. Atk 20, Sp. Def 30, Speed 40.
# *   **Archetype:** Physical Tank / Physical Wallbreaker (Little Cup).
# *   **Type Matchups:** As a pure Ground-type, it is **weak to Water, Grass, and Ice**. It **resists Poison and Rock** damage and possesses a total **immunity to Electric** attacks.
# *   **Move Selection:** Capitalizing on its high Defense and respectable Attack, an optimal move set includes **Earthquake** (powerful STAB), **Swords Dance** (to sharply boost its Attack), **Rock Slide** or **Stone Edge** (for coverage against Ice and Flying types), and **Rapid Spin** (to clear entry hazards).
# *   **Abilities:**
#     *   **Sand Veil:** Increases the Pokémon's evasion by 20% during a sandstorm.
#     *   **Sand Rush (Hidden Ability):** Doubles the Pokémon's Speed stat during a sandstorm, transforming it from a slow tank into a fast sweeper.
#
# ## Evolution & Biology
# Sandshrew is part of a 2-stage evolutionary line. It evolves into **Sandslash** starting at **Level 22**. While the standard form evolves via leveling up, its Alolan variant requires an Ice Stone to evolve. Sandshrew belongs to the **Ground (Field)** Egg Group and has a hatch counter of 20 cycles. In the wild, it is known to carry items such as the Quick Claw or Grip Claw.
#
# ---
#
# ### Entity: ditto
# - **Category**: pokemon
# - **ID**: 132
# - **Generation**: Generation I
#
# ## Identity & Lore
# Ditto (Pokedex #132) is the unique Normal-type Transform Pokémon introduced in Generation I (Kanto). An amorphous, purple blob with a rudimentary face, Ditto possesses the extraordinary ability to reorganize its cellular structure to mimic the appearance, cry, and moves of any opposing Pokémon. While it is naturally found in urban habitats, presumably to observe and mimic other life forms, it relies on memory to transform; if it attempts to mimic something it is not currently looking at, it may get the details wrong. While it lacks its own Mega Evolution or Gigantamax form, Ditto is capable of copying these enhanced states if it transforms into an opponent already utilizing them. It is famously essential to Pokémon ecology and breeding centers due to its flexible genetic code.
#
# ## Combat Profile
# *   **Stats:** HP 48, Attack 48, Defense 48, Sp. Atk 48, Sp. Def 48, Speed 48.
# *   **Archetype:** Situational Revenge Killer / Copycat Utility.
# *   **Type Matchups:** In its base form, it is **weak to Fighting** and **immune to Ghost**. (Note: Upon transformation, Ditto adopts the Type Matchups of its target).
# *   **Move Selection:** Uniquely, Ditto relies entirely on a single move: **Transform**. Upon use, it permanently copies the target's stats (except HP), type, Ability, and moveset for the duration of the battle. Because its base stats are low, its combat viability relies entirely on copying a stronger opponent.
# *   **Abilities:**
#     *   **Limber:** Protects the Pokémon from paralysis.
#     *   **Imposter (Hidden):** The defining competitive ability. As soon as the Pokémon enters battle, it automatically transforms into the opponent without wasting a turn using the move Transform. This allows Ditto to function as an immediate counter-attacker or scout.
#
# ## Evolution & Biology
# Ditto is a standalone Pokémon with no evolutionary line; it does not evolve from or into any other species. Despite not evolving, it holds a critical role in propagation. It belongs to the unique **Ditto Egg Group**, making it the universal breeding partner. It can breed with any Pokémon capable of reproduction (regardless of gender or species), including genderless Pokémon, acting as a genetic surrogate to produce Eggs of the partner's species. It can utilize species-specific held items such as **Metal Powder** (which boosts Defense) and **Quick Powder** (which boosts Speed) while in its untransformed state.
#
# ---
#
# ### Entity: slowpoke
# - **Category**: pokemon
# - **ID**: 79
# - **Generation**: Generation I
#
# ## Identity & Lore
# Slowpoke (Pokedex #079) is the Water/Psychic-type Dopey Pokémon introduced in Generation I (Kanto). This pink, quadrupedal creature is defined by its incredibly sluggish behavior and vacant expression. Lore indicates that its sensory systems are so delayed that it takes approximately five seconds for it to feel pain after being attacked. Slowpoke is often found at the **water's edge**, where it uses its sweet-tasting tail as a lure to fish for prey; however, it often forgets what it is doing due to its poor memory. While this profile details the standard Kantonian form, Slowpoke possesses a Psychic-type regional variant known as **Galarian Slowpoke**. Additionally, its evolved form, Slowbro, is capable of **Mega Evolution**.
#
# ## Combat Profile
# *   **Stats:** HP 90, Attack 65, Defense 65, Sp. Atk 40, Sp. Def 40, Speed 15.
# *   **Archetype:** Physical Tank / Bulky Pivot / Trick Room Setter.
# *   **Type Matchups:** It is **weak to Grass, Electric, Bug, Ghost, and Dark**. It **resists Fire, Water, Ice, Fighting, Psychic, and Steel**.
# *   **Move Selection:** Capitalizing on its higher Attack stat (65) compared to its Special Attack (40), and its utility as a pivot, key moves include **Liquidation, Zen Headbutt, Slack Off, and Trick Room**.
# *   **Abilities:**
#     *   **Oblivious:** Prevents the Pokémon from being infatuated or falling for Taunt.
#     *   **Own Tempo:** Prevents the Pokémon from becoming confused.
#     *   **Regenerator (Hidden):** Restores 33.3% of its maximum HP when switching out, making it a premier defensive pivot in competitive play.
#
# ## Evolution & Biology
# Slowpoke is part of a split evolutionary line.
# 1.  It evolves into **Slowbro** when leveled up to **Level 37**.
# 2.  Alternatively, it evolves into **Slowking** when traded while holding a **King's Rock**.
# Biological data indicates it belongs to the **Monster** and **Water 1** Egg Groups, and it has a hatch counter of 20. While the standard Slowpoke evolves via the methods above, its Galarian counterpart utilizes Galarica Cuffs or Galarica Wreaths to evolve.
#
# ---
#
# ### Entity: pichu
# - **Category**: pokemon
# - **ID**: 172
# - **Generation**: Generation II
#
# ## Identity & Lore
# Pichu (Pokedex #172) is the Electric-type Tiny Mouse Pokémon introduced in Generation II (Johto). Small, yellow, and classified as a **Baby Pokémon**, Pichu inhabits forests and socializes in groups, though it is famously unskilled at controlling its own power. Its cheek pouches are small and cannot store electricity effectively, causing it to accidentally discharge jolts when startled, amused, or even when laughing. A unique variant known as **Spiky-eared Pichu** exists in historical records (HeartGold/SoulSilver), though it cannot evolve or be transferred. As the pre-evolution of the franchise mascot, it is inextricably linked to the potential for evolving into **Gigantamax Pikachu** or the regional **Alolan Raichu** later in its life cycle.
#
# ## Combat Profile
# * **Stats:** HP 20, Attack 40, Defense 15, Sp. Atk 35, Sp. Def 35, Speed 60.
# * **Archetype:** Little Cup (LC) Fast Frail Sweeper / Glass Cannon.
# * **Type Matchups:** It is **weak to Ground** and **resists Electric, Flying, and Steel**.
# * **Move Selection:** Capitalizing on its Speed and mixed offensive capabilities (often enhanced by the Light Ball item in later stages), key moves include **Volt Tackle** (its signature heavy-hitting physical STAB), **Nasty Plot** (to sharply boost Special Attack), **Thunderbolt** (reliable special damage), and **Play Rough** (physical Fairy-type coverage).
# * **Abilities:**
#     *   **Static:** Has a 30% chance to paralyze the opponent when hit by a physical contact move.
#     *   **Lightning Rod (Hidden):** Grants immunity to Electric-type moves and raises Special Attack by one stage when hit by one.
#
# ## Evolution & Biology
# Pichu is the first stage of a 3-stage evolutionary line. It evolves into **Pikachu** when leveled up with **High Friendship** (220+). Subsequently, Pikachu can evolve into **Raichu** when exposed to a **Thunder Stone**. Because Pichu is a Baby Pokémon, it belongs to the **No Eggs** (Undiscovered) egg group and cannot breed until it evolves; however, breeding a female Pikachu or Raichu holding a Light Ball will produce a Pichu with the move Volt Tackle.
