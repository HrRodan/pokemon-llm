# %%
from agents.tech_data_agent import TechDataAgent

# %%
a = "who are you? I am "
def test():
    return

# %%
def test():
    return "Hi there"
# Out:
#   Cell In[1], line 1
#     def test():
#                ^
# SyntaxError: incomplete input

# %%
a = TechDataAgent()
a.response("List all Pokemon with names containing 'hound', 'dog', 'pup', 'wolf', or similar canine-related terms in their name or species")
# Out:
# [16:21:08] [TechDataAgent] Agent 'TechDataAgent' initialized with model 'openai/gpt-oss-20b'
# [16:21:08] [TechDataAgent] QUERY: List all Pokemon with names containing 'hound', 'dog', 'pup', 'wolf', or similar canine-related terms in their name or species
# [16:21:11] [TechDataAgent] 🛠️  TOOL REQUESTED: execute_query | Args: {"table":"pokemons","columns":["id","name","species_name"],"conditions":[{"column":"is_default","operator":"=","value":true},{"column":"name","operator":"LIKE","value":"%hound%"}],"condition_logic":"AND"}
# [16:21:11] [TechDataAgent] TOOL CALL: execute_query | Args: {'table': 'pokemons', 'columns': ['id', 'name', 'species_name'], 'conditions': [{'column': 'is_default', 'operator': '=', 'value': True}, {'column': 'name', 'operator': 'LIKE', 'value': '%hound%'}], 'condition_logic': 'AND'}
# [16:21:11] [TechDataAgent] TOOL OUTPUT (execute_query): | id | name | species_name |
# | --- | --- | --- |
# | 228 | houndour | houndour |
# | 229 | houndoom | houndoom |
# ...

# %%
from tools.vector_db import TOOLS, query_database

print(TOOLS)
# Out:
# [{'type': 'function', 'function': {'name': 'query_database', 'description': 'Queries the vector database for relevant Pokemon information (Pokemon, Moves, Items) based on a semantic query string. returns a markdown formatted string with the results.', 'parameters': {'description': 'Queries the vector database for relevant Pokemon information (Pokemon, Moves, Items) based on a semantic query string. returns a markdown formatted string with the results.', 'properties': {'query': {'description': "The semantic query string to search for (e.g. 'fire type pokemon that can learn fly', 'items that restore PP').", 'title': 'Query', 'type': 'string'}, 'n_results': {'default': 3, 'description': 'Number of results to return. Defaults to 3. Do NOT Exceed 10.', 'maximum': 10, 'minimum': 1, 'title': 'N Results', 'type': 'integer'}, 'category': {'anyOf': [{'items': {'enum': ['pokemon', 'move', 'item'], 'type': 'string'}, 'type': 'array'}, {'enum': ['pokemon', 'move', 'item'], 'type': 'string'}, {'ty
# ...

# %%
query_database(query = 'What move is called hyper beam?', type = 'move')
# Out:
# '### Entity: hyper-beam\n- **Category**: move\n- **ID**: 63\n- **Generation**: Generation I\n\n## Identity & Mechanics\n**Hyper Beam** is a Special Normal-type move introduced in Generation I.\n* **Description:** The user focuses its internal energy into a concentrated sphere before unleashing a massive, blinding beam of pure destructive force at the target. This cataclysmic discharge of energy is so taxing that the user must spend the following turn cooling down and recovering its stamina.\n* **Effect:** Inflicts massive damage. If the move hits, the user is forced to "recharge" on the next turn, preventing it from attacking, using items, or switching out.\n* **Secondary Effect:** None (Recharge is a mandatory mechanic).\n* **Targeting:** Selected single target.\n\n## Competitive Profile\n* **Stats:** Power 150, Accuracy 90%, PP 5.\n* **Role:** High-Risk Nuke / Finisher.\n* **Usage:** Hyper Beam is the quintessential "all-or-nothing" move. While its raw power is among the highest in
# ...

# %%
a.llm.chat_history
# Out:
# [{'role': 'user',
#   'content': "List all Pokemon with names containing 'hound', 'dog', 'pup', 'wolf', or similar canine-related terms in their name or species"},
#  {'role': 'assistant',
#   'content': '',
#   'tool_calls': [{'id': 'fc_f42408ff-8d73-4b23-b33a-20afe7a3c957',
#     'function': {'arguments': '{"columns":["id","name","species_name","type_1","type_2"],"condition_logic":"AND","conditions":[{"column":"is_default","operator":"=","value":true},{"column":"name","operator":"LIKE","value":"%hound%"}],"table":"pokemons"}',
#      'name': 'execute_query'},
#     'type': 'function',
#     'index': 0}]},
#  {'role': 'tool',
#   'content': '| id | name | species_name | type_1 | type_2 |\n| --- | --- | --- | --- | --- |\n| 228 | houndour | houndour | dark | fire |\n| 229 | houndoom | houndoom | dark | fire |\n| 972 | houndstone | houndstone | ghost | None |',
#   'tool_call_id': 'fc_f42408ff-8d73-4b23-b33a-20afe7a3c957'},
#  {'role': 'assistant',
#   'content': '',
# ...
